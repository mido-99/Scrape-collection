# %%
import pandas as pd
import json
from bs4 import BeautifulSoup
from time import sleep
import requests
from markdownify import markdownify as md

# %%
example_url = "https://www.make.com/en/help/app/gmail"

r = requests.get(example_url)
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.text, 'html.parser')
doc = soup.find('section', class_="section original-topic")
doc
# Out:
# <section class="section original-topic" data-legacy-id="UUID-135506fd-7a85-85d9-6f23-0bf1cce31cc2" data-origin-id="UUID-071dc7c2-e628-af06-aebc-7a8feb95114f" data-permalink="apps/communication/gmail.html" data-publication-date="" data-relative-prefix="../../" data-topic-level="3" dir="ltr" id="gmail" lang="en" xml:lang="en"><div class="titlepage"><div><div class="title"><h1 class="title" style="clear: both">Gmail <span class="phrase"></span></h1></div></div></div><p>With Gmail modules in <span class="phrase">Make</span>, you can manage the emails, email labels, and attachments in your Gmail account.</p><p>To use the Gmail modules, you must have a Gmail account. You can create an account at <a class="link" href="https://myaccount.google.com/" rel="noopener" target="_blank">myaccount.google.com</a>.</p><p>Refer to the <a class="link" href="https://developers.google.com/gmail/api/reference/rest" rel="noopener" target="_blank">Gmail API documentation</a> for a list of available endpoints
# ...

# %%
for i in soup.find('div', class_="footer-content").parent:
    print(i)
# Out:
# <div class="breadcrumb-container"><ul class="breadcrumb" xmlns:util="http://www.paligo.net/xsl1/functions/utility"><li class="breadcrumb-link"><a href="./../index-en.html">Make Help Center</a></li><li class="breadcrumb-link"><a href="./../apps.html">Apps</a></li><li class="breadcrumb-link"><a href="/en/help/apps/communication.html">Communication</a></li><li class="breadcrumb-node">Gmail <span class="phrase"></span></li></ul></div>
# ...

# %%
from markdown import markdown
markdown(str(doc))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 from markdown import markdown
#       2 markdown(str(doc))
#
# ModuleNotFoundError: No module named 'markdown'
