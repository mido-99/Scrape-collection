# %%
import json
import pandas as pd
import json
from bs4 import BeautifulSoup
import httpx
from time import sleep

# %%
import requests

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
    'content-type': 'application/json',
    # 'cookie': 'last_touch_gclid=undefined; first_touch_gclid=undefined; first_touch_landing_page=https%3A//www.make.com/en; last_touch_referral_url=; first_touch_referral_url=; referral_url=; gb_anonymous_id=4d967744-c4b8-41b6-9f90-d802fdb6bd2e; rl_page_init_referrer=RudderEncrypt%3AU2FsdGVkX1%2FCz9PRIUWfpw55RZZzB90hnV2RmGpzB%2Bc%3D; rl_page_init_referring_domain=RudderEncrypt%3AU2FsdGVkX18Buyn6d3%2B%2FZ%2BdkINFvxspfeXihCa3tEmk%3D; _ga=GA1.1.1543941994.1716808364; make_session_id=1716808364; poptin_old_user=true; poptin_user_id=0.83emxpg2gfb; _hjSession_2919042=eyJpZCI6IjcyMTJlZjZmLWNmYzItNGI2NC04ZjY2LTlmMDQzMWQ3ZTI2ZSIsImMiOjE3MTY4MDgzNjQ4NDksInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MX0=; poptin_user_ip=156.207.60.19; poptin_user_country_code=false; poptin_session_account_b242bb2954926=true; poptin_c_visitor=true; _gcl_au=1.1.13046725.1716808366; _fbp=fb.1.1716808367190.548965802; first_touch_landing_page_query=%3Fcommunity%3D1%26verified%3D1; OptanonAlertBoxClosed=2024-05-27T11:12:55.793Z; _hjSessionUser_2919042=eyJpZCI6IjgwNmJiZjg5LTY1OTMtNWY5MS1iYjNjLTUwZDQ1ZmU4ZGNlYiIsImNyZWF0ZWQiOjE3MTY4MDgzNjQ4NDcsImV4aXN0aW5nIjp0cnVlfQ==; poptin_referrer=; __cf_bm=ZhmiI_fJ7q50hTmpJ8Egh_mJwmFZAPaR1NP6m8QnpOs-1716809499-1.0.1.1-Fx0gbBEha8nuZx4K5CVf8xKq.oSYj7Se4ArRV028nsrkWJsyYoshTns8C9RRDjC4LhN8Kkxm5HJQUDrUjMaTzQ; poptin_previous_url=; _uetsid=0c5498001c1a11efbdf0954c2b28279f; _uetvid=0c54bd001c1a11ef99362fa261b0d15d; _rdt_uuid=1716808366676.355e1e32-bf41-4c7d-87c5-36507b532296; _ga_MY0CJTCDSF=GS1.1.1716808364.1.1.1716810255.60.0.0; last_touch_landing_page=https%3A//www.make.com/en/integrations; last_touch_landing_page_query=%3Fcommunity%3D1%26verified%3D1; rl_user_id=RudderEncrypt%3AU2FsdGVkX18MS4afj%2B433q2BT8LEHvjcSWTlJng7IYo%3D; rl_trait=RudderEncrypt%3AU2FsdGVkX1955aLSSg6p81sFHh2P%2BUEBgEZDMO7egxI%3D; rl_group_id=RudderEncrypt%3AU2FsdGVkX1%2BzXHnwwFhr2zrLRrE%2BcHBuZXt9hTV%2BOUE%3D; rl_group_trait=RudderEncrypt%3AU2FsdGVkX184R3Cbr2HEJkQaynq%2BjkYGsPNcDOSMdOA%3D; rl_anonymous_id=RudderEncrypt%3AU2FsdGVkX1%2BCtbAFSuSmQiO4RFaiKGp2%2FjamFPyGhCQBQA4m4mfSFnrAMGu0FtzsjPeiD%2BPvpNhcVpIWpLX38w%3D%3D; rl_session=RudderEncrypt%3AU2FsdGVkX195z1rZFRgVdnOj8PSlOdOciXFgY9GVVw31gzR0I301uLS3vEfo%2BsVCefg1HfcaXH73CEzlcTcp3iX%2FGyEdvXawYhtNxAYDwYpUGVpbaOCq1FudLdVBeFyDFseIEfl5NmNp9z0uiEgHvQ%3D%3D; OptanonConsent=isGpcEnabled=0&datestamp=Mon+May+27+2024+14%3A44%3A16+GMT%2B0300+(Eastern+European+Summer+Time)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=758c16f0-df45-4741-813f-b146c2926d1d&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1%2CC0002%3A1&AwaitingReconsent=false&geolocation=EG%3BKN',
    'referer': 'https://www.make.com/en/integrations?community=1&verified=1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
}

params = {
    'name': '',
    'limit': '3000', # high limit to get all plugins
    'offset': '0',   # starting point
    'sort': 'Most Popular',
    'category': '',
    'addOnApps': 'true',
    'nativeApps': 'true',
    'isCategory': 'false',
    'isSubCategory': 'false',
}

response = requests.get('https://www.make.com/pw-api/integrations/search-apps', params=params, headers=headers)

# %%
entities = response.json()['entities']

len(entities)
# Out:
# 1833

# %%
entities[:2]
# Out:
# [{'sys': {'id': 'app-google-sheets'},
#   'slug': 'google-sheets',
#   'name': 'Google Sheets',
#   'priority': 44103,
#   'ratingValue': None,
#   'ratingCount': None,
#   'reviewCount': None,
#   'theme': '#0fa763',
#   'featured': None,
#   'categoriesCollection': {'items': [{'slug': 'productivity'},
#     {'slug': 'app-families'}]},
#   'subcategoriesCollection': {'items': [{'slug': 'spreadsheets'},
#     {'slug': 'google'}]},
#   'icon': {'title': 'Google Sheets',
#    'url': 'https://images.ctfassets.net/un655fb9wln6/appIcon-google-sheets/a35859cd17514e0649a5f42db3d68713/google-sheets.png',
#    'width': 512,
#    'height': 512},
#   'supportedApp': True,
#   'addOnApp': False},
#  {'sys': {'id': 'app-google-email'},
#   'slug': 'google-email',
#   'name': 'Gmail',
#   'priority': 16079,
#   'ratingValue': None,
#   'ratingCount': None,
#   'reviewCount': None,
#   'theme': '#dd4b39',
#   'featured': None,
#   'categoriesCollection': {'items': [{'slug': 'communication'},
#     {'slug': 'app-families'}]},
#   'subcategoriesCollection': {'items': [{'slug': 'email'},
#     {'slug': 'google'}]},
#   'icon': {'title': 'Gmail',
#    'url': 'https://images.ctfassets.net/un655fb9wln6/appIcon-google-email/101a74209982a4c24ba5ebb9413fb87e/google-email.png',
#    'width': 512,
#    'height': 512},
#   'supportedApp': True,
#   'addOnApp': False}]

# %%
df.categoriesCollection[0]
# Out:
# {'items': [{'slug': 'productivity'}, {'slug': 'app-families'}]}

# %%
df.url
# Out:
# 0       https://www.make.com/en/integrations/google-sh...
# 1       https://www.make.com/en/integrations/google-email
# 2           https://www.make.com/en/integrations/airtable
# 3       https://www.make.com/en/integrations/openai-gpt-3
# 4       https://www.make.com/en/integrations/google-drive
#                               ...
# 1825         https://www.make.com/en/integrations/axosoft
# 1826          https://www.make.com/en/integrations/aspsms
# 1827    https://www.make.com/en/integrations/fitpassca...
# 1828    https://www.make.com/en/integrations/threescri...
# 1829    https://www.make.com/en/integrations/ten-to-eight
# Name: url, Length: 1830, dtype: object

# %%
def link(df):

    df['url'] = "https://www.make.com/en/integrations/" + df['slug']

# %%
entities[0]['slug']
# Out:
# 'google-sheets'

# %%
final = []
for rank, i in enumerate(entities, start=1):
    try:
        cat = i['categoriesCollection']['items'][0]['slug'].title()
    except (IndexError, KeyError):
        cat = "Not specified"
    url = "https://www.make.com/en/integrations/" + i['slug']
    final.append({'Plugin Name': i['name'], 'Rank': rank, 'Category': cat, 'url':url})

# %%
final
# Out:
# [{'Plugin Name': 'Google Sheets',
#   'Rank': 1,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/google-sheets'},
#  {'Plugin Name': 'Gmail',
#   'Rank': 2,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/google-email'},
#  {'Plugin Name': 'Airtable',
#   'Rank': 3,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/airtable'},
#  {'Plugin Name': 'OpenAI (ChatGPT, Whisper, DALL-E)',
#   'Rank': 4,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/openai-gpt-3'},
#  {'Plugin Name': 'Google Drive',
#   'Rank': 5,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-drive'},
#  {'Plugin Name': 'Notion',
#   'Rank': 6,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/notion'},
#  {'Plugin Name': 'Slack',
#   'Rank': 7,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/slack'},
#  {'Plugin Name': 'Telegram Bot',
#   'Rank': 8,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/telegram'},
#  {'Plugin Name': 'Facebook Lead Ads',
#   'Rank': 9,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-lead-ads'},
#  {'Plugin Name': 'Google Calendar',
#   'Rank': 10,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/google-calendar'},
#  {'Plugin Name': 'Google Docs',
#   'Rank': 11,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-docs'},
#  {'Plugin Name': 'Microsoft 365 Email',
#   'Rank': 12,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/microsoft-email'},
#  {'Plugin Name': 'Monday',
#   'Rank': 13,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/monday'},
#  {'Plugin Name': 'HubSpot CRM',
#   'Rank': 14,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/hubspotcrm'},
#  {'Plugin Name': 'ClickUp',
#   'Rank': 15,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/clickup'},
#  {'Plugin Name': 'Facebook Pages',
#   'Rank': 16,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-pages'},
#  {'Plugin Name': 'Discord',
#   'Rank': 17,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/discord'},
#  {'Plugin Name': 'Instagram for Business',
#   'Rank': 18,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/instagram-business'},
#  {'Plugin Name': 'Webflow',
#   'Rank': 19,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/webflow'},
#  {'Plugin Name': 'WooCommerce',
#   'Rank': 20,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/woocommerce'},
#  {'Plugin Name': 'Pipedrive CRM',
#   'Rank': 21,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/pipedrive'},
#  {'Plugin Name': 'Shopify',
#   'Rank': 22,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/shopify'},
#  {'Plugin Name': 'Trello',
#   'Rank': 23,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/trello'},
#  {'Plugin Name': 'WordPress',
#   'Rank': 24,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/wordpress'},
#  {'Plugin Name': 'Dropbox',
#   'Rank': 25,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/dropbox'},
#  {'Plugin Name': 'Stripe',
#   'Rank': 26,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/stripe'},
#  {'Plugin Name': 'ActiveCampaign',
#   'Rank': 27,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/activecampaign'},
#  {'Plugin Name': 'Brevo',
#   'Rank': 28,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendinblue'},
#  {'Plugin Name': 'Calendly',
#   'Rank': 29,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/calendly'},
#  {'Plugin Name': 'Google Forms',
#   'Rank': 30,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/google-forms'},
#  {'Plugin Name': 'Mailchimp',
#   'Rank': 31,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailchimp'},
#  {'Plugin Name': 'Microsoft 365 Excel',
#   'Rank': 32,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/microsoft-excel'},
#  {'Plugin Name': 'Google Contacts',
#   'Rank': 33,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/google-contacts'},
#  {'Plugin Name': 'Jotform',
#   'Rank': 34,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/jotform'},
#  {'Plugin Name': 'Typeform',
#   'Rank': 35,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/typeform'},
#  {'Plugin Name': 'Tally',
#   'Rank': 36,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/tally'},
#  {'Plugin Name': 'Salesforce',
#   'Rank': 37,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/salesforce'},
#  {'Plugin Name': 'Twilio',
#   'Rank': 38,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/twilio'},
#  {'Plugin Name': 'OneDrive',
#   'Rank': 39,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/onedrive'},
#  {'Plugin Name': 'LinkedIn',
#   'Rank': 40,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/linkedin'},
#  {'Plugin Name': 'LINE',
#   'Rank': 41,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/line'},
#  {'Plugin Name': 'MySQL',
#   'Rank': 42,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/mysql'},
#  {'Plugin Name': 'Asana',
#   'Rank': 43,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/asana'},
#  {'Plugin Name': 'SendGrid',
#   'Rank': 44,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendgrid'},
#  {'Plugin Name': 'Make',
#   'Rank': 45,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/make'},
#  {'Plugin Name': 'X (formerly Twitter)',
#   'Rank': 46,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/twitter'},
#  {'Plugin Name': 'Xero',
#   'Rank': 47,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/xero'},
#  {'Plugin Name': 'Todoist',
#   'Rank': 48,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/todoist'},
#  {'Plugin Name': 'Manychat',
#   'Rank': 49,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/manychat'},
#  {'Plugin Name': 'QuickBooks',
#   'Rank': 50,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/quickbooks'},
#  {'Plugin Name': 'PDF.co',
#   'Rank': 51,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdf-co'},
#  {'Plugin Name': 'Survey123',
#   'Rank': 52,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/survey123'},
#  {'Plugin Name': 'HighLevel LeadConnector',
#   'Rank': 53,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/highlevel'},
#  {'Plugin Name': 'Zoom',
#   'Rank': 54,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/zoom'},
#  {'Plugin Name': 'CloudConvert',
#   'Rank': 55,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/cloudconvert'},
#  {'Plugin Name': 'Jira Cloud Platform',
#   'Rank': 56,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/jira'},
#  {'Plugin Name': 'Zoho CRM',
#   'Rank': 57,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/zohocrm'},
#  {'Plugin Name': 'WhatsApp Business Cloud',
#   'Rank': 58,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/whatsapp-business-cloud'},
#  {'Plugin Name': 'Google Cloud Firestore',
#   'Rank': 59,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/google-cloud-firestore'},
#  {'Plugin Name': 'Microsoft 365 Calendar',
#   'Rank': 60,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/microsoft-calendar'},
#  {'Plugin Name': 'PandaDoc',
#   'Rank': 61,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pandadoc'},
#  {'Plugin Name': 'Facebook Insights',
#   'Rank': 62,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-insights'},
#  {'Plugin Name': 'MailerLite',
#   'Rank': 63,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailerlite2'},
#  {'Plugin Name': 'Google Maps',
#   'Rank': 64,
#   'Category': 'Travel',
#   'url': 'https://www.make.com/en/integrations/google-maps'},
#  {'Plugin Name': 'Google Slides',
#   'Rank': 65,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-slides'},
#  {'Plugin Name': 'Microsoft SharePoint Online',
#   'Rank': 66,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/microsoft-sharepoint'},
#  {'Plugin Name': 'Blogger',
#   'Rank': 67,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/blogger'},
#  {'Plugin Name': 'AWS S3',
#   'Rank': 68,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/aws-s3'},
#  {'Plugin Name': 'MailerLite Classic',
#   'Rank': 69,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailerlite'},
#  {'Plugin Name': 'Microsoft Word Templates',
#   'Rank': 70,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/docx-templater'},
#  {'Plugin Name': 'Bubble',
#   'Rank': 71,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/bubble'},
#  {'Plugin Name': 'Elementor',
#   'Rank': 72,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/elementor'},
#  {'Plugin Name': 'Printify',
#   'Rank': 73,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/printify'},
#  {'Plugin Name': 'PostgreSQL',
#   'Rank': 74,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/postgres'},
#  {'Plugin Name': 'Gravity Forms',
#   'Rank': 75,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/gravity-forms'},
#  {'Plugin Name': 'Z-API',
#   'Rank': 76,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/z-api'},
#  {'Plugin Name': 'Microsoft Teams',
#   'Rank': 77,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/microsoft-teams'},
#  {'Plugin Name': 'Klaviyo',
#   'Rank': 78,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/klaviyo'},
#  {'Plugin Name': 'Google Tasks',
#   'Rank': 79,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/google-tasks'},
#  {'Plugin Name': 'Contact Form 7',
#   'Rank': 80,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/contact-form-seven'},
#  {'Plugin Name': 'Bitly',
#   'Rank': 81,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/bitly'},
#  {'Plugin Name': 'Zendesk',
#   'Rank': 82,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/zendesk'},
#  {'Plugin Name': 'Facebook Conversions API',
#   'Rank': 83,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-conversions-api'},
#  {'Plugin Name': 'Ninox',
#   'Rank': 84,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/ninox'},
#  {'Plugin Name': 'Zapier',
#   'Rank': 85,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/zapier'},
#  {'Plugin Name': 'Buffer',
#   'Rank': 86,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/buffer'},
#  {'Plugin Name': 'BigQuery',
#   'Rank': 87,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/google-bigquery'},
#  {'Plugin Name': 'Facebook Custom Audiences',
#   'Rank': 88,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-custom-audiences'},
#  {'Plugin Name': 'Toggl Track',
#   'Rank': 89,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/toggl'},
#  {'Plugin Name': 'Cognito Forms',
#   'Rank': 90,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/cognitoforms'},
#  {'Plugin Name': 'Etsy',
#   'Rank': 91,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/etsy'},
#  {'Plugin Name': 'Microsoft SQL Server',
#   'Rank': 92,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/mssql'},
#  {'Plugin Name': 'Pinterest',
#   'Rank': 93,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/pinterest'},
#  {'Plugin Name': 'HTML/CSS to Image',
#   'Rank': 94,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/html-css-to-image'},
#  {'Plugin Name': 'Google Chat',
#   'Rank': 95,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/google-hangouts-chat'},
#  {'Plugin Name': 'Knack',
#   'Rank': 96,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/knack'},
#  {'Plugin Name': 'DocuSign',
#   'Rank': 97,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/docusign'},
#  {'Plugin Name': 'Twitch',
#   'Rank': 98,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/twitch'},
#  {'Plugin Name': 'Google Cloud Vision',
#   'Rank': 99,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/googlecloudvision'},
#  {'Plugin Name': 'Glide',
#   'Rank': 100,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/glide'},
#  {'Plugin Name': 'Mailgun',
#   'Rank': 101,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailgun'},
#  {'Plugin Name': 'Freshdesk',
#   'Rank': 102,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/freshdesk'},
#  {'Plugin Name': 'Spotify',
#   'Rank': 103,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/spotify'},
#  {'Plugin Name': 'ClickSend SMS',
#   'Rank': 104,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/clicksend'},
#  {'Plugin Name': 'RD Station',
#   'Rank': 105,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/rd-station'},
#  {'Plugin Name': 'Cuttly',
#   'Rank': 106,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/cuttly'},
#  {'Plugin Name': 'Coda',
#   'Rank': 107,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/coda'},
#  {'Plugin Name': 'Kommo',
#   'Rank': 108,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/amo-crm'},
#  {'Plugin Name': 'Bitrix24',
#   'Rank': 109,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/bitrix24'},
#  {'Plugin Name': 'Pipefy',
#   'Rank': 110,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/pipefy'},
#  {'Plugin Name': 'Short.io',
#   'Rank': 111,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/short-cm'},
#  {'Plugin Name': 'Microsoft To Do',
#   'Rank': 112,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/microsoft-to-do'},
#  {'Plugin Name': 'reddit',
#   'Rank': 113,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/reddit'},
#  {'Plugin Name': 'Clockify',
#   'Rank': 114,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/clockify'},
#  {'Plugin Name': 'SendPulse',
#   'Rank': 115,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendpulse'},
#  {'Plugin Name': 'Rav Messer / Responder',
#   'Rank': 116,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/rav-messer'},
#  {'Plugin Name': 'Google Workspace Admin',
#   'Rank': 117,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/google-g-suite'},
#  {'Plugin Name': 'Google Ads Conversions',
#   'Rank': 118,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-ads-conversions'},
#  {'Plugin Name': 'Google Analytics 4',
#   'Rank': 119,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/google-analytics-4'},
#  {'Plugin Name': '0CodeKit',
#   'Rank': 120,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/onesaas'},
#  {'Plugin Name': 'PayPal',
#   'Rank': 121,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/paypal'},
#  {'Plugin Name': 'lexoffice',
#   'Rank': 122,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/lexoffice'},
#  {'Plugin Name': 'Google Ads Campaign Management',
#   'Rank': 123,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-ads-campaign-management'},
#  {'Plugin Name': 'Acuity Scheduling',
#   'Rank': 124,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/acuity-scheduling'},
#  {'Plugin Name': 'Keap',
#   'Rank': 125,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/infusionsoft'},
#  {'Plugin Name': 'ConvertKit',
#   'Rank': 126,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/convertkit'},
#  {'Plugin Name': 'Memberstack',
#   'Rank': 127,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/memberstack'},
#  {'Plugin Name': 'Zoho Mail',
#   'Rank': 128,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/zoho-mail'},
#  {'Plugin Name': 'Mailjet',
#   'Rank': 129,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailjet'},
#  {'Plugin Name': 'Intercom',
#   'Rank': 130,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/intercom'},
#  {'Plugin Name': 'Apify',
#   'Rank': 131,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/apify'},
#  {'Plugin Name': 'PrestaShop',
#   'Rank': 132,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/prestashop'},
#  {'Plugin Name': 'Fireberry',
#   'Rank': 133,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/powerlink'},
#  {'Plugin Name': 'Close CRM',
#   'Rank': 134,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/close-crm'},
#  {'Plugin Name': 'PDFMonkey',
#   'Rank': 135,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdfmonkey'},
#  {'Plugin Name': 'LinkedIn Lead Gen Forms',
#   'Rank': 136,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/linkedin-lead-gen-forms'},
#  {'Plugin Name': 'Zoho Books',
#   'Rank': 137,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/zoho-books'},
#  {'Plugin Name': 'PhantomBuster',
#   'Rank': 138,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/phantombuster'},
#  {'Plugin Name': 'ElevenLabs',
#   'Rank': 139,
#   'Category': 'Ai',
#   'url': 'https://www.make.com/en/integrations/elevenlabs'},
#  {'Plugin Name': 'Eden AI',
#   'Rank': 140,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/edenai'},
#  {'Plugin Name': 'Cloudinary',
#   'Rank': 141,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/cloudinary'},
#  {'Plugin Name': 'Google My Business',
#   'Rank': 142,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-my-business'},
#  {'Plugin Name': 'DeepL',
#   'Rank': 143,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/deepl'},
#  {'Plugin Name': 'GitHub',
#   'Rank': 144,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/github'},
#  {'Plugin Name': 'Smoove',
#   'Rank': 145,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/smoove'},
#  {'Plugin Name': 'ShipStation',
#   'Rank': 146,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/shipstation'},
#  {'Plugin Name': 'Hotmart',
#   'Rank': 147,
#   'Category': 'Education',
#   'url': 'https://www.make.com/en/integrations/hotmart'},
#  {'Plugin Name': 'Instagram',
#   'Rank': 148,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/instagram'},
#  {'Plugin Name': 'Podio',
#   'Rank': 149,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/podio'},
#  {'Plugin Name': 'Google Cloud Storage',
#   'Rank': 150,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/google-cloud-storage'},
#  {'Plugin Name': 'Postmark',
#   'Rank': 151,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/postmark'},
#  {'Plugin Name': 'Harvest',
#   'Rank': 152,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/harvest'},
#  {'Plugin Name': 'iLovePDF',
#   'Rank': 153,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/ilovepdf'},
#  {'Plugin Name': 'Adalo',
#   'Rank': 154,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/adalo'},
#  {'Plugin Name': 'Paperform',
#   'Rank': 155,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/paperform'},
#  {'Plugin Name': 'Feedly',
#   'Rank': 156,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/feedly'},
#  {'Plugin Name': 'Google Groups',
#   'Rank': 157,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-groups'},
#  {'Plugin Name': 'Amazon Lambda',
#   'Rank': 158,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/amazon-lambda'},
#  {'Plugin Name': 'Tumblr',
#   'Rank': 159,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/tumblr'},
#  {'Plugin Name': 'ScrapingBee',
#   'Rank': 160,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/scrapingbee'},
#  {'Plugin Name': 'Evernote',
#   'Rank': 161,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/evernote'},
#  {'Plugin Name': 'DocuWare',
#   'Rank': 162,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/docuware'},
#  {'Plugin Name': 'Smartsheet',
#   'Rank': 163,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/smartsheet'},
#  {'Plugin Name': 'Google Translate',
#   'Rank': 164,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/google-translate'},
#  {'Plugin Name': 'Squarespace',
#   'Rank': 165,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/squarespace'},
#  {'Plugin Name': 'Qonto',
#   'Rank': 166,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/qonto'},
#  {'Plugin Name': 'Browse AI',
#   'Rank': 167,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/browse-ai'},
#  {'Plugin Name': 'TikTok',
#   'Rank': 168,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/tiktok'},
#  {'Plugin Name': 'Facebook Ads Campaign Management',
#   'Rank': 169,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-ads-cm'},
#  {'Plugin Name': 'Teamleader',
#   'Rank': 170,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/teamleader'},
#  {'Plugin Name': 'Google Ads Customer Match',
#   'Rank': 171,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-ads-customer-match'},
#  {'Plugin Name': 'Aircall',
#   'Rank': 172,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/aircall'},
#  {'Plugin Name': 'ClickFunnels',
#   'Rank': 173,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/click-funnels'},
#  {'Plugin Name': 'SoundCloud',
#   'Rank': 174,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/soundcloud'},
#  {'Plugin Name': 'RAYNET CRM',
#   'Rank': 175,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/raynetcrm'},
#  {'Plugin Name': 'Circle',
#   'Rank': 176,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/circle-so'},
#  {'Plugin Name': 'Wix',
#   'Rank': 177,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/wix'},
#  {'Plugin Name': 'Square',
#   'Rank': 178,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/square'},
#  {'Plugin Name': 'Box',
#   'Rank': 179,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/box'},
#  {'Plugin Name': 'CraftMyPDF.com',
#   'Rank': 180,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/craftmypdf-com'},
#  {'Plugin Name': 'APITemplate.io',
#   'Rank': 181,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/apitemplate-io'},
#  {'Plugin Name': 'mailparser.io',
#   'Rank': 182,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/mailparser-io'},
#  {'Plugin Name': 'PrintNode',
#   'Rank': 183,
#   'Category': 'Internet-Of-Things',
#   'url': 'https://www.make.com/en/integrations/printnode'},
#  {'Plugin Name': 'MailerSend',
#   'Rank': 184,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailersend'},
#  {'Plugin Name': 'eSignatures.io',
#   'Rank': 185,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/esignatures-io'},
#  {'Plugin Name': 'GetResponse',
#   'Rank': 186,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/getresponse'},
#  {'Plugin Name': 'Freshsales',
#   'Rank': 187,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/freshsales'},
#  {'Plugin Name': 'MongoDB',
#   'Rank': 188,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/mongodb'},
#  {'Plugin Name': 'IFTTT',
#   'Rank': 189,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/ifttt'},
#  {'Plugin Name': 'Eledo PDF',
#   'Rank': 190,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/eledo'},
#  {'Plugin Name': 'Strava',
#   'Rank': 191,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/strava'},
#  {'Plugin Name': 'Pocket',
#   'Rank': 192,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/pocket'},
#  {'Plugin Name': 'Google Photos',
#   'Rank': 193,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-photos'},
#  {'Plugin Name': 'Fakturoid',
#   'Rank': 194,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/fakturoid'},
#  {'Plugin Name': 'Softr',
#   'Rank': 195,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/softr'},
#  {'Plugin Name': 'Pushover',
#   'Rank': 196,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/pushover'},
#  {'Plugin Name': 'Apollo',
#   'Rank': 197,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/apollo'},
#  {'Plugin Name': 'SmartSuite',
#   'Rank': 198,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/smartsuite'},
#  {'Plugin Name': 'Eventbrite',
#   'Rank': 199,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/eventbrite'},
#  {'Plugin Name': 'lemlist',
#   'Rank': 200,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/lemlist'},
#  {'Plugin Name': 'Zoho Forms',
#   'Rank': 201,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/zoho-forms'},
#  {'Plugin Name': 'Wild Apricot',
#   'Rank': 202,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/wild-apricot'},
#  {'Plugin Name': 'Mautic',
#   'Rank': 203,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mautic'},
#  {'Plugin Name': 'Google Ads Lead Forms',
#   'Rank': 204,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-ads-lead-forms'},
#  {'Plugin Name': 'Facebook Messenger',
#   'Rank': 205,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/facebook-messenger'},
#  {'Plugin Name': 'Thinkific',
#   'Rank': 206,
#   'Category': 'Education',
#   'url': 'https://www.make.com/en/integrations/thinkific'},
#  {'Plugin Name': 'Odoo',
#   'Rank': 207,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/odoo'},
#  {'Plugin Name': 'Medium',
#   'Rank': 208,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/medium'},
#  {'Plugin Name': 'Chargebee',
#   'Rank': 209,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/chargebee'},
#  {'Plugin Name': 'WebinarJam',
#   'Rank': 210,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/webinarjam'},
#  {'Plugin Name': 'GitLab',
#   'Rank': 211,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/gitlab'},
#  {'Plugin Name': 'Vtiger CRM',
#   'Rank': 212,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/vtiger'},
#  {'Plugin Name': 'Morning',
#   'Rank': 213,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/morning'},
#  {'Plugin Name': 'Customer.io',
#   'Rank': 214,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/customer-io'},
#  {'Plugin Name': 'Fillout Forms',
#   'Rank': 215,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/fillout'},
#  {'Plugin Name': 'Wave',
#   'Rank': 216,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/wave'},
#  {'Plugin Name': 'RingCentral',
#   'Rank': 217,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/ringcentral'},
#  {'Plugin Name': 'ThriveCart',
#   'Rank': 218,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/thrivecart'},
#  {'Plugin Name': 'ScrapeNinja',
#   'Rank': 219,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/scrapeninja'},
#  {'Plugin Name': 'Basecamp 3',
#   'Rank': 220,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/basecamp3'},
#  {'Plugin Name': 'ChatGuru',
#   'Rank': 221,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/chatguru'},
#  {'Plugin Name': 'Zoho Invoice',
#   'Rank': 222,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/zoho-invoice'},
#  {'Plugin Name': 'beehiiv',
#   'Rank': 223,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/beehiiv'},
#  {'Plugin Name': 'Chatwork',
#   'Rank': 224,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chatwork'},
#  {'Plugin Name': 'Rebrandly',
#   'Rank': 225,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/rebrandly'},
#  {'Plugin Name': 'AWeber',
#   'Rank': 226,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/aweber'},
#  {'Plugin Name': 'Mixpanel',
#   'Rank': 227,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/mixpanel'},
#  {'Plugin Name': 'Google Chrome',
#   'Rank': 228,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chrome'},
#  {'Plugin Name': 'Nextcloud',
#   'Rank': 229,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/nextcloud'},
#  {'Plugin Name': 'Moneybird',
#   'Rank': 230,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/moneybird'},
#  {'Plugin Name': 'ArcGIS Field Maps',
#   'Rank': 231,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/arcgis-field-maps'},
#  {'Plugin Name': 'Responder.live',
#   'Rank': 232,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/responder-live'},
#  {'Plugin Name': 'Foursquare',
#   'Rank': 233,
#   'Category': 'Travel',
#   'url': 'https://www.make.com/en/integrations/foursquare'},
#  {'Plugin Name': 'tawk.to',
#   'Rank': 234,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/tawkto'},
#  {'Plugin Name': 'Bigin by Zoho CRM',
#   'Rank': 235,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/bigin-by-zoho'},
#  {'Plugin Name': 'Sellsy',
#   'Rank': 236,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/sellsy'},
#  {'Plugin Name': 'Custom JS',
#   'Rank': 237,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/custom-js'},
#  {'Plugin Name': 'ActiveTrail',
#   'Rank': 238,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/activetrail'},
#  {'Plugin Name': 'Zoho Creator',
#   'Rank': 239,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/zoho-creator'},
#  {'Plugin Name': 'Tripetto',
#   'Rank': 240,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/tripetto'},
#  {'Plugin Name': 'Microsoft 365 People',
#   'Rank': 241,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/microsoft-people'},
#  {'Plugin Name': 'ZeroBounce',
#   'Rank': 242,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/zerobounce'},
#  {'Plugin Name': 'WPForms',
#   'Rank': 243,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/wpforms'},
#  {'Plugin Name': 'Adobe Commerce',
#   'Rank': 244,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/magento2'},
#  {'Plugin Name': 'Help Scout',
#   'Rank': 245,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/helpscout'},
#  {'Plugin Name': 'Unbounce',
#   'Rank': 246,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/unbounce'},
#  {'Plugin Name': 'Fio banka',
#   'Rank': 247,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/fio'},
#  {'Plugin Name': 'Amazon SES',
#   'Rank': 248,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/amazon-ses'},
#  {'Plugin Name': 'Amazon Seller Central',
#   'Rank': 249,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/amazon-seller-central'},
#  {'Plugin Name': 'Asaas',
#   'Rank': 250,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/asaas'},
#  {'Plugin Name': 'Placid',
#   'Rank': 251,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/placid-app'},
#  {'Plugin Name': 'Ghost',
#   'Rank': 252,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/ghost'},
#  {'Plugin Name': 'Raindrop.io',
#   'Rank': 253,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/raindrop-io'},
#  {'Plugin Name': 'Shortcuts',
#   'Rank': 254,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/shortcuts'},
#  {'Plugin Name': 'Inoreader',
#   'Rank': 255,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/inoreader'},
#  {'Plugin Name': 'Front',
#   'Rank': 256,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/front'},
#  {'Plugin Name': 'Constant Contact',
#   'Rank': 257,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/constant-contact'},
#  {'Plugin Name': 'Drip',
#   'Rank': 258,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/drip'},
#  {'Plugin Name': 'Follow Up Boss',
#   'Rank': 259,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/follow-up-boss'},
#  {'Plugin Name': 'bexio',
#   'Rank': 260,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/bexio'},
#  {'Plugin Name': 'Bannerbear',
#   'Rank': 261,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/bannerbear'},
#  {'Plugin Name': 'Ecomail.cz',
#   'Rank': 262,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/ecomail-cz'},
#  {'Plugin Name': 'WP Webhooks',
#   'Rank': 263,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/wp-webhooks'},
#  {'Plugin Name': 'Unsplash',
#   'Rank': 264,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/unsplash'},
#  {'Plugin Name': 'Teamwork',
#   'Rank': 265,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/teamwork'},
#  {'Plugin Name': 'Microsoft Power BI',
#   'Rank': 266,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/microsoft-power-bi'},
#  {'Plugin Name': 'Zoho Desk',
#   'Rank': 267,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/zoho-desk'},
#  {'Plugin Name': 'Google Cloud Text-to-Speech',
#   'Rank': 268,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-cloud-tts'},
#  {'Plugin Name': 'sevDesk',
#   'Rank': 269,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/sevdesk'},
#  {'Plugin Name': 'VideoAsk',
#   'Rank': 270,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/videoask'},
#  {'Plugin Name': 'Kintone',
#   'Rank': 271,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/kintone'},
#  {'Plugin Name': 'Docparser',
#   'Rank': 272,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/docparser'},
#  {'Plugin Name': 'GIPHY',
#   'Rank': 273,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/giphy'},
#  {'Plugin Name': 'BambooHR',
#   'Rank': 274,
#   'Category': 'Hr-Management',
#   'url': 'https://www.make.com/en/integrations/bamboohr'},
#  {'Plugin Name': 'Moskit CRM',
#   'Rank': 275,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/moskitcrm'},
#  {'Plugin Name': 'Mailchimp Transactional Email',
#   'Rank': 276,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/mailchimp-transactional-email'},
#  {'Plugin Name': 'ImgBB',
#   'Rank': 277,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/imgbb'},
#  {'Plugin Name': 'Snowflake',
#   'Rank': 278,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/snowflake'},
#  {'Plugin Name': 'Mastodon',
#   'Rank': 279,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mastodon'},
#  {'Plugin Name': 'Frame.io',
#   'Rank': 280,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/frame-io'},
#  {'Plugin Name': 'ConvertAPI',
#   'Rank': 281,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/convertapi'},
#  {'Plugin Name': 'Beds24',
#   'Rank': 282,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/beds24'},
#  {'Plugin Name': 'Zoho Campaigns',
#   'Rank': 283,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/zoho-campaigns'},
#  {'Plugin Name': 'Teachable',
#   'Rank': 284,
#   'Category': 'Education',
#   'url': 'https://www.make.com/en/integrations/teachable'},
#  {'Plugin Name': 'Invoice Ninja',
#   'Rank': 285,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/invoiceninja'},
#  {'Plugin Name': 'Docupilot',
#   'Rank': 286,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/docupilot'},
#  {'Plugin Name': 'Documint',
#   'Rank': 287,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/documint'},
#  {'Plugin Name': 'AppSheet',
#   'Rank': 288,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/appsheet'},
#  {'Plugin Name': 'Linear',
#   'Rank': 289,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/linear'},
#  {'Plugin Name': 'EverWebinar',
#   'Rank': 290,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/everwebinar'},
#  {'Plugin Name': 'Typebot',
#   'Rank': 291,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/typebot'},
#  {'Plugin Name': 'Survey Monkey',
#   'Rank': 292,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/survey-monkey'},
#  {'Plugin Name': 'Sendcloud',
#   'Rank': 293,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/sendcloud'},
#  {'Plugin Name': 'Vimeo',
#   'Rank': 294,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/vimeo'},
#  {'Plugin Name': 'Pushbullet',
#   'Rank': 295,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/pushbullet'},
#  {'Plugin Name': 'PDF4me',
#   'Rank': 296,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdf4me'},
#  {'Plugin Name': 'Google Meet',
#   'Rank': 297,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/google-meet'},
#  {'Plugin Name': 'ABRA FlexiBee',
#   'Rank': 298,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/flexibee'},
#  {'Plugin Name': 'Tny',
#   'Rank': 299,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/tny'},
#  {'Plugin Name': 'SmartEmailing',
#   'Rank': 300,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/smart-emailing'},
#  {'Plugin Name': 'SendFox',
#   'Rank': 301,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendfox'},
#  {'Plugin Name': 'InforUMobile',
#   'Rank': 302,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/inforumobile'},
#  {'Plugin Name': 'Sendy',
#   'Rank': 303,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendy'},
#  {'Plugin Name': 'Missive',
#   'Rank': 304,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/missive'},
#  {'Plugin Name': 'EmailOctopus',
#   'Rank': 305,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/email-octopus'},
#  {'Plugin Name': 'Zoho Inventory',
#   'Rank': 306,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/zoho-inventory'},
#  {'Plugin Name': 'Miro',
#   'Rank': 307,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/miro'},
#  {'Plugin Name': 'NinjaForms',
#   'Rank': 308,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/ninja-forms'},
#  {'Plugin Name': 'GatewayAPI SMS',
#   'Rank': 309,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/gatewayapi'},
#  {'Plugin Name': 'CoinMarketCap',
#   'Rank': 310,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/coinmarketcap'},
#  {'Plugin Name': 'YouTube',
#   'Rank': 311,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/youtube'},
#  {'Plugin Name': 'YNAB',
#   'Rank': 312,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/ynab'},
#  {'Plugin Name': 'PDF Generator API',
#   'Rank': 313,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdf-generator-api'},
#  {'Plugin Name': 'OpenWeatherMap',
#   'Rank': 314,
#   'Category': 'Travel',
#   'url': 'https://www.make.com/en/integrations/openweathermap'},
#  {'Plugin Name': 'Tabidoo',
#   'Rank': 315,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/tabidoo'},
#  {'Plugin Name': 'MOCO',
#   'Rank': 316,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/moco'},
#  {'Plugin Name': 'SignRequest',
#   'Rank': 317,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/signrequest'},
#  {'Plugin Name': 'Segment',
#   'Rank': 318,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/segment'},
#  {'Plugin Name': 'pdfFiller',
#   'Rank': 319,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdffiller'},
#  {'Plugin Name': 'Mattermost',
#   'Rank': 320,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/mattermost'},
#  {'Plugin Name': 'Habitica',
#   'Rank': 321,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/habitica'},
#  {'Plugin Name': 'Gumroad',
#   'Rank': 322,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/gumroad'},
#  {'Plugin Name': 'FluentCRM',
#   'Rank': 323,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/fluentcrm'},
#  {'Plugin Name': 'SMSAPI',
#   'Rank': 324,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/smsapi'},
#  {'Plugin Name': 'Livestorm',
#   'Rank': 325,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/livestorm'},
#  {'Plugin Name': 'easybill',
#   'Rank': 326,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/easybill'},
#  {'Plugin Name': 'Respond.io',
#   'Rank': 327,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/respond-io'},
#  {'Plugin Name': 'OneSignal',
#   'Rank': 328,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/onesignal'},
#  {'Plugin Name': 'OneNote',
#   'Rank': 329,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/onenote'},
#  {'Plugin Name': 'Axonaut',
#   'Rank': 330,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/axonaut'},
#  {'Plugin Name': 'Wrike',
#   'Rank': 331,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/wrike'},
#  {'Plugin Name': 'OnceHub',
#   'Rank': 332,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/scheduleonce'},
#  {'Plugin Name': 'Katana Cloud Inventory',
#   'Rank': 333,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/katana-mrp'},
#  {'Plugin Name': 'Snov.io',
#   'Rank': 334,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/snovio'},
#  {'Plugin Name': 'SeaTable',
#   'Rank': 335,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/seatable'},
#  {'Plugin Name': 'JustCall',
#   'Rank': 336,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/justcall'},
#  {'Plugin Name': 'Cloudflare',
#   'Rank': 337,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/cloudflare'},
#  {'Plugin Name': 'Chatbase',
#   'Rank': 338,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chatbase'},
#  {'Plugin Name': 'Streak',
#   'Rank': 339,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/streak'},
#  {'Plugin Name': 'BaseLinker',
#   'Rank': 340,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/baselinker'},
#  {'Plugin Name': 'Skloňování Jmen',
#   'Rank': 341,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/sklonovani-jmen'},
#  {'Plugin Name': 'Kartra',
#   'Rank': 342,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/kartra'},
#  {'Plugin Name': 'CleverReach',
#   'Rank': 343,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/cleverreach'},
#  {'Plugin Name': 'ZapSign',
#   'Rank': 344,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/zapsign'},
#  {'Plugin Name': 'SuperSaaS',
#   'Rank': 345,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/supersaas'},
#  {'Plugin Name': 'Salla',
#   'Rank': 346,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/salla'},
#  {'Plugin Name': 'apaleo',
#   'Rank': 347,
#   'Category': 'Travel',
#   'url': 'https://www.make.com/en/integrations/apaleo'},
#  {'Plugin Name': 'TextMagic',
#   'Rank': 348,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/textmagic'},
#  {'Plugin Name': 'Convertio',
#   'Rank': 349,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/convertio'},
# ...
#   'Rank': 884,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/prefinery'},
#  {'Plugin Name': 'Plumsail Documents',
#   'Rank': 885,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/plumsail-documents'},
#  {'Plugin Name': 'Pinboard',
#   'Rank': 886,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/pinboard'},
#  {'Plugin Name': 'Pastebin',
#   'Rank': 887,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pastebin'},
#  {'Plugin Name': 'Onoff Business',
#   'Rank': 888,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/onoff-business'},
#  {'Plugin Name': 'Nusii',
#   'Rank': 889,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/nusii'},
#  {'Plugin Name': 'Nozbe Teams',
#   'Rank': 890,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/nozbe-teams'},
#  {'Plugin Name': 'Moxie',
#   'Rank': 891,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/moxie'},
#  {'Plugin Name': 'Mitto SMS',
#   'Rank': 892,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/mitto-sms'},
#  {'Plugin Name': 'Metabase',
#   'Rank': 893,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/metabase'},
#  {'Plugin Name': 'LinkedIn Offline Conversions',
#   'Rank': 894,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/linkedin-offline-conversions'},
#  {'Plugin Name': 'LearningSuite',
#   'Rank': 895,
#   'Category': 'Education',
#   'url': 'https://www.make.com/en/integrations/learningsuite'},
#  {'Plugin Name': 'Leady',
#   'Rank': 896,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/leady'},
#  {'Plugin Name': 'LeadSquared',
#   'Rank': 897,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/leadsquared'},
#  {'Plugin Name': 'KissFlow',
#   'Rank': 898,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/kissflow'},
#  {'Plugin Name': 'JW Player',
#   'Rank': 899,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/jw-player'},
#  {'Plugin Name': 'Jenkins',
#   'Rank': 900,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/jenkins'},
#  {'Plugin Name': 'involve.me',
#   'Rank': 901,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/involve-me'},
#  {'Plugin Name': 'Invoiced',
#   'Rank': 902,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/invoiced'},
#  {'Plugin Name': 'Infinity',
#   'Rank': 903,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/infinity'},
#  {'Plugin Name': 'Hive',
#   'Rank': 904,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/hive'},
#  {'Plugin Name': 'Hireflix',
#   'Rank': 905,
#   'Category': 'Hr-Management',
#   'url': 'https://www.make.com/en/integrations/hireflix'},
#  {'Plugin Name': 'HERO Software für Handwerker',
#   'Rank': 906,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/hero-software'},
#  {'Plugin Name': 'HappyFox Help Desk',
#   'Rank': 907,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/happyfox-help-desk'},
#  {'Plugin Name': 'Groove',
#   'Rank': 908,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/groove'},
#  {'Plugin Name': 'Grist',
#   'Rank': 909,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/grist'},
#  {'Plugin Name': 'Greenhouse Recruiting',
#   'Rank': 910,
#   'Category': 'Hr-Management',
#   'url': 'https://www.make.com/en/integrations/greenhouse'},
#  {'Plugin Name': 'GoodBarber eCommerce',
#   'Rank': 911,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/goodbarber-ecommerce'},
#  {'Plugin Name': 'Freshmail',
#   'Rank': 912,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/freshmail'},
#  {'Plugin Name': 'Formspree',
#   'Rank': 913,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/formspree'},
#  {'Plugin Name': 'Endorsal',
#   'Rank': 914,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/endorsal'},
#  {'Plugin Name': 'Emma',
#   'Rank': 915,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/emma'},
#  {'Plugin Name': 'Drift',
#   'Rank': 916,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/drift'},
#  {'Plugin Name': 'Customerly',
#   'Rank': 917,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/customerly'},
#  {'Plugin Name': 'Clust',
#   'Rank': 918,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/clust'},
#  {'Plugin Name': 'Chatra',
#   'Rank': 919,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chatra'},
#  {'Plugin Name': 'ChatBot',
#   'Rank': 920,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chatbot'},
#  {'Plugin Name': 'BlockSurvey',
#   'Rank': 921,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/blocksurvey'},
#  {'Plugin Name': 'BigMailer',
#   'Rank': 922,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/bigmailer'},
#  {'Plugin Name': 'Bannerbite',
#   'Rank': 923,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/bannerbite'},
#  {'Plugin Name': 'Avochato',
#   'Rank': 924,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/avochato'},
#  {'Plugin Name': 'ArtiBot.ai',
#   'Rank': 925,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/artibot-ai'},
#  {'Plugin Name': 'FastBill',
#   'Rank': 926,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/fastbill'},
#  {'Plugin Name': 'Bullhorn API',
#   'Rank': 927,
#   'Category': 'Hr-Management',
#   'url': 'https://www.make.com/en/integrations/bullhorn-api'},
#  {'Plugin Name': 'Oblio.eu Facturare',
#   'Rank': 928,
#   'Category': 'Other',
#   'url': 'https://www.make.com/en/integrations/oblio.eu-facturare'},
#  {'Plugin Name': 'Relevance AI',
#   'Rank': 929,
#   'Category': 'Ai',
#   'url': 'https://www.make.com/en/integrations/relevance-ai'},
#  {'Plugin Name': 'Exact Online',
#   'Rank': 930,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/exact-online'},
#  {'Plugin Name': 'Zulip',
#   'Rank': 931,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/zulip'},
#  {'Plugin Name': 'Yandex.Translate',
#   'Rank': 932,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/yandex-translate'},
#  {'Plugin Name': 'WP All Import',
#   'Rank': 933,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/wp-all-import'},
#  {'Plugin Name': 'WiziShop',
#   'Rank': 934,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/wizishop'},
#  {'Plugin Name': 'WaiverFile',
#   'Rank': 935,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/waiverfile'},
#  {'Plugin Name': 'Visma eAccounting',
#   'Rank': 936,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/visma-eaccounting'},
#  {'Plugin Name': 'Vend',
#   'Rank': 937,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/vend'},
#  {'Plugin Name': 'Trustpilot',
#   'Rank': 938,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/trustpilot'},
#  {'Plugin Name': 'Toodledo',
#   'Rank': 939,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/toodledo'},
#  {'Plugin Name': 'Toggl Plan',
#   'Rank': 940,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/toggl-plan'},
#  {'Plugin Name': 'Timing',
#   'Rank': 941,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/timing'},
#  {'Plugin Name': 'The Keys',
#   'Rank': 942,
#   'Category': 'Internet-Of-Things',
#   'url': 'https://www.make.com/en/integrations/the-keys'},
#  {'Plugin Name': 'Temi',
#   'Rank': 943,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/temi'},
#  {'Plugin Name': 'TeamViewer',
#   'Rank': 944,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/teamviewer'},
#  {'Plugin Name': 'Survicate',
#   'Rank': 945,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/survicate'},
#  {'Plugin Name': 'SugarCRM 7/8',
#   'Rank': 946,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/sugarcrm7'},
#  {'Plugin Name': 'Stencil',
#   'Rank': 947,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/stencil'},
#  {'Plugin Name': 'Stamped.io',
#   'Rank': 948,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/stamped'},
#  {'Plugin Name': 'SocialBee',
#   'Rank': 949,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/socialbee'},
#  {'Plugin Name': 'Snipcart',
#   'Rank': 950,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/snipcart'},
#  {'Plugin Name': 'SMSC',
#   'Rank': 951,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/smsc'},
#  {'Plugin Name': 'Smith.ai',
#   'Rank': 952,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/smith-ai'},
#  {'Plugin Name': 'SlickText',
#   'Rank': 953,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/slicktext'},
#  {'Plugin Name': 'Site Search 360',
#   'Rank': 954,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/site-search-360'},
#  {'Plugin Name': 'SigParser',
#   'Rank': 955,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/sigparser'},
#  {'Plugin Name': 'Shift4Shop',
#   'Rank': 956,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/a3dcart'},
#  {'Plugin Name': 'Scrive eSign',
#   'Rank': 957,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/scrive'},
#  {'Plugin Name': 'ScanOrders',
#   'Rank': 958,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/scanorders'},
#  {'Plugin Name': 'Retable',
#   'Rank': 959,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/retable'},
#  {'Plugin Name': 'Relatel',
#   'Rank': 960,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/relatel'},
#  {'Plugin Name': 'Quable PIM',
#   'Rank': 961,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/quable-pim'},
#  {'Plugin Name': 'Product Hunt',
#   'Rank': 962,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/product-hunt'},
#  {'Plugin Name': 'PracticePanther',
#   'Rank': 963,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/practicepanther'},
#  {'Plugin Name': 'Planyo',
#   'Rank': 964,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/planyo'},
#  {'Plugin Name': 'Paperless.io',
#   'Rank': 965,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/paperless-io'},
#  {'Plugin Name': 'Outreach',
#   'Rank': 966,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/outreach'},
#  {'Plugin Name': 'Nuelink',
#   'Rank': 967,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/nuelink'},
#  {'Plugin Name': 'MoreApp Forms',
#   'Rank': 968,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/moreapp-forms'},
#  {'Plugin Name': 'Mallabe Websites',
#   'Rank': 969,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/mallabe-websites'},
#  {'Plugin Name': 'MakeForms',
#   'Rank': 970,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/make-forms'},
#  {'Plugin Name': 'Mailshake',
#   'Rank': 971,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailshake'},
#  {'Plugin Name': 'Luxafor',
#   'Rank': 972,
#   'Category': 'Internet-Of-Things',
#   'url': 'https://www.make.com/en/integrations/luxafor'},
#  {'Plugin Name': 'LiveChat',
#   'Rank': 973,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/livechat'},
#  {'Plugin Name': 'Komerční banka',
#   'Rank': 974,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/komercni-banka'},
#  {'Plugin Name': 'Jitbit',
#   'Rank': 975,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/jitbit'},
#  {'Plugin Name': 'Iteration X',
#   'Rank': 976,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/iteration-x'},
#  {'Plugin Name': 'Invision Community',
#   'Rank': 977,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/invision-community'},
#  {'Plugin Name': 'Humanitix',
#   'Rank': 978,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/humanitix'},
#  {'Plugin Name': 'Gong',
#   'Rank': 979,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/gong'},
#  {'Plugin Name': 'GoCanvas',
#   'Rank': 980,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/gocanvas'},
#  {'Plugin Name': 'Go4Clients',
#   'Rank': 981,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/go4clients'},
#  {'Plugin Name': 'GetProspect',
#   'Rank': 982,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/getprospect'},
#  {'Plugin Name': 'FileCloud',
#   'Rank': 983,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/filecloud'},
#  {'Plugin Name': 'Disqus',
#   'Rank': 984,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/disqus'},
#  {'Plugin Name': 'Demodesk',
#   'Rank': 985,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/demodesk'},
#  {'Plugin Name': 'Custify',
#   'Rank': 986,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/custify'},
#  {'Plugin Name': 'Clickatell',
#   'Rank': 987,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/clickatell'},
#  {'Plugin Name': 'cituro',
#   'Rank': 988,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/cituro'},
#  {'Plugin Name': 'Captivate',
#   'Rank': 989,
#   'Category': 'Other',
#   'url': 'https://www.make.com/en/integrations/captivate'},
#  {'Plugin Name': 'Brave',
#   'Rank': 990,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/getbrave-io'},
#  {'Plugin Name': 'Basecamp 2',
#   'Rank': 991,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/basecamp'},
#  {'Plugin Name': 'Axiom',
#   'Rank': 992,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/axiom'},
#  {'Plugin Name': 'Avaza',
#   'Rank': 993,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/avaza'},
#  {'Plugin Name': 'Aurora Solar',
#   'Rank': 994,
#   'Category': 'Other',
#   'url': 'https://www.make.com/en/integrations/aurora-solar'},
#  {'Plugin Name': 'ApuTime',
#   'Rank': 995,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/aputime'},
#  {'Plugin Name': 'AgilePlace',
#   'Rank': 996,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/agileplace'},
#  {'Plugin Name': 'AdRoll',
#   'Rank': 997,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/adroll'},
#  {'Plugin Name': '4leads',
#   'Rank': 998,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/four-leads'},
#  {'Plugin Name': 'Copy.AI',
#   'Rank': 999,
#   'Category': 'Ai',
#   'url': 'https://www.make.com/en/integrations/copy.ai'},
#  {'Plugin Name': 'ZenRows',
#   'Rank': 1000,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/zenrows'},
#  ...]

# %%
url = final[0]['url']

# %%
for i in entities:
    print("https://www.make.com/en/integrations/" + i['slug'])
# Out:
# https://www.make.com/en/integrations/google-sheets
# https://www.make.com/en/integrations/google-email
# https://www.make.com/en/integrations/airtable
# https://www.make.com/en/integrations/openai-gpt-3
# https://www.make.com/en/integrations/google-drive
# https://www.make.com/en/integrations/notion
# https://www.make.com/en/integrations/slack
# https://www.make.com/en/integrations/telegram
# https://www.make.com/en/integrations/facebook-lead-ads
# https://www.make.com/en/integrations/google-calendar
# https://www.make.com/en/integrations/google-docs
# https://www.make.com/en/integrations/microsoft-email
# https://www.make.com/en/integrations/monday
# https://www.make.com/en/integrations/hubspotcrm
# https://www.make.com/en/integrations/clickup
# https://www.make.com/en/integrations/facebook-pages
# https://www.make.com/en/integrations/discord
# https://www.make.com/en/integrations/instagram-business
# https://www.make.com/en/integrations/webflow
# https://www.make.com/en/integrations/woocommerce
# https://www.make.com/en/integrations/pipedrive
# https://www.make.com/en/integrations/shopify
# https://www.make.com/en/integrations/trello
# https://www.make.com/en/integrations/wordpress
# https://www.make.com/en/integrations/dropbox
# https://www.make.com/en/integrations/stripe
# https://www.make.com/en/integrations/activecampaign
# https://www.make.com/en/integrations/sendinblue
# https://www.make.com/en/integrations/calendly
# https://www.make.com/en/integrations/google-forms
# https://www.make.com/en/integrations/mailchimp
# https://www.make.com/en/integrations/microsoft-excel
# https://www.make.com/en/integrations/google-contacts
# https://www.make.com/en/integrations/jotform
# https://www.make.com/en/integrations/typeform
# https://www.make.com/en/integrations/tally
# https://www.make.com/en/integrations/salesforce
# https://www.make.com/en/integrations/twilio
# https://www.make.com/en/integrations/onedrive
# https://www.make.com/en/integrations/linkedin
# https://www.make.com/en/integrations/line
# https://www.make.com/en/integrations/mysql
# https://www.make.com/en/integrations/asana
# https://www.make.com/en/integrations/sendgrid
# https://www.make.com/en/integrations/make
# https://www.make.com/en/integrations/twitter
# https://www.make.com/en/integrations/xero
# https://www.make.com/en/integrations/todoist
# https://www.make.com/en/integrations/manychat
# https://www.make.com/en/integrations/quickbooks
# https://www.make.com/en/integrations/pdf-co
# https://www.make.com/en/integrations/survey123
# https://www.make.com/en/integrations/highlevel
# https://www.make.com/en/integrations/zoom
# https://www.make.com/en/integrations/cloudconvert
# https://www.make.com/en/integrations/jira
# https://www.make.com/en/integrations/zohocrm
# https://www.make.com/en/integrations/whatsapp-business-cloud
# https://www.make.com/en/integrations/google-cloud-firestore
# https://www.make.com/en/integrations/microsoft-calendar
# https://www.make.com/en/integrations/pandadoc
# https://www.make.com/en/integrations/facebook-insights
# https://www.make.com/en/integrations/mailerlite2
# https://www.make.com/en/integrations/google-maps
# https://www.make.com/en/integrations/google-slides
# https://www.make.com/en/integrations/microsoft-sharepoint
# https://www.make.com/en/integrations/blogger
# https://www.make.com/en/integrations/aws-s3
# https://www.make.com/en/integrations/mailerlite
# https://www.make.com/en/integrations/docx-templater
# https://www.make.com/en/integrations/bubble
# https://www.make.com/en/integrations/elementor
# https://www.make.com/en/integrations/printify
# https://www.make.com/en/integrations/postgres
# https://www.make.com/en/integrations/gravity-forms
# https://www.make.com/en/integrations/z-api
# https://www.make.com/en/integrations/microsoft-teams
# https://www.make.com/en/integrations/klaviyo
# https://www.make.com/en/integrations/google-tasks
# https://www.make.com/en/integrations/contact-form-seven
# https://www.make.com/en/integrations/bitly
# https://www.make.com/en/integrations/zendesk
# https://www.make.com/en/integrations/facebook-conversions-api
# https://www.make.com/en/integrations/ninox
# https://www.make.com/en/integrations/zapier
# https://www.make.com/en/integrations/buffer
# https://www.make.com/en/integrations/google-bigquery
# https://www.make.com/en/integrations/facebook-custom-audiences
# https://www.make.com/en/integrations/toggl
# https://www.make.com/en/integrations/cognitoforms
# https://www.make.com/en/integrations/etsy
# https://www.make.com/en/integrations/mssql
# https://www.make.com/en/integrations/pinterest
# https://www.make.com/en/integrations/html-css-to-image
# https://www.make.com/en/integrations/google-hangouts-chat
# https://www.make.com/en/integrations/knack
# https://www.make.com/en/integrations/docusign
# https://www.make.com/en/integrations/twitch
# https://www.make.com/en/integrations/googlecloudvision
# https://www.make.com/en/integrations/glide
# https://www.make.com/en/integrations/mailgun
# https://www.make.com/en/integrations/freshdesk
# https://www.make.com/en/integrations/spotify
# https://www.make.com/en/integrations/clicksend
# https://www.make.com/en/integrations/rd-station
# https://www.make.com/en/integrations/cuttly
# https://www.make.com/en/integrations/coda
# https://www.make.com/en/integrations/amo-crm
# https://www.make.com/en/integrations/bitrix24
# https://www.make.com/en/integrations/pipefy
# https://www.make.com/en/integrations/short-cm
# https://www.make.com/en/integrations/microsoft-to-do
# https://www.make.com/en/integrations/reddit
# https://www.make.com/en/integrations/clockify
# https://www.make.com/en/integrations/sendpulse
# https://www.make.com/en/integrations/rav-messer
# https://www.make.com/en/integrations/google-g-suite
# https://www.make.com/en/integrations/google-ads-conversions
# https://www.make.com/en/integrations/google-analytics-4
# https://www.make.com/en/integrations/onesaas
# https://www.make.com/en/integrations/paypal
# https://www.make.com/en/integrations/lexoffice
# https://www.make.com/en/integrations/google-ads-campaign-management
# https://www.make.com/en/integrations/acuity-scheduling
# https://www.make.com/en/integrations/infusionsoft
# https://www.make.com/en/integrations/convertkit
# https://www.make.com/en/integrations/memberstack
# https://www.make.com/en/integrations/zoho-mail
# https://www.make.com/en/integrations/mailjet
# https://www.make.com/en/integrations/intercom
# https://www.make.com/en/integrations/apify
# https://www.make.com/en/integrations/prestashop
# https://www.make.com/en/integrations/powerlink
# https://www.make.com/en/integrations/close-crm
# https://www.make.com/en/integrations/pdfmonkey
# https://www.make.com/en/integrations/linkedin-lead-gen-forms
# https://www.make.com/en/integrations/zoho-books
# https://www.make.com/en/integrations/phantombuster
# https://www.make.com/en/integrations/elevenlabs
# https://www.make.com/en/integrations/edenai
# https://www.make.com/en/integrations/cloudinary
# https://www.make.com/en/integrations/google-my-business
# https://www.make.com/en/integrations/deepl
# https://www.make.com/en/integrations/github
# https://www.make.com/en/integrations/smoove
# https://www.make.com/en/integrations/shipstation
# https://www.make.com/en/integrations/hotmart
# https://www.make.com/en/integrations/instagram
# https://www.make.com/en/integrations/podio
# https://www.make.com/en/integrations/google-cloud-storage
# https://www.make.com/en/integrations/postmark
# https://www.make.com/en/integrations/harvest
# https://www.make.com/en/integrations/ilovepdf
# https://www.make.com/en/integrations/adalo
# https://www.make.com/en/integrations/paperform
# https://www.make.com/en/integrations/feedly
# https://www.make.com/en/integrations/google-groups
# https://www.make.com/en/integrations/amazon-lambda
# https://www.make.com/en/integrations/tumblr
# https://www.make.com/en/integrations/scrapingbee
# https://www.make.com/en/integrations/evernote
# https://www.make.com/en/integrations/docuware
# https://www.make.com/en/integrations/smartsheet
# https://www.make.com/en/integrations/google-translate
# https://www.make.com/en/integrations/squarespace
# https://www.make.com/en/integrations/qonto
# https://www.make.com/en/integrations/browse-ai
# https://www.make.com/en/integrations/tiktok
# https://www.make.com/en/integrations/facebook-ads-cm
# https://www.make.com/en/integrations/teamleader
# https://www.make.com/en/integrations/google-ads-customer-match
# https://www.make.com/en/integrations/aircall
# https://www.make.com/en/integrations/click-funnels
# https://www.make.com/en/integrations/soundcloud
# https://www.make.com/en/integrations/raynetcrm
# https://www.make.com/en/integrations/circle-so
# https://www.make.com/en/integrations/wix
# https://www.make.com/en/integrations/square
# https://www.make.com/en/integrations/box
# https://www.make.com/en/integrations/craftmypdf-com
# https://www.make.com/en/integrations/apitemplate-io
# https://www.make.com/en/integrations/mailparser-io
# https://www.make.com/en/integrations/printnode
# https://www.make.com/en/integrations/mailersend
# https://www.make.com/en/integrations/esignatures-io
# https://www.make.com/en/integrations/getresponse
# https://www.make.com/en/integrations/freshsales
# https://www.make.com/en/integrations/mongodb
# https://www.make.com/en/integrations/ifttt
# https://www.make.com/en/integrations/eledo
# https://www.make.com/en/integrations/strava
# https://www.make.com/en/integrations/pocket
# https://www.make.com/en/integrations/google-photos
# https://www.make.com/en/integrations/fakturoid
# https://www.make.com/en/integrations/softr
# https://www.make.com/en/integrations/pushover
# https://www.make.com/en/integrations/apollo
# https://www.make.com/en/integrations/smartsuite
# https://www.make.com/en/integrations/eventbrite
# https://www.make.com/en/integrations/lemlist
# https://www.make.com/en/integrations/zoho-forms
# https://www.make.com/en/integrations/wild-apricot
# https://www.make.com/en/integrations/mautic
# https://www.make.com/en/integrations/google-ads-lead-forms
# https://www.make.com/en/integrations/facebook-messenger
# https://www.make.com/en/integrations/thinkific
# https://www.make.com/en/integrations/odoo
# https://www.make.com/en/integrations/medium
# https://www.make.com/en/integrations/chargebee
# https://www.make.com/en/integrations/webinarjam
# https://www.make.com/en/integrations/gitlab
# https://www.make.com/en/integrations/vtiger
# https://www.make.com/en/integrations/customer-io
# https://www.make.com/en/integrations/fillout
# https://www.make.com/en/integrations/morning
# https://www.make.com/en/integrations/wave
# https://www.make.com/en/integrations/ringcentral
# https://www.make.com/en/integrations/thrivecart
# https://www.make.com/en/integrations/scrapeninja
# https://www.make.com/en/integrations/basecamp3
# https://www.make.com/en/integrations/chatguru
# https://www.make.com/en/integrations/zoho-invoice
# https://www.make.com/en/integrations/beehiiv
# https://www.make.com/en/integrations/chatwork
# https://www.make.com/en/integrations/rebrandly
# https://www.make.com/en/integrations/aweber
# https://www.make.com/en/integrations/mixpanel
# https://www.make.com/en/integrations/chrome
# https://www.make.com/en/integrations/nextcloud
# https://www.make.com/en/integrations/moneybird
# https://www.make.com/en/integrations/arcgis-field-maps
# https://www.make.com/en/integrations/responder-live
# https://www.make.com/en/integrations/foursquare
# https://www.make.com/en/integrations/tawkto
# https://www.make.com/en/integrations/bigin-by-zoho
# https://www.make.com/en/integrations/sellsy
# https://www.make.com/en/integrations/custom-js
# https://www.make.com/en/integrations/activetrail
# https://www.make.com/en/integrations/zoho-creator
# https://www.make.com/en/integrations/tripetto
# https://www.make.com/en/integrations/microsoft-people
# https://www.make.com/en/integrations/zerobounce
# https://www.make.com/en/integrations/wpforms
# https://www.make.com/en/integrations/magento2
# https://www.make.com/en/integrations/helpscout
# https://www.make.com/en/integrations/unbounce
# https://www.make.com/en/integrations/fio
# https://www.make.com/en/integrations/amazon-ses
# https://www.make.com/en/integrations/amazon-seller-central
# https://www.make.com/en/integrations/asaas
# https://www.make.com/en/integrations/placid-app
# https://www.make.com/en/integrations/ghost
# https://www.make.com/en/integrations/raindrop-io
# https://www.make.com/en/integrations/shortcuts
# https://www.make.com/en/integrations/inoreader
# https://www.make.com/en/integrations/front
# https://www.make.com/en/integrations/constant-contact
# https://www.make.com/en/integrations/drip
# https://www.make.com/en/integrations/follow-up-boss
# https://www.make.com/en/integrations/bexio
# https://www.make.com/en/integrations/bannerbear
# https://www.make.com/en/integrations/ecomail-cz
# https://www.make.com/en/integrations/wp-webhooks
# https://www.make.com/en/integrations/unsplash
# https://www.make.com/en/integrations/teamwork
# https://www.make.com/en/integrations/microsoft-power-bi
# https://www.make.com/en/integrations/zoho-desk
# https://www.make.com/en/integrations/google-cloud-tts
# https://www.make.com/en/integrations/sevdesk
# https://www.make.com/en/integrations/videoask
# https://www.make.com/en/integrations/kintone
# https://www.make.com/en/integrations/docparser
# https://www.make.com/en/integrations/giphy
# https://www.make.com/en/integrations/bamboohr
# https://www.make.com/en/integrations/moskitcrm
# https://www.make.com/en/integrations/mailchimp-transactional-email
# https://www.make.com/en/integrations/imgbb
# https://www.make.com/en/integrations/snowflake
# https://www.make.com/en/integrations/mastodon
# https://www.make.com/en/integrations/frame-io
# https://www.make.com/en/integrations/convertapi
# https://www.make.com/en/integrations/beds24
# https://www.make.com/en/integrations/zoho-campaigns
# https://www.make.com/en/integrations/teachable
# https://www.make.com/en/integrations/invoiceninja
# https://www.make.com/en/integrations/docupilot
# https://www.make.com/en/integrations/documint
# https://www.make.com/en/integrations/appsheet
# https://www.make.com/en/integrations/linear
# https://www.make.com/en/integrations/everwebinar
# https://www.make.com/en/integrations/typebot
# https://www.make.com/en/integrations/survey-monkey
# https://www.make.com/en/integrations/sendcloud
# https://www.make.com/en/integrations/vimeo
# https://www.make.com/en/integrations/pushbullet
# https://www.make.com/en/integrations/pdf4me
# https://www.make.com/en/integrations/google-meet
# https://www.make.com/en/integrations/flexibee
# https://www.make.com/en/integrations/tny
# https://www.make.com/en/integrations/smart-emailing
# https://www.make.com/en/integrations/sendfox
# https://www.make.com/en/integrations/inforumobile
# https://www.make.com/en/integrations/sendy
# https://www.make.com/en/integrations/missive
# https://www.make.com/en/integrations/email-octopus
# https://www.make.com/en/integrations/zoho-inventory
# https://www.make.com/en/integrations/miro
# https://www.make.com/en/integrations/ninja-forms
# https://www.make.com/en/integrations/gatewayapi
# https://www.make.com/en/integrations/coinmarketcap
# https://www.make.com/en/integrations/youtube
# https://www.make.com/en/integrations/ynab
# https://www.make.com/en/integrations/pdf-generator-api
# https://www.make.com/en/integrations/openweathermap
# https://www.make.com/en/integrations/tabidoo
# https://www.make.com/en/integrations/moco
# https://www.make.com/en/integrations/signrequest
# https://www.make.com/en/integrations/segment
# https://www.make.com/en/integrations/pdffiller
# https://www.make.com/en/integrations/mattermost
# https://www.make.com/en/integrations/habitica
# https://www.make.com/en/integrations/gumroad
# https://www.make.com/en/integrations/fluentcrm
# https://www.make.com/en/integrations/smsapi
# https://www.make.com/en/integrations/livestorm
# https://www.make.com/en/integrations/easybill
# https://www.make.com/en/integrations/respond-io
# https://www.make.com/en/integrations/onesignal
# https://www.make.com/en/integrations/onenote
# https://www.make.com/en/integrations/axonaut
# https://www.make.com/en/integrations/wrike
# https://www.make.com/en/integrations/scheduleonce
# https://www.make.com/en/integrations/katana-mrp
# https://www.make.com/en/integrations/snovio
# https://www.make.com/en/integrations/seatable
# https://www.make.com/en/integrations/justcall
# https://www.make.com/en/integrations/cloudflare
# https://www.make.com/en/integrations/chatbase
# https://www.make.com/en/integrations/streak
# https://www.make.com/en/integrations/baselinker
# https://www.make.com/en/integrations/sklonovani-jmen
# https://www.make.com/en/integrations/kartra
# https://www.make.com/en/integrations/cleverreach
# https://www.make.com/en/integrations/zapsign
# https://www.make.com/en/integrations/supersaas
# https://www.make.com/en/integrations/salla
# https://www.make.com/en/integrations/apaleo
# https://www.make.com/en/integrations/textmagic
# https://www.make.com/en/integrations/convertio
# https://www.make.com/en/integrations/zoho-sign
# https://www.make.com/en/integrations/removebg
# https://www.make.com/en/integrations/omnisend
# https://www.make.com/en/integrations/neverbounce
# https://www.make.com/en/integrations/netlify
# https://www.make.com/en/integrations/learndash
# https://www.make.com/en/integrations/pushcut
# https://www.make.com/en/integrations/fibery
# https://www.make.com/en/integrations/facebook-conversion-leads
# https://www.make.com/en/integrations/woodpecker
# https://www.make.com/en/integrations/splitwise
# https://www.make.com/en/integrations/rest-countries
# https://www.make.com/en/integrations/hunter
# https://www.make.com/en/integrations/google-chat
# https://www.make.com/en/integrations/fapi
# https://www.make.com/en/integrations/callrail
# https://www.make.com/en/integrations/bolt-iot
# https://www.make.com/en/integrations/skype
# https://www.make.com/en/integrations/pcloud
# https://www.make.com/en/integrations/freshservice
# https://www.make.com/en/integrations/formidable-forms
# https://www.make.com/en/integrations/dialpad
# https://www.make.com/en/integrations/clio-manage
# https://www.make.com/en/integrations/chatfuel
# https://www.make.com/en/integrations/campaign-monitor
# https://www.make.com/en/integrations/baserow
# https://www.make.com/en/integrations/tadabase
# https://www.make.com/en/integrations/parseur
# https://www.make.com/en/integrations/onesimpleapi
# https://www.make.com/en/integrations/loyverse
# https://www.make.com/en/integrations/idoklad
# https://www.make.com/en/integrations/facebook
# https://www.make.com/en/integrations/vybit
# https://www.make.com/en/integrations/shotstack
# https://www.make.com/en/integrations/scraptio
# https://www.make.com/en/integrations/microsoft-planner
# https://www.make.com/en/integrations/message-bird
# https://www.make.com/en/integrations/fatture-in-cloud
# https://www.make.com/en/integrations/caflou
# https://www.make.com/en/integrations/bulkgate
# https://www.make.com/en/integrations/anthropic-claude
# https://www.make.com/en/integrations/zoho-cliq
# https://www.make.com/en/integrations/memberpress
# https://www.make.com/en/integrations/mallabe-images
# https://www.make.com/en/integrations/formstack
# https://www.make.com/en/integrations/crisp
# https://www.make.com/en/integrations/pinecone
# https://www.make.com/en/integrations/ontraport
# https://www.make.com/en/integrations/eversign
# https://www.make.com/en/integrations/clearbit
# https://www.make.com/en/integrations/zendesk-sell
# https://www.make.com/en/integrations/google-data-studio
# https://www.make.com/en/integrations/espo-crm
# https://www.make.com/en/integrations/encharge
# https://www.make.com/en/integrations/dropcontact
# https://www.make.com/en/integrations/databox
# https://www.make.com/en/integrations/auth0
# https://www.make.com/en/integrations/zoho-projects
# https://www.make.com/en/integrations/servicem8
# https://www.make.com/en/integrations/receitaws
# https://www.make.com/en/integrations/poptin
# https://www.make.com/en/integrations/google-cloud-pubsub
# https://www.make.com/en/integrations/freshbooks
# https://www.make.com/en/integrations/fcm
# https://www.make.com/en/integrations/caspio
# https://www.make.com/en/integrations/abyssale
# https://www.make.com/en/integrations/suitecrm7
# https://www.make.com/en/integrations/icount
# https://www.make.com/en/integrations/google-cloud-speech
# https://www.make.com/en/integrations/bannerly
# https://www.make.com/en/integrations/tsheets
# https://www.make.com/en/integrations/holded
# https://www.make.com/en/integrations/elastic-email
# https://www.make.com/en/integrations/prosperworks
# https://www.make.com/en/integrations/uploadcare
# https://www.make.com/en/integrations/super-manager
# https://www.make.com/en/integrations/everhour
# https://www.make.com/en/integrations/plutio
# https://www.make.com/en/integrations/people-data-labs
# https://www.make.com/en/integrations/mailrelay
# https://www.make.com/en/integrations/gosms
# https://www.make.com/en/integrations/egnyte
# https://www.make.com/en/integrations/simplybook
# https://www.make.com/en/integrations/rocket-chat
# https://www.make.com/en/integrations/mollie
# https://www.make.com/en/integrations/meistertask
# https://www.make.com/en/integrations/learnworlds
# https://www.make.com/en/integrations/huggingface
# https://www.make.com/en/integrations/fireflies-ai
# https://www.make.com/en/integrations/hellosign
# https://www.make.com/en/integrations/chatforma
# https://www.make.com/en/integrations/sms019
# https://www.make.com/en/integrations/telnyx
# https://www.make.com/en/integrations/sharpspring
# https://www.make.com/en/integrations/linkedin-ads-reports
# https://www.make.com/en/integrations/agendor
# https://www.make.com/en/integrations/aftership
# https://www.make.com/en/integrations/signnow
# https://www.make.com/en/integrations/linkedin-matched-audiences
# https://www.make.com/en/integrations/groupme
# https://www.make.com/en/integrations/cloud-bot
# https://www.make.com/en/integrations/abby
# https://www.make.com/en/integrations/sms77
# https://www.make.com/en/integrations/razorpay
# https://www.make.com/en/integrations/productboard
# https://www.make.com/en/integrations/judge-me
# https://www.make.com/en/integrations/webmerge
# https://www.make.com/en/integrations/capsule-crm
# https://www.make.com/en/integrations/alegra
# https://www.make.com/en/integrations/recharge
# https://www.make.com/en/integrations/parsio
# https://www.make.com/en/integrations/linkedin-lgf-events
# https://www.make.com/en/integrations/google-cloud-dialogflow
# https://www.make.com/en/integrations/discourse
# https://www.make.com/en/integrations/burst-sms
# https://www.make.com/en/integrations/bitbucket
# https://www.make.com/en/integrations/zendesk-guide
# https://www.make.com/en/integrations/youcanbookme
# https://www.make.com/en/integrations/officeguy
# https://www.make.com/en/integrations/boondmanager
# https://www.make.com/en/integrations/wufoo
# https://www.make.com/en/integrations/prospero
# https://www.make.com/en/integrations/flickr
# https://www.make.com/en/integrations/canvas-lms
# https://www.make.com/en/integrations/planfix
# https://www.make.com/en/integrations/handlebars
# https://www.make.com/en/integrations/reply-io
# https://www.make.com/en/integrations/redmine
# https://www.make.com/en/integrations/parsehub
# https://www.make.com/en/integrations/pagerduty
# https://www.make.com/en/integrations/mallabe-currencies
# https://www.make.com/en/integrations/patreon
# https://www.make.com/en/integrations/okta
# https://www.make.com/en/integrations/nocrm-io
# https://www.make.com/en/integrations/digistore
# https://www.make.com/en/integrations/captain-data
# https://www.make.com/en/integrations/personio
# https://www.make.com/en/integrations/outseta
# https://www.make.com/en/integrations/binance
# https://www.make.com/en/integrations/aws-redshift
# https://www.make.com/en/integrations/clubhouse
# https://www.make.com/en/integrations/recruitee
# https://www.make.com/en/integrations/quickchart
# https://www.make.com/en/integrations/process-street
# https://www.make.com/en/integrations/formaloo
# https://www.make.com/en/integrations/digitalocean-spaces
# https://www.make.com/en/integrations/xero-projects
# https://www.make.com/en/integrations/vbout
# https://www.make.com/en/integrations/ticket-tailor
# https://www.make.com/en/integrations/numverify
# https://www.make.com/en/integrations/nethunt
# https://www.make.com/en/integrations/landbot
# https://www.make.com/en/integrations/ksaar
# https://www.make.com/en/integrations/hootsuite
# https://www.make.com/en/integrations/generatebanners
# https://www.make.com/en/integrations/flashyapp
# https://www.make.com/en/integrations/clover-pos
# https://www.make.com/en/integrations/bland-ai
# https://www.make.com/en/integrations/zoho-recruit
# https://www.make.com/en/integrations/usercom
# https://www.make.com/en/integrations/tapfiliate
# https://www.make.com/en/integrations/kurzy-cnb
# https://www.make.com/en/integrations/shippo
# https://www.make.com/en/integrations/handwrytten
# https://www.make.com/en/integrations/getmyinvoices
# https://www.make.com/en/integrations/filestack
# https://www.make.com/en/integrations/elopage
# https://www.make.com/en/integrations/dux-soup
# https://www.make.com/en/integrations/delighted
# https://www.make.com/en/integrations/cloudtalk
# https://www.make.com/en/integrations/kanbanize
# https://www.make.com/en/integrations/teamwork-desk
# https://www.make.com/en/integrations/syncro
# https://www.make.com/en/integrations/simvoly2
# https://www.make.com/en/integrations/salesmate
# https://www.make.com/en/integrations/rossum-elis
# https://www.make.com/en/integrations/plivo
# https://www.make.com/en/integrations/memberspot
# https://www.make.com/en/integrations/freeagent
# https://www.make.com/en/integrations/whatconverts
# https://www.make.com/en/integrations/simpletexting
# https://www.make.com/en/integrations/onfleet
# https://www.make.com/en/integrations/dear-inventory
# https://www.make.com/en/integrations/beeminder
# https://www.make.com/en/integrations/attio
# https://www.make.com/en/integrations/sender
# https://www.make.com/en/integrations/quentn
# https://www.make.com/en/integrations/nocodb
# https://www.make.com/en/integrations/klicktipp
# https://www.make.com/en/integrations/hubstaff
# https://www.make.com/en/integrations/google-shopping
# https://www.make.com/en/integrations/clearout
# https://www.make.com/en/integrations/bouncer
# https://www.make.com/en/integrations/bitskout
# https://www.make.com/en/integrations/azure-devops
# https://www.make.com/en/integrations/autopilot
# https://www.make.com/en/integrations/reamaze
# https://www.make.com/en/integrations/quill-forms
# https://www.make.com/en/integrations/opsgenie
# https://www.make.com/en/integrations/netsuite
# https://www.make.com/en/integrations/linkedin-ads-campaign-mgmt
# https://www.make.com/en/integrations/google-natural-language
# https://www.make.com/en/integrations/freelo
# https://www.make.com/en/integrations/free-finance
# https://www.make.com/en/integrations/figma
# https://www.make.com/en/integrations/email-list-verify
# https://www.make.com/en/integrations/deputy
# https://www.make.com/en/integrations/yourls
# https://www.make.com/en/integrations/wistia
# https://www.make.com/en/integrations/vonage
# https://www.make.com/en/integrations/textcortex-ai
# https://www.make.com/en/integrations/teamup
# https://www.make.com/en/integrations/quickcapture
# https://www.make.com/en/integrations/placetel
# https://www.make.com/en/integrations/moosend
# https://www.make.com/en/integrations/lob
# https://www.make.com/en/integrations/geckoboard
# https://www.make.com/en/integrations/cloudmersive
# https://www.make.com/en/integrations/chartmogul
# https://www.make.com/en/integrations/kajabi
# https://www.make.com/en/integrations/veriphone
# https://www.make.com/en/integrations/twist
# https://www.make.com/en/integrations/talentlms
# https://www.make.com/en/integrations/smsfactor
# https://www.make.com/en/integrations/slybroadcast
# https://www.make.com/en/integrations/memberkit
# https://www.make.com/en/integrations/datadog
# https://www.make.com/en/integrations/clickmeeting
# https://www.make.com/en/integrations/sharefile
# https://www.make.com/en/integrations/agile-crm
# https://www.make.com/en/integrations/fx1001
# https://www.make.com/en/integrations/smartlead-ai
# https://www.make.com/en/integrations/unisender
# https://www.make.com/en/integrations/tilda
# https://www.make.com/en/integrations/superfaktura
# https://www.make.com/en/integrations/quanda
# https://www.make.com/en/integrations/leapai
# https://www.make.com/en/integrations/instapage
# https://www.make.com/en/integrations/gotowebinar
# https://www.make.com/en/integrations/fastfield
# https://www.make.com/en/integrations/elasticsearch
# https://www.make.com/en/integrations/edusign
# https://www.make.com/en/integrations/clicksign
# https://www.make.com/en/integrations/techulus-push
# https://www.make.com/en/integrations/sentry
# https://www.make.com/en/integrations/rescuetime
# https://www.make.com/en/integrations/recurly
# https://www.make.com/en/integrations/porsline
# https://www.make.com/en/integrations/natif-ai
# https://www.make.com/en/integrations/meetovo
# https://www.make.com/en/integrations/insightly
# https://www.make.com/en/integrations/happyforms
# https://www.make.com/en/integrations/facebook-catalogs
# https://www.make.com/en/integrations/exact-spotter
# https://www.make.com/en/integrations/e-goi
# https://www.make.com/en/integrations/easypost
# https://www.make.com/en/integrations/basin
# https://www.make.com/en/integrations/awork
# https://www.make.com/en/integrations/atera
# https://www.make.com/en/integrations/zoho-sheet
# https://www.make.com/en/integrations/timelyapp
# https://www.make.com/en/integrations/smartthings
# https://www.make.com/en/integrations/reversecontact
# https://www.make.com/en/integrations/repairshopr
# https://www.make.com/en/integrations/mailmodo
# https://www.make.com/en/integrations/funnelforms
# https://www.make.com/en/integrations/zoho-people
# https://www.make.com/en/integrations/waze-deep-links
# https://www.make.com/en/integrations/timeular
# https://www.make.com/en/integrations/timebuzzer
# https://www.make.com/en/integrations/sleekflow
# https://www.make.com/en/integrations/sendowl
# https://www.make.com/en/integrations/rentman
# https://www.make.com/en/integrations/printful
# https://www.make.com/en/integrations/pingdom
# https://www.make.com/en/integrations/merk
# https://www.make.com/en/integrations/mavenlink
# https://www.make.com/en/integrations/iterable
# https://www.make.com/en/integrations/hibob
# https://www.make.com/en/integrations/crocoblock
# https://www.make.com/en/integrations/convertbox
# https://www.make.com/en/integrations/cloze
# https://www.make.com/en/integrations/adobe-sign
# https://www.make.com/en/integrations/zammad
# https://www.make.com/en/integrations/xama-onboarding
# https://www.make.com/en/integrations/wealthbox
# https://www.make.com/en/integrations/wasabi
# https://www.make.com/en/integrations/vk-com
# https://www.make.com/en/integrations/umbler-utalk
# https://www.make.com/en/integrations/smaily
# https://www.make.com/en/integrations/rows
# https://www.make.com/en/integrations/revolut
# https://www.make.com/en/integrations/quaderno
# https://www.make.com/en/integrations/pipedrive-resellers
# https://www.make.com/en/integrations/marketo
# https://www.make.com/en/integrations/godaddy
# https://www.make.com/en/integrations/getaccept
# https://www.make.com/en/integrations/float
# https://www.make.com/en/integrations/engagebay
# https://www.make.com/en/integrations/dhl
# https://www.make.com/en/integrations/contentful
# https://www.make.com/en/integrations/amplitude
# https://www.make.com/en/integrations/thanks-io
# https://www.make.com/en/integrations/steam
# https://www.make.com/en/integrations/sms-alert
# https://www.make.com/en/integrations/semrush
# https://www.make.com/en/integrations/mem
# https://www.make.com/en/integrations/mailercheck
# https://www.make.com/en/integrations/jobnimbus
# https://www.make.com/en/integrations/freshchat
# https://www.make.com/en/integrations/fortnox
# https://www.make.com/en/integrations/force-manager
# https://www.make.com/en/integrations/factorial
# https://www.make.com/en/integrations/deezer
# https://www.make.com/en/integrations/datagma
# https://www.make.com/en/integrations/contactsplus
# https://www.make.com/en/integrations/webex-teams
# https://www.make.com/en/integrations/braintree
# https://www.make.com/en/integrations/bizmachine
# https://www.make.com/en/integrations/bigmarker
# https://www.make.com/en/integrations/amazon-sns
# https://www.make.com/en/integrations/twentyninenext
# https://www.make.com/en/integrations/gemini-ai
# https://www.make.com/en/integrations/virtuagym
# https://www.make.com/en/integrations/unleashed-software
# https://www.make.com/en/integrations/timecamp
# https://www.make.com/en/integrations/sparkpost
# https://www.make.com/en/integrations/shipday
# https://www.make.com/en/integrations/serwersms
# https://www.make.com/en/integrations/sage-accounting
# https://www.make.com/en/integrations/qwilr
# https://www.make.com/en/integrations/pulseem
# https://www.make.com/en/integrations/survey-anyplace
# https://www.make.com/en/integrations/paystack
# https://www.make.com/en/integrations/pagar-me
# https://www.make.com/en/integrations/order-desk
# https://www.make.com/en/integrations/meetime
# https://www.make.com/en/integrations/mailbluster
# https://www.make.com/en/integrations/landingi
# https://www.make.com/en/integrations/google-keep
# https://www.make.com/en/integrations/goodbarber
# https://www.make.com/en/integrations/freshping
# https://www.make.com/en/integrations/firetext
# https://www.make.com/en/integrations/easyship
# https://www.make.com/en/integrations/detrack
# https://www.make.com/en/integrations/canny
# https://www.make.com/en/integrations/amazing-marvin
# https://www.make.com/en/integrations/action-network
# https://www.make.com/en/integrations/transistor-fm
# https://www.make.com/en/integrations/trakt-tv
# https://www.make.com/en/integrations/textline
# https://www.make.com/en/integrations/sugarcrm11
# https://www.make.com/en/integrations/salesmanago
# https://www.make.com/en/integrations/pomodoneapp
# https://www.make.com/en/integrations/resource-guru
# https://www.make.com/en/integrations/rabbitmq
# https://www.make.com/en/integrations/printavo
# https://www.make.com/en/integrations/paymo
# https://www.make.com/en/integrations/outgrow
# https://www.make.com/en/integrations/mixmax
# https://www.make.com/en/integrations/neto
# https://www.make.com/en/integrations/mailboxvalidator
# https://www.make.com/en/integrations/kizeo-forms
# https://www.make.com/en/integrations/fareharbor
# https://www.make.com/en/integrations/converts-online
# https://www.make.com/en/integrations/chytrystart
# https://www.make.com/en/integrations/chatsonic
# https://www.make.com/en/integrations/byteplant-address-validator
# https://www.make.com/en/integrations/booqable
# https://www.make.com/en/integrations/belazy
# https://www.make.com/en/integrations/allmysms
# https://www.make.com/en/integrations/the-bot-platform
# https://www.make.com/en/integrations/signable
# https://www.make.com/en/integrations/senuto
# https://www.make.com/en/integrations/salesflare
# https://www.make.com/en/integrations/qualtrics
# https://www.make.com/en/integrations/plex
# https://www.make.com/en/integrations/opengraph-io
# https://www.make.com/en/integrations/officernd
# https://www.make.com/en/integrations/nutshell
# https://www.make.com/en/integrations/iucto
# https://www.make.com/en/integrations/infobip
# https://www.make.com/en/integrations/gist
# https://www.make.com/en/integrations/fomo
# https://www.make.com/en/integrations/files-com
# https://www.make.com/en/integrations/demio
# https://www.make.com/en/integrations/d7-sms
# https://www.make.com/en/integrations/billit
# https://www.make.com/en/integrations/skool
# https://www.make.com/en/integrations/openrouter.ai
# https://www.make.com/en/integrations/yelp
# https://www.make.com/en/integrations/wflow
# https://www.make.com/en/integrations/viral-loops
# https://www.make.com/en/integrations/beaconstac
# https://www.make.com/en/integrations/twilio-verify
# https://www.make.com/en/integrations/taphome
# https://www.make.com/en/integrations/stealth-seminar
# https://www.make.com/en/integrations/smtp2go
# https://www.make.com/en/integrations/quotient
# https://www.make.com/en/integrations/quickfile
# https://www.make.com/en/integrations/quickemailverification
# https://www.make.com/en/integrations/nectar-crm
# https://www.make.com/en/integrations/lightspeed-ecom
# https://www.make.com/en/integrations/iauditor
# https://www.make.com/en/integrations/formsite
# https://www.make.com/en/integrations/flowlu
# https://www.make.com/en/integrations/fapi-member
# https://www.make.com/en/integrations/e-conomic
# https://www.make.com/en/integrations/ecologi
# https://www.make.com/en/integrations/drupal
# https://www.make.com/en/integrations/backendless
# https://www.make.com/en/integrations/groq-ai
# https://www.make.com/en/integrations/heygen
# https://www.make.com/en/integrations/weclapp
# https://www.make.com/en/integrations/zendesk-sunshine
# https://www.make.com/en/integrations/zamzar
# https://www.make.com/en/integrations/yoast
# https://www.make.com/en/integrations/upviral
# https://www.make.com/en/integrations/trint
# https://www.make.com/en/integrations/transloadit
# https://www.make.com/en/integrations/tookan
# https://www.make.com/en/integrations/simplero
# https://www.make.com/en/integrations/rudderstack
# https://www.make.com/en/integrations/plentymarkets
# https://www.make.com/en/integrations/phoneburner
# https://www.make.com/en/integrations/phaxio
# https://www.make.com/en/integrations/onepagecrm
# https://www.make.com/en/integrations/officely
# https://www.make.com/en/integrations/active-directory
# https://www.make.com/en/integrations/memberful
# https://www.make.com/en/integrations/lnk-bio
# https://www.make.com/en/integrations/keboola
# https://www.make.com/en/integrations/ipqualityscore
# https://www.make.com/en/integrations/goaffpro
# https://www.make.com/en/integrations/getform
# https://www.make.com/en/integrations/ezeep-blue-printing
# https://www.make.com/en/integrations/easydoc
# https://www.make.com/en/integrations/debounce
# https://www.make.com/en/integrations/marketcircle-daylite
# https://www.make.com/en/integrations/cliengo
# https://www.make.com/en/integrations/byteplant-email-validator
# https://www.make.com/en/integrations/anabix
# https://www.make.com/en/integrations/eight-stacks-image-generator
# https://www.make.com/en/integrations/onecrm
# https://www.make.com/en/integrations/motion
# https://www.make.com/en/integrations/moodle
# https://www.make.com/en/integrations/xano
# https://www.make.com/en/integrations/zagomail
# https://www.make.com/en/integrations/yay-forms
# https://www.make.com/en/integrations/when-i-work
# https://www.make.com/en/integrations/wechat
# https://www.make.com/en/integrations/view-dns
# https://www.make.com/en/integrations/ups-quantum-view
# https://www.make.com/en/integrations/triggercmd
# https://www.make.com/en/integrations/tmetric
# https://www.make.com/en/integrations/time-doctor
# https://www.make.com/en/integrations/tableau
# https://www.make.com/en/integrations/synthesia
# https://www.make.com/en/integrations/selly-erp
# https://www.make.com/en/integrations/salesmsg
# https://www.make.com/en/integrations/rocketreach
# https://www.make.com/en/integrations/refiner
# https://www.make.com/en/integrations/profitwell
# https://www.make.com/en/integrations/oopspam-anti-spam
# https://www.make.com/en/integrations/mwork365
# https://www.make.com/en/integrations/matrix
# https://www.make.com/en/integrations/loops
# https://www.make.com/en/integrations/kanbanflow
# https://www.make.com/en/integrations/jivochat
# https://www.make.com/en/integrations/emailvalidation
# https://www.make.com/en/integrations/easy-project
# https://www.make.com/en/integrations/dynalist
# https://www.make.com/en/integrations/documentero
# https://www.make.com/en/integrations/digisign
# https://www.make.com/en/integrations/cs-cart
# https://www.make.com/en/integrations/craft-ql
# https://www.make.com/en/integrations/codereadr
# https://www.make.com/en/integrations/chargeover
# https://www.make.com/en/integrations/bugherd
# https://www.make.com/en/integrations/wise
# https://www.make.com/en/integrations/bigcommerce
# https://www.make.com/en/integrations/stable-diffusion
# https://www.make.com/en/integrations/zoho-writer
# https://www.make.com/en/integrations/uproc
# https://www.make.com/en/integrations/textbelt
# https://www.make.com/en/integrations/stackby
# https://www.make.com/en/integrations/service-provider-pro
# https://www.make.com/en/integrations/sellercloud
# https://www.make.com/en/integrations/satismeter
# https://www.make.com/en/integrations/runkeeper
# https://www.make.com/en/integrations/ragic
# https://www.make.com/en/integrations/quickbase
# https://www.make.com/en/integrations/pivotal-tracker
# https://www.make.com/en/integrations/picsart
# https://www.make.com/en/integrations/nimble
# https://www.make.com/en/integrations/nexweave
# https://www.make.com/en/integrations/meetup
# https://www.make.com/en/integrations/liveagent
# https://www.make.com/en/integrations/kixie
# https://www.make.com/en/integrations/kickbox
# https://www.make.com/en/integrations/initiative-crm
# https://www.make.com/en/integrations/helpwise
# https://www.make.com/en/integrations/freescout
# https://www.make.com/en/integrations/filestage
# https://www.make.com/en/integrations/favro
# https://www.make.com/en/integrations/expensify
# https://www.make.com/en/integrations/easycsv
# https://www.make.com/en/integrations/dotdigital
# https://www.make.com/en/integrations/copilot
# https://www.make.com/en/integrations/byteplant-phone-validator
# https://www.make.com/en/integrations/botstar
# https://www.make.com/en/integrations/book-like-a-boss
# https://www.make.com/en/integrations/beamer
# https://www.make.com/en/integrations/arlo
# https://www.make.com/en/integrations/apn
# https://www.make.com/en/integrations/apple-map-links
# https://www.make.com/en/integrations/airparser
# https://www.make.com/en/integrations/one-two-three-form-builder
# https://www.make.com/en/integrations/exact-online
# https://www.make.com/en/integrations/relevance-ai
# https://www.make.com/en/integrations/join
# https://www.make.com/en/integrations/surecart
# https://www.make.com/en/integrations/vyfakturuj-cz
# https://www.make.com/en/integrations/vitally
# https://www.make.com/en/integrations/uteach
# https://www.make.com/en/integrations/textit
# https://www.make.com/en/integrations/swapcard
# https://www.make.com/en/integrations/sling
# https://www.make.com/en/integrations/simpletix
# https://www.make.com/en/integrations/simplesat
# https://www.make.com/en/integrations/simpleen-translation
# https://www.make.com/en/integrations/signi
# https://www.make.com/en/integrations/signalwire
# https://www.make.com/en/integrations/salesloft
# https://www.make.com/en/integrations/prefinery
# https://www.make.com/en/integrations/plumsail-documents
# https://www.make.com/en/integrations/pinboard
# https://www.make.com/en/integrations/pastebin
# https://www.make.com/en/integrations/onoff-business
# https://www.make.com/en/integrations/nusii
# https://www.make.com/en/integrations/nozbe-teams
# https://www.make.com/en/integrations/moxie
# https://www.make.com/en/integrations/mitto-sms
# https://www.make.com/en/integrations/metabase
# https://www.make.com/en/integrations/linkedin-offline-conversions
# https://www.make.com/en/integrations/learningsuite
# https://www.make.com/en/integrations/leady
# https://www.make.com/en/integrations/leadsquared
# https://www.make.com/en/integrations/kissflow
# https://www.make.com/en/integrations/jw-player
# https://www.make.com/en/integrations/jenkins
# https://www.make.com/en/integrations/involve-me
# https://www.make.com/en/integrations/invoiced
# https://www.make.com/en/integrations/infinity
# https://www.make.com/en/integrations/hive
# https://www.make.com/en/integrations/hireflix
# https://www.make.com/en/integrations/hero-software
# https://www.make.com/en/integrations/happyfox-help-desk
# https://www.make.com/en/integrations/groove
# https://www.make.com/en/integrations/grist
# https://www.make.com/en/integrations/greenhouse
# https://www.make.com/en/integrations/goodbarber-ecommerce
# https://www.make.com/en/integrations/freshmail
# https://www.make.com/en/integrations/formspree
# https://www.make.com/en/integrations/endorsal
# https://www.make.com/en/integrations/emma
# https://www.make.com/en/integrations/drift
# https://www.make.com/en/integrations/customerly
# https://www.make.com/en/integrations/clust
# https://www.make.com/en/integrations/chatra
# https://www.make.com/en/integrations/chatbot
# https://www.make.com/en/integrations/blocksurvey
# https://www.make.com/en/integrations/bigmailer
# https://www.make.com/en/integrations/bannerbite
# https://www.make.com/en/integrations/avochato
# https://www.make.com/en/integrations/artibot-ai
# https://www.make.com/en/integrations/oblio.eu-facturare
# https://www.make.com/en/integrations/fastbill
# https://www.make.com/en/integrations/exact-online
# https://www.make.com/en/integrations/zulip
# https://www.make.com/en/integrations/yandex-translate
# https://www.make.com/en/integrations/wp-all-import
# https://www.make.com/en/integrations/wizishop
# https://www.make.com/en/integrations/waiverfile
# https://www.make.com/en/integrations/visma-eaccounting
# https://www.make.com/en/integrations/vend
# https://www.make.com/en/integrations/trustpilot
# https://www.make.com/en/integrations/toodledo
# https://www.make.com/en/integrations/toggl-plan
# https://www.make.com/en/integrations/timing
# https://www.make.com/en/integrations/the-keys
# https://www.make.com/en/integrations/temi
# https://www.make.com/en/integrations/teamviewer
# https://www.make.com/en/integrations/survicate
# https://www.make.com/en/integrations/sugarcrm7
# https://www.make.com/en/integrations/stencil
# https://www.make.com/en/integrations/stamped
# https://www.make.com/en/integrations/socialbee
# https://www.make.com/en/integrations/snipcart
# https://www.make.com/en/integrations/smsc
# https://www.make.com/en/integrations/smith-ai
# https://www.make.com/en/integrations/slicktext
# https://www.make.com/en/integrations/site-search-360
# https://www.make.com/en/integrations/sigparser
# https://www.make.com/en/integrations/a3dcart
# https://www.make.com/en/integrations/scrive
# https://www.make.com/en/integrations/scanorders
# https://www.make.com/en/integrations/retable
# https://www.make.com/en/integrations/relatel
# https://www.make.com/en/integrations/quable-pim
# https://www.make.com/en/integrations/product-hunt
# https://www.make.com/en/integrations/practicepanther
# https://www.make.com/en/integrations/planyo
# https://www.make.com/en/integrations/paperless-io
# https://www.make.com/en/integrations/outreach
# https://www.make.com/en/integrations/nuelink
# https://www.make.com/en/integrations/moreapp-forms
# https://www.make.com/en/integrations/mallabe-websites
# https://www.make.com/en/integrations/make-forms
# https://www.make.com/en/integrations/mailshake
# https://www.make.com/en/integrations/luxafor
# https://www.make.com/en/integrations/livechat
# https://www.make.com/en/integrations/komercni-banka
# https://www.make.com/en/integrations/jitbit
# https://www.make.com/en/integrations/iteration-x
# https://www.make.com/en/integrations/invision-community
# https://www.make.com/en/integrations/humanitix
# https://www.make.com/en/integrations/gong
# https://www.make.com/en/integrations/gocanvas
# https://www.make.com/en/integrations/go4clients
# https://www.make.com/en/integrations/getprospect
# https://www.make.com/en/integrations/filecloud
# https://www.make.com/en/integrations/disqus
# https://www.make.com/en/integrations/demodesk
# https://www.make.com/en/integrations/custify
# https://www.make.com/en/integrations/clickatell
# https://www.make.com/en/integrations/cituro
# https://www.make.com/en/integrations/captivate
# https://www.make.com/en/integrations/getbrave-io
# https://www.make.com/en/integrations/basecamp
# https://www.make.com/en/integrations/axiom
# https://www.make.com/en/integrations/avaza
# https://www.make.com/en/integrations/aurora-solar
# https://www.make.com/en/integrations/aputime
# https://www.make.com/en/integrations/agileplace
# https://www.make.com/en/integrations/adroll
# https://www.make.com/en/integrations/four-leads
# https://www.make.com/en/integrations/botpress
# https://www.make.com/en/integrations/copy.ai
# https://www.make.com/en/integrations/bullhorn-api
# https://www.make.com/en/integrations/zenrows
# https://www.make.com/en/integrations/workday
# https://www.make.com/en/integrations/wizychat
# https://www.make.com/en/integrations/weblucy
# https://www.make.com/en/integrations/webex-meetings
# https://www.make.com/en/integrations/voicecenter
# https://www.make.com/en/integrations/vidalytics
# https://www.make.com/en/integrations/uzeli-salon-software
# https://www.make.com/en/integrations/tolstoy
# https://www.make.com/en/integrations/toky
# https://www.make.com/en/integrations/the-keys-pro
# https://www.make.com/en/integrations/teamwork-crm
# https://www.make.com/en/integrations/surveysparrow
# ...
# https://www.make.com/en/integrations/roboquill
# https://www.make.com/en/integrations/robolytix
# https://www.make.com/en/integrations/robocorp
# https://www.make.com/en/integrations/robly
# https://www.make.com/en/integrations/ringover
# https://www.make.com/en/integrations/rewardsciences
# https://www.make.com/en/integrations/revv-documents
# https://www.make.com/en/integrations/review-scraper
# https://www.make.com/en/integrations/reviewly
# https://www.make.com/en/integrations/restya-core
# https://www.make.com/en/integrations/responsesuite
# https://www.make.com/en/integrations/reservanto
# https://www.make.com/en/integrations/reply-agent
# https://www.make.com/en/integrations/repliq
# https://www.make.com/en/integrations/remberg
# https://www.make.com/en/integrations/rejstriky-info
# https://www.make.com/en/integrations/regfox
# https://www.make.com/en/integrations/rebill
# https://www.make.com/en/integrations/reachinbox
# https://www.make.com/en/integrations/rapidreg
# https://www.make.com/en/integrations/raklet
# https://www.make.com/en/integrations/quizcube
# https://www.make.com/en/integrations/quipu
# https://www.make.com/en/integrations/qualiobee
# https://www.make.com/en/integrations/qdrant
# https://www.make.com/en/integrations/put-io
# https://www.make.com/en/integrations/pushwoosh
# https://www.make.com/en/integrations/prodpad
# https://www.make.com/en/integrations/pro-crew-schedule
# https://www.make.com/en/integrations/procertif
# https://www.make.com/en/integrations/post-my-link
# https://www.make.com/en/integrations/platoforms
# https://www.make.com/en/integrations/planta-pulse
# https://www.make.com/en/integrations/getplaceholder
# https://www.make.com/en/integrations/picdefense
# https://www.make.com/en/integrations/phonenumber
# https://www.make.com/en/integrations/petoffice
# https://www.make.com/en/integrations/perspective
# https://www.make.com/en/integrations/perplexity-ai
# https://www.make.com/en/integrations/people-hr
# https://www.make.com/en/integrations/pennylane
# https://www.make.com/en/integrations/peliqan
# https://www.make.com/en/integrations/peerboard
# https://www.make.com/en/integrations/peaka
# https://www.make.com/en/integrations/the-pdf-maker
# https://www.make.com/en/integrations/passkit
# https://www.make.com/en/integrations/papyrs
# https://www.make.com/en/integrations/paon
# https://www.make.com/en/integrations/paced-email
# https://www.make.com/en/integrations/ozy-approvals
# https://www.make.com/en/integrations/overledger
# https://www.make.com/en/integrations/orbit
# https://www.make.com/en/integrations/oracle-fusion-cloud-sales
# https://www.make.com/en/integrations/oracle-fusion-cloud-hcm
# https://www.make.com/en/integrations/oracle-fusion-cloud-erp
# https://www.make.com/en/integrations/oracle-eloqua
# https://www.make.com/en/integrations/onboard
# https://www.make.com/en/integrations/omnivery
# https://www.make.com/en/integrations/omnichat
# https://www.make.com/en/integrations/omise
# https://www.make.com/en/integrations/olark
# https://www.make.com/en/integrations/oanda-exchange-rates
# https://www.make.com/en/integrations/norns-ai
# https://www.make.com/en/integrations/nocodetable
# https://www.make.com/en/integrations/nip24-pl
# https://www.make.com/en/integrations/new-relic
# https://www.make.com/en/integrations/netwo
# https://www.make.com/en/integrations/net0
# https://www.make.com/en/integrations/neaktor
# https://www.make.com/en/integrations/nasa
# https://www.make.com/en/integrations/mycalendaralerts
# https://www.make.com/en/integrations/mural
# https://www.make.com/en/integrations/mumble
# https://www.make.com/en/integrations/mumara
# https://www.make.com/en/integrations/mulesoft
# https://www.make.com/en/integrations/msg91
# https://www.make.com/en/integrations/moon-invoice
# https://www.make.com/en/integrations/mocean
# https://www.make.com/en/integrations/mobivate-sms
# https://www.make.com/en/integrations/mobicrm
# https://www.make.com/en/integrations/mistral-ai
# https://www.make.com/en/integrations/missionone-dialogplus
# https://www.make.com/en/integrations/mini-course-generator
# https://www.make.com/en/integrations/ghoststead
# https://www.make.com/en/integrations/mime
# https://www.make.com/en/integrations/microsoft-d365-bc
# https://www.make.com/en/integrations/metatask
# https://www.make.com/en/integrations/memomeister
# https://www.make.com/en/integrations/megaapi-start
# https://www.make.com/en/integrations/meero
# https://www.make.com/en/integrations/math
# https://www.make.com/en/integrations/markdown
# https://www.make.com/en/integrations/mapy-cz
# https://www.make.com/en/integrations/mantisbt
# https://www.make.com/en/integrations/mallabe-validations
# https://www.make.com/en/integrations/mallabe-barcodes
# https://www.make.com/en/integrations/makeplans
# https://www.make.com/en/integrations/mailvio
# https://www.make.com/en/integrations/mails-so
# https://www.make.com/en/integrations/mailkit
# https://www.make.com/en/integrations/mailcheck
# https://www.make.com/en/integrations/mail2many
# https://www.make.com/en/integrations/magic-eden
# https://www.make.com/en/integrations/macanta
# https://www.make.com/en/integrations/logbookie
# https://www.make.com/en/integrations/live-chat-ai
# https://www.make.com/en/integrations/lista-firme
# https://www.make.com/en/integrations/lionwheel-delivery
# https://www.make.com/en/integrations/linx-commerce
# https://www.make.com/en/integrations/lighthouse-by-cloudify
# https://www.make.com/en/integrations/levity
# https://www.make.com/en/integrations/letterdrop
# https://www.make.com/en/integrations/leonardo-ai
# https://www.make.com/en/integrations/leonai-priority
# https://www.make.com/en/integrations/legito
# https://www.make.com/en/integrations/leav-engine
# https://www.make.com/en/integrations/leadtable
# https://www.make.com/en/integrations/leadagent
# https://www.make.com/en/integrations/layerise
# https://www.make.com/en/integrations/kanban-tool
# https://www.make.com/en/integrations/kaleyra
# https://www.make.com/en/integrations/justclick
# https://www.make.com/en/integrations/json
# https://www.make.com/en/integrations/jepto
# https://www.make.com/en/integrations/iso
# https://www.make.com/en/integrations/iqmreports
# https://www.make.com/en/integrations/iqdial
# https://www.make.com/en/integrations/ip2proxy
# https://www.make.com/en/integrations/invokesms
# https://www.make.com/en/integrations/invoicing-plus
# https://www.make.com/en/integrations/invoiceberry
# https://www.make.com/en/integrations/interseller
# https://www.make.com/en/integrations/interact-do
# https://www.make.com/en/integrations/instasent
# https://www.make.com/en/integrations/instantly
# https://www.make.com/en/integrations/innform
# https://www.make.com/en/integrations/infor-m3
# https://www.make.com/en/integrations/image
# https://www.make.com/en/integrations/ilert
# https://www.make.com/en/integrations/iex-cloud
# https://www.make.com/en/integrations/idiligo
# https://www.make.com/en/integrations/icypeas
# https://www.make.com/en/integrations/ic-project
# https://www.make.com/en/integrations/httpstatus
# https://www.make.com/en/integrations/http-agent
# https://www.make.com/en/integrations/http
# https://www.make.com/en/integrations/html-to-img-api
# https://www.make.com/en/integrations/html-2-pdf
# https://www.make.com/en/integrations/hrflow-ai
# https://www.make.com/en/integrations/hi-sign
# https://www.make.com/en/integrations/hirevire
# https://www.make.com/en/integrations/hiretrack-nx
# https://www.make.com/en/integrations/heysummit
# https://www.make.com/en/integrations/heyspace
# https://www.make.com/en/integrations/herobot
# https://www.make.com/en/integrations/here
# https://www.make.com/en/integrations/scrape-it-cloud
# https://www.make.com/en/integrations/growsurf
# https://www.make.com/en/integrations/groner
# https://www.make.com/en/integrations/gps-tools
# https://www.make.com/en/integrations/google-vertex-ai
# https://www.make.com/en/integrations/google-search-console
# https://www.make.com/en/integrations/google-plus
# https://www.make.com/en/integrations/good-grants
# https://www.make.com/en/integrations/golemio
# https://www.make.com/en/integrations/webpay
# https://www.make.com/en/integrations/gigrove
# https://www.make.com/en/integrations/gifda
# https://www.make.com/en/integrations/getemail-io
# https://www.make.com/en/integrations/genderize
# https://www.make.com/en/integrations/gamfi
# https://www.make.com/en/integrations/gakunin-rdm
# https://www.make.com/en/integrations/funnelcockpit
# https://www.make.com/en/integrations/fulcrum
# https://www.make.com/en/integrations/ftp
# https://www.make.com/en/integrations/fresh-proposals
# https://www.make.com/en/integrations/forsign
# https://www.make.com/en/integrations/formlets
# https://www.make.com/en/integrations/formcan
# https://www.make.com/en/integrations/folk
# https://www.make.com/en/integrations/fogbugz
# https://www.make.com/en/integrations/focuster
# https://www.make.com/en/integrations/focus-anchor
# https://www.make.com/en/integrations/flutterwave
# https://www.make.com/en/integrations/flowgraph
# https://www.make.com/en/integrations/builtin
# https://www.make.com/en/integrations/flow-blockchain
# https://www.make.com/en/integrations/flodesk
# https://www.make.com/en/integrations/flock
# https://www.make.com/en/integrations/firstpromoter
# https://www.make.com/en/integrations/findymail
# https://www.make.com/en/integrations/fillfaster
# https://www.make.com/en/integrations/feedier
# https://www.make.com/en/integrations/fauna
# https://www.make.com/en/integrations/faceup
# https://www.make.com/en/integrations/ezofficeinventory
# https://www.make.com/en/integrations/fidoo-expense-management
# https://www.make.com/en/integrations/expanzo
# https://www.make.com/en/integrations/eway-crm
# https://www.make.com/en/integrations/eventzilla
# https://www.make.com/en/integrations/engage-ai
# https://www.make.com/en/integrations/engage
# https://www.make.com/en/integrations/enflow
# https://www.make.com/en/integrations/crypto
# https://www.make.com/en/integrations/emporix-oe
# https://www.make.com/en/integrations/emporix-commerce
# https://www.make.com/en/integrations/emercury
# https://www.make.com/en/integrations/emelia
# https://www.make.com/en/integrations/email
# https://www.make.com/en/integrations/elite-seller
# https://www.make.com/en/integrations/elements-cloud
# https://www.make.com/en/integrations/element451
# https://www.make.com/en/integrations/eet
# https://www.make.com/en/integrations/edock
# https://www.make.com/en/integrations/easyweek
# https://www.make.com/en/integrations/easypay
# https://www.make.com/en/integrations/easiware
# https://www.make.com/en/integrations/easelly
# https://www.make.com/en/integrations/earned-value
# https://www.make.com/en/integrations/dropfunnels
# https://www.make.com/en/integrations/drimify
# https://www.make.com/en/integrations/dootax
# https://www.make.com/en/integrations/dokan
# https://www.make.com/en/integrations/docugenerate
# https://www.make.com/en/integrations/docsgenflow
# https://www.make.com/en/integrations/docsfold
# https://www.make.com/en/integrations/doc-crafter
# https://www.make.com/en/integrations/disciple-tools
# https://www.make.com/en/integrations/diffbot
# https://www.make.com/en/integrations/delesign
# https://www.make.com/en/integrations/deepgram
# https://www.make.com/en/integrations/deel
# https://www.make.com/en/integrations/datelist
# https://www.make.com/en/integrations/datastore
# https://www.make.com/en/integrations/datamz
# https://www.make.com/en/integrations/data24-7
# https://www.make.com/en/integrations/fit-cvut-kos
# https://www.make.com/en/integrations/fit-cvut-grades
# https://www.make.com/en/integrations/cuttly-team
# https://www.make.com/en/integrations/currency
# https://www.make.com/en/integrations/csv
# https://www.make.com/en/integrations/crowdpower
# https://www.make.com/en/integrations/crossbeam
# https://www.make.com/en/integrations/crm-messaging
# https://www.make.com/en/integrations/coveo
# https://www.make.com/en/integrations/costbucket
# https://www.make.com/en/integrations/corymbus
# https://www.make.com/en/integrations/copicake
# https://www.make.com/en/integrations/contractbook
# https://www.make.com/en/integrations/content-snare
# https://www.make.com/en/integrations/connery
# https://www.make.com/en/integrations/confluence
# https://www.make.com/en/integrations/confiban
# https://www.make.com/en/integrations/confection
# https://www.make.com/en/integrations/companyhub
# https://www.make.com/en/integrations/commercehq
# https://www.make.com/en/integrations/commcare
# https://www.make.com/en/integrations/colligso-walletin
# https://www.make.com/en/integrations/colligso-textin
# https://www.make.com/en/integrations/collector
# https://www.make.com/en/integrations/colete-online
# https://www.make.com/en/integrations/cohere
# https://www.make.com/en/integrations/codegpt
# https://www.make.com/en/integrations/cnpja
# https://www.make.com/en/integrations/clicfans
# https://www.make.com/en/integrations/citibank
# https://www.make.com/en/integrations/chiavistello
# https://www.make.com/en/integrations/chat-breezes
# https://www.make.com/en/integrations/charlie-lounge
# https://www.make.com/en/integrations/channels
# https://www.make.com/en/integrations/celestory
# https://www.make.com/en/integrations/crmcarecloud
# https://www.make.com/en/integrations/cargoboard
# https://www.make.com/en/integrations/capri
# https://www.make.com/en/integrations/canvasflare
# https://www.make.com/en/integrations/candu
# https://www.make.com/en/integrations/campaign-cleaner
# https://www.make.com/en/integrations/callhippo
# https://www.make.com/en/integrations/call-assist
# https://www.make.com/en/integrations/calbanktrust
# https://www.make.com/en/integrations/businesslogic
# https://www.make.com/en/integrations/bullet
# https://www.make.com/en/integrations/bsi
# https://www.make.com/en/integrations/bringdata
# https://www.make.com/en/integrations/brightflag
# https://www.make.com/en/integrations/brain-pod-ai
# https://www.make.com/en/integrations/botsheets
# https://www.make.com/en/integrations/botdistrikt
# https://www.make.com/en/integrations/boost-hub
# https://www.make.com/en/integrations/boloforms
# https://www.make.com/en/integrations/bluesky-by-unshape
# https://www.make.com/en/integrations/bluelink
# https://www.make.com/en/integrations/bing-spell-check
# https://www.make.com/en/integrations/bind-erp
# https://www.make.com/en/integrations/billsby
# https://www.make.com/en/integrations/billplz
# https://www.make.com/en/integrations/bigcommerce
# https://www.make.com/en/integrations/betty-blocks
# https://www.make.com/en/integrations/bellbird
# https://www.make.com/en/integrations/behavior-sales
# https://www.make.com/en/integrations/becon
# https://www.make.com/en/integrations/barcode
# https://www.make.com/en/integrations/banqup
# https://www.make.com/en/integrations/bambuser
# https://www.make.com/en/integrations/azure-openai
# https://www.make.com/en/integrations/axosoft
# https://www.make.com/en/integrations/automizy
# https://www.make.com/en/integrations/automation-anywhere
# https://www.make.com/en/integrations/authvia
# https://www.make.com/en/integrations/autentique
# https://www.make.com/en/integrations/aunoa
# https://www.make.com/en/integrations/atspoke
# https://www.make.com/en/integrations/atarim
# https://www.make.com/en/integrations/assembly-ai
# https://www.make.com/en/integrations/aspsms
# https://www.make.com/en/integrations/archive
# https://www.make.com/en/integrations/arbox
# https://www.make.com/en/integrations/ios
# https://www.make.com/en/integrations/announcekit
# https://www.make.com/en/integrations/android
# https://www.make.com/en/integrations/altoviz
# https://www.make.com/en/integrations/all-images-ai
# https://www.make.com/en/integrations/airmeet
# https://www.make.com/en/integrations/ai-engine
# https://www.make.com/en/integrations/agencyjoy
# https://www.make.com/en/integrations/adobe-cc-libraries
# https://www.make.com/en/integrations/manageengine-admanager
# https://www.make.com/en/integrations/addme
# https://www.make.com/en/integrations/acymailing
# https://www.make.com/en/integrations/acuity
# https://www.make.com/en/integrations/activedemand
# https://www.make.com/en/integrations/fitpasscalltracking
# https://www.make.com/en/integrations/sixzerotwo-sofa
# https://www.make.com/en/integrations/threescribe-transcription
# https://www.make.com/en/integrations/two-chat
# https://www.make.com/en/integrations/ten-to-eight

# %%
cookies = {
    'last_touch_gclid': 'undefined',
    'first_touch_gclid': 'undefined',
    'first_touch_landing_page': 'https%3A//www.make.com/en',
    'gb_anonymous_id': '4d967744-c4b8-41b6-9f90-d802fdb6bd2e',
    'rl_page_init_referrer': 'RudderEncrypt%3AU2FsdGVkX1%2FCz9PRIUWfpw55RZZzB90hnV2RmGpzB%2Bc%3D',
    'rl_page_init_referring_domain': 'RudderEncrypt%3AU2FsdGVkX18Buyn6d3%2B%2FZ%2BdkINFvxspfeXihCa3tEmk%3D',
    '_ga': 'GA1.1.1543941994.1716808364',
    'poptin_old_user': 'true',
    'poptin_user_id': '0.83emxpg2gfb',
    'poptin_user_ip': '156.207.60.19',
    'poptin_user_country_code': 'false',
    'poptin_session_account_b242bb2954926': 'true',
    'poptin_c_visitor': 'true',
    '_gcl_au': '1.1.13046725.1716808366',
    '_fbp': 'fb.1.1716808367190.548965802',
    'first_touch_landing_page_query': '%3Fcommunity%3D1%26verified%3D1',
    'OptanonAlertBoxClosed': '2024-05-27T11:12:55.793Z',
    '_hjSessionUser_2919042': 'eyJpZCI6IjgwNmJiZjg5LTY1OTMtNWY5MS1iYjNjLTUwZDQ1ZmU4ZGNlYiIsImNyZWF0ZWQiOjE3MTY4MDgzNjQ4NDcsImV4aXN0aW5nIjp0cnVlfQ==',
    'last_touch_landing_page_query': '',
    'first_touch_referral_url': 'http%3A//localhost%3A8888/',
    'poptin_referrer': '',
    'last_touch_landing_page': 'https%3A//www.make.com/en/integrations/google-sheets',
    'last_touch_referral_url': '',
    'referral_url': '',
    'visitor_id1009662': '179264686',
    'visitor_id1009662-hash': '1519c6c73d563505d3864a715df232c09d12f131ebe0cd353812b4f58d2c6c0d06c659c3e81d67c117cb2ec8215ee459825eaa67',
    '__cf_bm': '1kTgSA4sIMaW0D3T75liMBg5ZxRIxmWW7b_0DF0LTXQ-1716836483-1.0.1.1-uWF4cAaHH6BQEgatTwbESQ__oIBXbWuCkay8YUiPfiswxwA9loQjfPXvLPeWGK76UHod9WxnaSwmJJViQmUFMA',
    'rl_user_id': 'RudderEncrypt%3AU2FsdGVkX1%2BCCgdB42kQJtAjWsRJozHOuk0iMPy5wjQ%3D',
    'rl_trait': 'RudderEncrypt%3AU2FsdGVkX1%2Bg6ToT1Ywws2w%2BLullpd8BXty5QNALWUo%3D',
    'rl_group_id': 'RudderEncrypt%3AU2FsdGVkX1%2BL2H9TPM%2Be8Vf0OFQYEAJWhLtI%2B5n4Yck%3D',
    'rl_group_trait': 'RudderEncrypt%3AU2FsdGVkX18SuOz9gHkxMUdJTn7tGaf%2BVJ1xwJfJTe0%3D',
    'rl_anonymous_id': 'RudderEncrypt%3AU2FsdGVkX1913wNUN4YLhOjZxyk4j%2FhDA0lqzJLqGyi4MbY0tjnvpaBsv0gKI1T1OtVEbO3Ki%2FCwbyF9ifk89Q%3D%3D',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Mon+May+27+2024+22%3A06%3A41+GMT%2B0300+(Eastern+European+Summer+Time)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=758c16f0-df45-4741-813f-b146c2926d1d&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1%2CC0002%3A1&AwaitingReconsent=false&geolocation=EG%3BKN',
    'rl_session': 'RudderEncrypt%3AU2FsdGVkX1%2BehoyhNrQ8XjNmBJS4C20m8ZbMk7WpBM5Z70ZInV8TRDUWJzRewaOErFW5ukLAdpdO%2Fk0HXvujRL6zjo6JnO4HdmCeaS7AIhFY3anWcoWEXDe68pDhruhDa%2BGOA3R8uXmi7rCt4Y4MEw%3D%3D',
    '_ga_MY0CJTCDSF': 'GS1.1.1716836799.6.1.1716836809.50.0.0',
    'make_session_id': '1716836799',
    '_uetsid': '0c5498001c1a11efbdf0954c2b28279f',
    '_uetvid': '0c54bd001c1a11ef99362fa261b0d15d',
    '_hjSession_2919042': 'eyJpZCI6IjY0ZWFhN2JkLTVjYTctNDQ1YS05NTQ0LTQzMmZjMTE1ZGZhOCIsImMiOjE3MTY4MzY4MTYzMDYsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=',
    '_rdt_uuid': '1716808366676.355e1e32-bf41-4c7d-87c5-36507b532296',
    'poptin_session': 'true',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Google Chrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
}

response2 = requests.get('https://www.make.com/en/integrations/google-sheets', headers=headers)

# %%
response2.status_code
# Out:
# 200

# %%
response2.url
# Out:
# 'https://www.make.com/en/integrations/google-sheets'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response2.content, 'html.parser')

# %%
from pprint import pprint
pprint(soup.find('script', id="__NEXT_DATA__"))
# Out:
# <script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"app":{"sys":{"id":"app-google-sheets","__typename":"Sys"},"__typename":"App","name":"Google Sheets","slug":"google-sheets","owner":null,"ownerRelationship":null,"ratingValue":null,"ratingCount":null,"reviewCount":null,"theme":"#0fa763","beta":false,"premium":false,"description":"Create your customized scenario with Make. Automate repetitive tasks involved in using Google Sheets and make your work easier.","useCustomDescription":false,"keywords":null,"subTitle":null,"videoUrl":null,"subDescription":null,"actionsJson":[{"acid":false,"name":"Add a Conditional Format Rule","slug":"addConditionalFormatting","listener":false,"description":"Creates a new conditional format rule at the given index. All subsequent rules' indexes are incremented."},{"acid":false,"name":"Add a Row","slug":"addRow","listener":false,"description":"Appends a new row to the bottom of the table."},{"acid":false,"name":"Add a Sheet","slug":"addSheet","listener":false,"description":"Adds a new sheet."},{"acid":false,"name":"Clear a Cell","slug":"clearCell","listener":false,"description":"Cleares a specific cell."},{"acid":false,"name":"Clear a Row","slug":"clearRow","listener":false,"description":"Clears values from a specific row."},{"acid":false,"name":"Clear Values from a Range","slug":"clearValuesFromRange","listener":false,"description":"Clears a specified range of values from a spreadsheet."},{"acid":false,"name":"Copy a Sheet","slug":"copyASheet","listener":false,"description":"Copies a sheet to another spreadsheet."},{"acid":false,"name":"Create a Spreadsheet","slug":"createSpreadsheet","listener":false,"description":"Creates a new spreadsheet."},{"acid":false,"name":"Create a Spreadsheet from a Template","slug":"createASpreadsheetFromATemplate","listener":false,"description":"Creates a new spreadsheet from a template sheet."},{"acid":false,"name":"Delete a Conditional Format Rule","slug":"deleteConditionalFormatting","listener":false,"description":"Deletes a conditional format rule at the given index. All subsequent rules' indexes are decremented."},{"acid":false,"name":"Delete a Row","slug":"deleteRow","listener":false,"description":"Deletes a specific row."},{"acid":false,"name":"Delete a Sheet","slug":"deleteSheet","listener":false,"description":"Deletes a specific sheet."},{"acid":false,"name":"Get a Cell","slug":"getCell","listener":false,"description":"Gets a specific cell."},{"acid":false,"name":"Make an API Call","slug":"makeAPICall","listener":false,"description":"Performs an arbitrary authorized API call."},{"acid":false,"name":"Perform a Function - Responder","slug":"performFunctionResponder","listener":false,"description":"Returns processed data as a result of the MAKE_FUNCTION or INTEGROMAT function. Sheets Add-On required."},{"acid":false,"name":"Rename a Sheet","slug":"renameSheet","listener":false,"description":"Renames a specific sheet."},{"acid":false,"name":"Update a Cell","slug":"updateCell","listener":false,"description":"Updates a specific cell."},{"acid":false,"name":"Update a Row","slug":"updateRow","listener":false,"description":"Updates a row."}],"aggregatorsJson":[],"feedersJson":[],"searchesJson":[{"acid":false,"name":"Get Range Values","slug":"getSheetContent","listener":false,"description":"Gets a range content."},{"acid":false,"name":"List Sheets","slug":"listSheets","listener":false,"description":"Gets a list of all sheets in a spreadsheet."},{"acid":false,"name":"Search Rows","slug":"filterRows","listener":false,"description":"Returns results matching the given criteria."},{"acid":false,"name":"Search Rows (Advanced)","slug":"filterRowsAdvanced","listener":false,"description":"Returns results matching the given criteria. This module doesn't return a row number."}],"transformersJson":[],"triggersJson":[{"acid":true,"name":"Perform a Function","slug":"performFunction","listener":true,"description":"Receives data passed to the function MAKE_FUNCTION ...

# %%
json_str = soup.find('script', id="__NEXT_DATA__").text
json_data = json.loads(json_str)

# %%
df = pd.DataFrame(entities)

# %%
def extract_description(client, plugin_slug, plugin_name):

    base_url = "https://www.make.com/en/integrations/"
    attemps = 3
    for attempt in range(attemps):
        response = client.get(base_url + plugin_slug)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            json_str = soup.find('script', id="__NEXT_DATA__").text
            json_data = json.loads(json_str)
            description = json_data['props']['pageProps']['appDetails']['description'].replace(r"{name}", plugin_name)
            return description
        else:
            sleep(5)
            
            if attempt == attemps -1:
                print(response.status_code, response.text)
                print(f"Error in plugin page: {df['name']}")
                return None

# %%
cookies = {
    'last_touch_gclid': 'undefined',
    'first_touch_gclid': 'undefined',
    'first_touch_landing_page': 'https%3A//www.make.com/en',
    'gb_anonymous_id': '4d967744-c4b8-41b6-9f90-d802fdb6bd2e',
    'rl_page_init_referrer': 'RudderEncrypt%3AU2FsdGVkX1%2FCz9PRIUWfpw55RZZzB90hnV2RmGpzB%2Bc%3D',
    'rl_page_init_referring_domain': 'RudderEncrypt%3AU2FsdGVkX18Buyn6d3%2B%2FZ%2BdkINFvxspfeXihCa3tEmk%3D',
    '_ga': 'GA1.1.1543941994.1716808364',
    'poptin_old_user': 'true',
    'poptin_user_id': '0.83emxpg2gfb',
    'poptin_user_ip': '156.207.60.19',
    'poptin_user_country_code': 'false',
    'poptin_session_account_b242bb2954926': 'true',
    'poptin_c_visitor': 'true',
    '_gcl_au': '1.1.13046725.1716808366',
    '_fbp': 'fb.1.1716808367190.548965802',
    'first_touch_landing_page_query': '%3Fcommunity%3D1%26verified%3D1',
    'OptanonAlertBoxClosed': '2024-05-27T11:12:55.793Z',
    '_hjSessionUser_2919042': 'eyJpZCI6IjgwNmJiZjg5LTY1OTMtNWY5MS1iYjNjLTUwZDQ1ZmU4ZGNlYiIsImNyZWF0ZWQiOjE3MTY4MDgzNjQ4NDcsImV4aXN0aW5nIjp0cnVlfQ==',
    'last_touch_landing_page_query': '',
    'first_touch_referral_url': 'http%3A//localhost%3A8888/',
    'poptin_referrer': '',
    'last_touch_landing_page': 'https%3A//www.make.com/en/integrations/google-sheets',
    'last_touch_referral_url': '',
    'referral_url': '',
    'visitor_id1009662': '179264686',
    'visitor_id1009662-hash': '1519c6c73d563505d3864a715df232c09d12f131ebe0cd353812b4f58d2c6c0d06c659c3e81d67c117cb2ec8215ee459825eaa67',
    '__cf_bm': '1kTgSA4sIMaW0D3T75liMBg5ZxRIxmWW7b_0DF0LTXQ-1716836483-1.0.1.1-uWF4cAaHH6BQEgatTwbESQ__oIBXbWuCkay8YUiPfiswxwA9loQjfPXvLPeWGK76UHod9WxnaSwmJJViQmUFMA',
    'rl_user_id': 'RudderEncrypt%3AU2FsdGVkX1%2BCCgdB42kQJtAjWsRJozHOuk0iMPy5wjQ%3D',
    'rl_trait': 'RudderEncrypt%3AU2FsdGVkX1%2Bg6ToT1Ywws2w%2BLullpd8BXty5QNALWUo%3D',
    'rl_group_id': 'RudderEncrypt%3AU2FsdGVkX1%2BL2H9TPM%2Be8Vf0OFQYEAJWhLtI%2B5n4Yck%3D',
    'rl_group_trait': 'RudderEncrypt%3AU2FsdGVkX18SuOz9gHkxMUdJTn7tGaf%2BVJ1xwJfJTe0%3D',
    'rl_anonymous_id': 'RudderEncrypt%3AU2FsdGVkX1913wNUN4YLhOjZxyk4j%2FhDA0lqzJLqGyi4MbY0tjnvpaBsv0gKI1T1OtVEbO3Ki%2FCwbyF9ifk89Q%3D%3D',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Mon+May+27+2024+22%3A06%3A41+GMT%2B0300+(Eastern+European+Summer+Time)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=758c16f0-df45-4741-813f-b146c2926d1d&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1%2CC0002%3A1&AwaitingReconsent=false&geolocation=EG%3BKN',
    'rl_session': 'RudderEncrypt%3AU2FsdGVkX1%2BehoyhNrQ8XjNmBJS4C20m8ZbMk7WpBM5Z70ZInV8TRDUWJzRewaOErFW5ukLAdpdO%2Fk0HXvujRL6zjo6JnO4HdmCeaS7AIhFY3anWcoWEXDe68pDhruhDa%2BGOA3R8uXmi7rCt4Y4MEw%3D%3D',
    '_ga_MY0CJTCDSF': 'GS1.1.1716836799.6.1.1716836809.50.0.0',
    'make_session_id': '1716836799',
    '_uetsid': '0c5498001c1a11efbdf0954c2b28279f',
    '_uetvid': '0c54bd001c1a11ef99362fa261b0d15d',
    '_hjSession_2919042': 'eyJpZCI6IjY0ZWFhN2JkLTVjYTctNDQ1YS05NTQ0LTQzMmZjMTE1ZGZhOCIsImMiOjE3MTY4MzY4MTYzMDYsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=',
    '_rdt_uuid': '1716808366676.355e1e32-bf41-4c7d-87c5-36507b532296',
    'poptin_session': 'true',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
    'priority': 'u=0, i',
    'sec-ch-ua': '"Google Chrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
}

with requests.Session() as session:
    session.headers.update(headers)
    session.cookies.update(cookies)
    
    description = df.iloc[400:410, :].apply(lambda row: extract_description(session, row['slug'], row['name']), axis=1)
    print(description)
# Out:
# 400    Connect Looker Studio with any of your favorit...
# 401    Connect EspoCRM with any of your favorite apps...
# 402    Connect Encharge with any of your favorite app...
# 403    Connect Dropcontact with any of your favorite ...
# 404    Connect Databox with any of your favorite apps...
# 405    Connect Auth0 with any of your favorite apps i...
# 406    Connect Zoho Projects with any of your favorit...
# 407    Connect ServiceM8 with any of your favorite ap...
# 408    Connect ReceitaWS with any of your favorite ap...
# 409    Connect Poptin with any of your favorite apps ...
# dtype: object

# %%
description[3]
# Out:
# 'Connect OpenAI (ChatGPT, Whisper, DALL-E) with any of your favorite apps in just a few clicks. Design, build, and automate anything for your work by integrating apps like OpenAI (ChatGPT, Whisper, DALL-E) to create visual automated workflows. Choose from thousands of ready-made apps or use our no-code toolkit to connect to apps not yet in our library.'

# %%
json_data['props']['pageProps']['appDetails']['description'].replace(r"{name}", 'Google Sheet')
# Out:
# 'Connect Google Sheet with any of your favorite apps in just a few clicks. Design, build, and automate anything for your work by integrating apps like Google Sheet to create visual automated workflows. Choose from thousands of ready-made apps or use our no-code toolkit to connect to apps not yet in our library.'

# %%
for key, item in json_data['props']['pageProps']['app'].items():
    if 'Json' in key and item != []:
        final_key = key.rsplit('Json', 1)[0].title()
        pprint(item)
        print(final_key)
# Out:
# [{'acid': False,
#   'description': 'Creates a new conditional format rule at the given index. '
#                  "All subsequent rules' indexes are incremented.",
#   'listener': False,
#   'name': 'Add a Conditional Format Rule',
#   'slug': 'addConditionalFormatting'},
#  {'acid': False,
#   'description': 'Appends a new row to the bottom of the table.',
#   'listener': False,
#   'name': 'Add a Row',
#   'slug': 'addRow'},
#  {'acid': False,
#   'description': 'Adds a new sheet.',
#   'listener': False,
#   'name': 'Add a Sheet',
#   'slug': 'addSheet'},
#  {'acid': False,
#   'description': 'Cleares a specific cell.',
#   'listener': False,
#   'name': 'Clear a Cell',
#   'slug': 'clearCell'},
#  {'acid': False,
#   'description': 'Clears values from a specific row.',
#   'listener': False,
#   'name': 'Clear a Row',
#   'slug': 'clearRow'},
#  {'acid': False,
#   'description': 'Clears a specified range of values from a spreadsheet.',
#   'listener': False,
#   'name': 'Clear Values from a Range',
#   'slug': 'clearValuesFromRange'},
#  {'acid': False,
#   'description': 'Copies a sheet to another spreadsheet.',
#   'listener': False,
#   'name': 'Copy a Sheet',
#   'slug': 'copyASheet'},
#  {'acid': False,
#   'description': 'Creates a new spreadsheet.',
#   'listener': False,
#   'name': 'Create a Spreadsheet',
#   'slug': 'createSpreadsheet'},
#  {'acid': False,
#   'description': 'Creates a new spreadsheet from a template sheet.',
#   'listener': False,
#   'name': 'Create a Spreadsheet from a Template',
#   'slug': 'createASpreadsheetFromATemplate'},
#  {'acid': False,
#   'description': 'Deletes a conditional format rule at the given index. All '
#                  "subsequent rules' indexes are decremented.",
#   'listener': False,
#   'name': 'Delete a Conditional Format Rule',
#   'slug': 'deleteConditionalFormatting'},
#  {'acid': False,
#   'description': 'Deletes a specific row.',
#   'listener': False,
#   'name': 'Delete a Row',
#   'slug': 'deleteRow'},
#  {'acid': False,
#   'description': 'Deletes a specific sheet.',
#   'listener': False,
#   'name': 'Delete a Sheet',
#   'slug': 'deleteSheet'},
#  {'acid': False,
#   'description': 'Gets a specific cell.',
#   'listener': False,
#   'name': 'Get a Cell',
#   'slug': 'getCell'},
#  {'acid': False,
#   'description': 'Performs an arbitrary authorized API call.',
#   'listener': False,
#   'name': 'Make an API Call',
#   'slug': 'makeAPICall'},
#  {'acid': False,
#   'description': 'Returns processed data as a result of the MAKE_FUNCTION or '
#                  'INTEGROMAT function. Sheets Add-On required.',
#   'listener': False,
#   'name': 'Perform a Function - Responder',
#   'slug': 'performFunctionResponder'},
#  {'acid': False,
#   'description': 'Renames a specific sheet.',
#   'listener': False,
#   'name': 'Rename a Sheet',
#   'slug': 'renameSheet'},
#  {'acid': False,
#   'description': 'Updates a specific cell.',
#   'listener': False,
#   'name': 'Update a Cell',
#   'slug': 'updateCell'},
#  {'acid': False,
#   'description': 'Updates a row.',
#   'listener': False,
#   'name': 'Update a Row',
#   'slug': 'updateRow'}]
# Actions
# [{'acid': False,
#   'description': 'Gets a range content.',
#   'listener': False,
#   'name': 'Get Range Values',
#   'slug': 'getSheetContent'},
#  {'acid': False,
#   'description': 'Gets a list of all sheets in a spreadsheet.',
#   'listener': False,
#   'name': 'List Sheets',
#   'slug': 'listSheets'},
#  {'acid': False,
#   'description': 'Returns results matching the given criteria.',
#   'listener': False,
#   'name': 'Search Rows',
#   'slug': 'filterRows'},
#  {'acid': False,
#   'description': 'Returns results matching the given criteria. This module '
#                  "doesn't return a row number.",
#   'listener': False,
#   'name': 'Search Rows (Advanced)',
#   'slug': 'filterRowsAdvanced'}]
# Searches
# [{'acid': True,
#   'description': 'Receives data passed to the function MAKE_FUNCTION or '
#                  'INTEGROMAT used in a sheet. Sheets Add-On required.',
#   'listener': True,
#   'name': 'Perform a Function',
#   'slug': 'performFunction'},
#  {'acid': True,
#   'description': 'Triggers when a cell is updated. Watches only changes made '
#                  'in Google Sheet app. Sheets Add-On required.',
#   'listener': True,
#   'name': 'Watch Changes',
#   'slug': 'watchUpdatedCells'},
#  {'acid': True,
#   'description': 'Triggers when a new row is added.',
#   'listener': False,
#   'name': 'Watch New Rows',
#   'slug': 'watchRows'}]
# Triggers

# %%
for key, item in json_data['props']['pageProps']['app'].items():
    if 'Json' in key and item != []:
        final_key = key.rsplit('Json', 1)[0].title()
        formatted = '\n'.join([f"{i['name']}: {i['description']}" for i in item])
#         print(final_key)
#         print(formatted)
#         final.append[final_key] = formatted
final
# Out:
# [{'Plugin Name': 'Google Sheets',
#   'Rank': 1,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/google-sheets'},
#  {'Plugin Name': 'Gmail',
#   'Rank': 2,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/google-email'},
#  {'Plugin Name': 'Airtable',
#   'Rank': 3,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/airtable'},
#  {'Plugin Name': 'OpenAI (ChatGPT, Whisper, DALL-E)',
#   'Rank': 4,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/openai-gpt-3'},
#  {'Plugin Name': 'Google Drive',
#   'Rank': 5,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-drive'},
#  {'Plugin Name': 'Notion',
#   'Rank': 6,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/notion'},
#  {'Plugin Name': 'Slack',
#   'Rank': 7,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/slack'},
#  {'Plugin Name': 'Telegram Bot',
#   'Rank': 8,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/telegram'},
#  {'Plugin Name': 'Facebook Lead Ads',
#   'Rank': 9,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-lead-ads'},
#  {'Plugin Name': 'Google Calendar',
#   'Rank': 10,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/google-calendar'},
#  {'Plugin Name': 'Google Docs',
#   'Rank': 11,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-docs'},
#  {'Plugin Name': 'Microsoft 365 Email',
#   'Rank': 12,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/microsoft-email'},
#  {'Plugin Name': 'Monday',
#   'Rank': 13,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/monday'},
#  {'Plugin Name': 'HubSpot CRM',
#   'Rank': 14,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/hubspotcrm'},
#  {'Plugin Name': 'ClickUp',
#   'Rank': 15,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/clickup'},
#  {'Plugin Name': 'Facebook Pages',
#   'Rank': 16,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-pages'},
#  {'Plugin Name': 'Discord',
#   'Rank': 17,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/discord'},
#  {'Plugin Name': 'Instagram for Business',
#   'Rank': 18,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/instagram-business'},
#  {'Plugin Name': 'Webflow',
#   'Rank': 19,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/webflow'},
#  {'Plugin Name': 'WooCommerce',
#   'Rank': 20,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/woocommerce'},
#  {'Plugin Name': 'Pipedrive CRM',
#   'Rank': 21,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/pipedrive'},
#  {'Plugin Name': 'Shopify',
#   'Rank': 22,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/shopify'},
#  {'Plugin Name': 'Trello',
#   'Rank': 23,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/trello'},
#  {'Plugin Name': 'WordPress',
#   'Rank': 24,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/wordpress'},
#  {'Plugin Name': 'Dropbox',
#   'Rank': 25,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/dropbox'},
#  {'Plugin Name': 'Stripe',
#   'Rank': 26,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/stripe'},
#  {'Plugin Name': 'ActiveCampaign',
#   'Rank': 27,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/activecampaign'},
#  {'Plugin Name': 'Brevo',
#   'Rank': 28,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendinblue'},
#  {'Plugin Name': 'Calendly',
#   'Rank': 29,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/calendly'},
#  {'Plugin Name': 'Google Forms',
#   'Rank': 30,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/google-forms'},
#  {'Plugin Name': 'Mailchimp',
#   'Rank': 31,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailchimp'},
#  {'Plugin Name': 'Microsoft 365 Excel',
#   'Rank': 32,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/microsoft-excel'},
#  {'Plugin Name': 'Google Contacts',
#   'Rank': 33,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/google-contacts'},
#  {'Plugin Name': 'Jotform',
#   'Rank': 34,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/jotform'},
#  {'Plugin Name': 'Typeform',
#   'Rank': 35,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/typeform'},
#  {'Plugin Name': 'Tally',
#   'Rank': 36,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/tally'},
#  {'Plugin Name': 'Salesforce',
#   'Rank': 37,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/salesforce'},
#  {'Plugin Name': 'Twilio',
#   'Rank': 38,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/twilio'},
#  {'Plugin Name': 'OneDrive',
#   'Rank': 39,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/onedrive'},
#  {'Plugin Name': 'LinkedIn',
#   'Rank': 40,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/linkedin'},
#  {'Plugin Name': 'LINE',
#   'Rank': 41,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/line'},
#  {'Plugin Name': 'MySQL',
#   'Rank': 42,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/mysql'},
#  {'Plugin Name': 'Asana',
#   'Rank': 43,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/asana'},
#  {'Plugin Name': 'SendGrid',
#   'Rank': 44,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendgrid'},
#  {'Plugin Name': 'Make',
#   'Rank': 45,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/make'},
#  {'Plugin Name': 'X (formerly Twitter)',
#   'Rank': 46,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/twitter'},
#  {'Plugin Name': 'Xero',
#   'Rank': 47,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/xero'},
#  {'Plugin Name': 'Todoist',
#   'Rank': 48,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/todoist'},
#  {'Plugin Name': 'Manychat',
#   'Rank': 49,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/manychat'},
#  {'Plugin Name': 'QuickBooks',
#   'Rank': 50,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/quickbooks'},
#  {'Plugin Name': 'PDF.co',
#   'Rank': 51,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdf-co'},
#  {'Plugin Name': 'Survey123',
#   'Rank': 52,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/survey123'},
#  {'Plugin Name': 'HighLevel LeadConnector',
#   'Rank': 53,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/highlevel'},
#  {'Plugin Name': 'Zoom',
#   'Rank': 54,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/zoom'},
#  {'Plugin Name': 'CloudConvert',
#   'Rank': 55,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/cloudconvert'},
#  {'Plugin Name': 'Jira Cloud Platform',
#   'Rank': 56,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/jira'},
#  {'Plugin Name': 'Zoho CRM',
#   'Rank': 57,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/zohocrm'},
#  {'Plugin Name': 'WhatsApp Business Cloud',
#   'Rank': 58,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/whatsapp-business-cloud'},
#  {'Plugin Name': 'Google Cloud Firestore',
#   'Rank': 59,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/google-cloud-firestore'},
#  {'Plugin Name': 'Microsoft 365 Calendar',
#   'Rank': 60,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/microsoft-calendar'},
#  {'Plugin Name': 'PandaDoc',
#   'Rank': 61,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pandadoc'},
#  {'Plugin Name': 'Facebook Insights',
#   'Rank': 62,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-insights'},
#  {'Plugin Name': 'MailerLite',
#   'Rank': 63,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailerlite2'},
#  {'Plugin Name': 'Google Maps',
#   'Rank': 64,
#   'Category': 'Travel',
#   'url': 'https://www.make.com/en/integrations/google-maps'},
#  {'Plugin Name': 'Google Slides',
#   'Rank': 65,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-slides'},
#  {'Plugin Name': 'Microsoft SharePoint Online',
#   'Rank': 66,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/microsoft-sharepoint'},
#  {'Plugin Name': 'Blogger',
#   'Rank': 67,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/blogger'},
#  {'Plugin Name': 'AWS S3',
#   'Rank': 68,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/aws-s3'},
#  {'Plugin Name': 'MailerLite Classic',
#   'Rank': 69,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailerlite'},
#  {'Plugin Name': 'Microsoft Word Templates',
#   'Rank': 70,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/docx-templater'},
#  {'Plugin Name': 'Bubble',
#   'Rank': 71,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/bubble'},
#  {'Plugin Name': 'Elementor',
#   'Rank': 72,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/elementor'},
#  {'Plugin Name': 'Printify',
#   'Rank': 73,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/printify'},
#  {'Plugin Name': 'PostgreSQL',
#   'Rank': 74,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/postgres'},
#  {'Plugin Name': 'Gravity Forms',
#   'Rank': 75,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/gravity-forms'},
#  {'Plugin Name': 'Z-API',
#   'Rank': 76,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/z-api'},
#  {'Plugin Name': 'Microsoft Teams',
#   'Rank': 77,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/microsoft-teams'},
#  {'Plugin Name': 'Klaviyo',
#   'Rank': 78,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/klaviyo'},
#  {'Plugin Name': 'Google Tasks',
#   'Rank': 79,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/google-tasks'},
#  {'Plugin Name': 'Contact Form 7',
#   'Rank': 80,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/contact-form-seven'},
#  {'Plugin Name': 'Bitly',
#   'Rank': 81,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/bitly'},
#  {'Plugin Name': 'Zendesk',
#   'Rank': 82,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/zendesk'},
#  {'Plugin Name': 'Facebook Conversions API',
#   'Rank': 83,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-conversions-api'},
#  {'Plugin Name': 'Ninox',
#   'Rank': 84,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/ninox'},
#  {'Plugin Name': 'Zapier',
#   'Rank': 85,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/zapier'},
#  {'Plugin Name': 'Buffer',
#   'Rank': 86,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/buffer'},
#  {'Plugin Name': 'BigQuery',
#   'Rank': 87,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/google-bigquery'},
#  {'Plugin Name': 'Facebook Custom Audiences',
#   'Rank': 88,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-custom-audiences'},
#  {'Plugin Name': 'Toggl Track',
#   'Rank': 89,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/toggl'},
#  {'Plugin Name': 'Cognito Forms',
#   'Rank': 90,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/cognitoforms'},
#  {'Plugin Name': 'Etsy',
#   'Rank': 91,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/etsy'},
#  {'Plugin Name': 'Microsoft SQL Server',
#   'Rank': 92,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/mssql'},
#  {'Plugin Name': 'Pinterest',
#   'Rank': 93,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/pinterest'},
#  {'Plugin Name': 'HTML/CSS to Image',
#   'Rank': 94,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/html-css-to-image'},
#  {'Plugin Name': 'Google Chat',
#   'Rank': 95,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/google-hangouts-chat'},
#  {'Plugin Name': 'Knack',
#   'Rank': 96,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/knack'},
#  {'Plugin Name': 'DocuSign',
#   'Rank': 97,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/docusign'},
#  {'Plugin Name': 'Twitch',
#   'Rank': 98,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/twitch'},
#  {'Plugin Name': 'Google Cloud Vision',
#   'Rank': 99,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/googlecloudvision'},
#  {'Plugin Name': 'Glide',
#   'Rank': 100,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/glide'},
#  {'Plugin Name': 'Mailgun',
#   'Rank': 101,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailgun'},
#  {'Plugin Name': 'Freshdesk',
#   'Rank': 102,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/freshdesk'},
#  {'Plugin Name': 'Spotify',
#   'Rank': 103,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/spotify'},
#  {'Plugin Name': 'ClickSend SMS',
#   'Rank': 104,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/clicksend'},
#  {'Plugin Name': 'RD Station',
#   'Rank': 105,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/rd-station'},
#  {'Plugin Name': 'Cuttly',
#   'Rank': 106,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/cuttly'},
#  {'Plugin Name': 'Coda',
#   'Rank': 107,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/coda'},
#  {'Plugin Name': 'Kommo',
#   'Rank': 108,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/amo-crm'},
#  {'Plugin Name': 'Bitrix24',
#   'Rank': 109,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/bitrix24'},
#  {'Plugin Name': 'Pipefy',
#   'Rank': 110,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/pipefy'},
#  {'Plugin Name': 'Short.io',
#   'Rank': 111,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/short-cm'},
#  {'Plugin Name': 'Microsoft To Do',
#   'Rank': 112,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/microsoft-to-do'},
#  {'Plugin Name': 'reddit',
#   'Rank': 113,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/reddit'},
#  {'Plugin Name': 'Clockify',
#   'Rank': 114,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/clockify'},
#  {'Plugin Name': 'SendPulse',
#   'Rank': 115,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendpulse'},
#  {'Plugin Name': 'Rav Messer / Responder',
#   'Rank': 116,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/rav-messer'},
#  {'Plugin Name': 'Google Workspace Admin',
#   'Rank': 117,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/google-g-suite'},
#  {'Plugin Name': 'Google Ads Conversions',
#   'Rank': 118,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-ads-conversions'},
#  {'Plugin Name': 'Google Analytics 4',
#   'Rank': 119,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/google-analytics-4'},
#  {'Plugin Name': '0CodeKit',
#   'Rank': 120,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/onesaas'},
#  {'Plugin Name': 'PayPal',
#   'Rank': 121,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/paypal'},
#  {'Plugin Name': 'lexoffice',
#   'Rank': 122,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/lexoffice'},
#  {'Plugin Name': 'Google Ads Campaign Management',
#   'Rank': 123,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-ads-campaign-management'},
#  {'Plugin Name': 'Acuity Scheduling',
#   'Rank': 124,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/acuity-scheduling'},
#  {'Plugin Name': 'Keap',
#   'Rank': 125,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/infusionsoft'},
#  {'Plugin Name': 'ConvertKit',
#   'Rank': 126,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/convertkit'},
#  {'Plugin Name': 'Memberstack',
#   'Rank': 127,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/memberstack'},
#  {'Plugin Name': 'Zoho Mail',
#   'Rank': 128,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/zoho-mail'},
#  {'Plugin Name': 'Mailjet',
#   'Rank': 129,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailjet'},
#  {'Plugin Name': 'Intercom',
#   'Rank': 130,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/intercom'},
#  {'Plugin Name': 'Apify',
#   'Rank': 131,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/apify'},
#  {'Plugin Name': 'PrestaShop',
#   'Rank': 132,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/prestashop'},
#  {'Plugin Name': 'Fireberry',
#   'Rank': 133,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/powerlink'},
#  {'Plugin Name': 'Close CRM',
#   'Rank': 134,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/close-crm'},
#  {'Plugin Name': 'PDFMonkey',
#   'Rank': 135,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdfmonkey'},
#  {'Plugin Name': 'LinkedIn Lead Gen Forms',
#   'Rank': 136,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/linkedin-lead-gen-forms'},
#  {'Plugin Name': 'Zoho Books',
#   'Rank': 137,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/zoho-books'},
#  {'Plugin Name': 'PhantomBuster',
#   'Rank': 138,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/phantombuster'},
#  {'Plugin Name': 'ElevenLabs',
#   'Rank': 139,
#   'Category': 'Ai',
#   'url': 'https://www.make.com/en/integrations/elevenlabs'},
#  {'Plugin Name': 'Eden AI',
#   'Rank': 140,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/edenai'},
#  {'Plugin Name': 'Cloudinary',
#   'Rank': 141,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/cloudinary'},
#  {'Plugin Name': 'Google My Business',
#   'Rank': 142,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-my-business'},
#  {'Plugin Name': 'DeepL',
#   'Rank': 143,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/deepl'},
#  {'Plugin Name': 'GitHub',
#   'Rank': 144,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/github'},
#  {'Plugin Name': 'Smoove',
#   'Rank': 145,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/smoove'},
#  {'Plugin Name': 'ShipStation',
#   'Rank': 146,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/shipstation'},
#  {'Plugin Name': 'Hotmart',
#   'Rank': 147,
#   'Category': 'Education',
#   'url': 'https://www.make.com/en/integrations/hotmart'},
#  {'Plugin Name': 'Instagram',
#   'Rank': 148,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/instagram'},
#  {'Plugin Name': 'Podio',
#   'Rank': 149,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/podio'},
#  {'Plugin Name': 'Google Cloud Storage',
#   'Rank': 150,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/google-cloud-storage'},
#  {'Plugin Name': 'Postmark',
#   'Rank': 151,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/postmark'},
#  {'Plugin Name': 'Harvest',
#   'Rank': 152,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/harvest'},
#  {'Plugin Name': 'iLovePDF',
#   'Rank': 153,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/ilovepdf'},
#  {'Plugin Name': 'Adalo',
#   'Rank': 154,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/adalo'},
#  {'Plugin Name': 'Paperform',
#   'Rank': 155,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/paperform'},
#  {'Plugin Name': 'Feedly',
#   'Rank': 156,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/feedly'},
#  {'Plugin Name': 'Google Groups',
#   'Rank': 157,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-groups'},
#  {'Plugin Name': 'Amazon Lambda',
#   'Rank': 158,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/amazon-lambda'},
#  {'Plugin Name': 'Tumblr',
#   'Rank': 159,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/tumblr'},
#  {'Plugin Name': 'ScrapingBee',
#   'Rank': 160,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/scrapingbee'},
#  {'Plugin Name': 'Evernote',
#   'Rank': 161,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/evernote'},
#  {'Plugin Name': 'DocuWare',
#   'Rank': 162,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/docuware'},
#  {'Plugin Name': 'Smartsheet',
#   'Rank': 163,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/smartsheet'},
#  {'Plugin Name': 'Google Translate',
#   'Rank': 164,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/google-translate'},
#  {'Plugin Name': 'Squarespace',
#   'Rank': 165,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/squarespace'},
#  {'Plugin Name': 'Qonto',
#   'Rank': 166,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/qonto'},
#  {'Plugin Name': 'Browse AI',
#   'Rank': 167,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/browse-ai'},
#  {'Plugin Name': 'TikTok',
#   'Rank': 168,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/tiktok'},
#  {'Plugin Name': 'Facebook Ads Campaign Management',
#   'Rank': 169,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/facebook-ads-cm'},
#  {'Plugin Name': 'Teamleader',
#   'Rank': 170,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/teamleader'},
#  {'Plugin Name': 'Google Ads Customer Match',
#   'Rank': 171,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-ads-customer-match'},
#  {'Plugin Name': 'Aircall',
#   'Rank': 172,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/aircall'},
#  {'Plugin Name': 'ClickFunnels',
#   'Rank': 173,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/click-funnels'},
#  {'Plugin Name': 'SoundCloud',
#   'Rank': 174,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/soundcloud'},
#  {'Plugin Name': 'RAYNET CRM',
#   'Rank': 175,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/raynetcrm'},
#  {'Plugin Name': 'Circle',
#   'Rank': 176,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/circle-so'},
#  {'Plugin Name': 'Wix',
#   'Rank': 177,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/wix'},
#  {'Plugin Name': 'Square',
#   'Rank': 178,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/square'},
#  {'Plugin Name': 'Box',
#   'Rank': 179,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/box'},
#  {'Plugin Name': 'CraftMyPDF.com',
#   'Rank': 180,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/craftmypdf-com'},
#  {'Plugin Name': 'APITemplate.io',
#   'Rank': 181,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/apitemplate-io'},
#  {'Plugin Name': 'mailparser.io',
#   'Rank': 182,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/mailparser-io'},
#  {'Plugin Name': 'PrintNode',
#   'Rank': 183,
#   'Category': 'Internet-Of-Things',
#   'url': 'https://www.make.com/en/integrations/printnode'},
#  {'Plugin Name': 'MailerSend',
#   'Rank': 184,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailersend'},
#  {'Plugin Name': 'eSignatures.io',
#   'Rank': 185,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/esignatures-io'},
#  {'Plugin Name': 'GetResponse',
#   'Rank': 186,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/getresponse'},
#  {'Plugin Name': 'Freshsales',
#   'Rank': 187,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/freshsales'},
#  {'Plugin Name': 'MongoDB',
#   'Rank': 188,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/mongodb'},
#  {'Plugin Name': 'IFTTT',
#   'Rank': 189,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/ifttt'},
#  {'Plugin Name': 'Eledo PDF',
#   'Rank': 190,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/eledo'},
#  {'Plugin Name': 'Strava',
#   'Rank': 191,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/strava'},
#  {'Plugin Name': 'Pocket',
#   'Rank': 192,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/pocket'},
#  {'Plugin Name': 'Google Photos',
#   'Rank': 193,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-photos'},
#  {'Plugin Name': 'Fakturoid',
#   'Rank': 194,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/fakturoid'},
#  {'Plugin Name': 'Softr',
#   'Rank': 195,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/softr'},
#  {'Plugin Name': 'Pushover',
#   'Rank': 196,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/pushover'},
#  {'Plugin Name': 'Apollo',
#   'Rank': 197,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/apollo'},
#  {'Plugin Name': 'SmartSuite',
#   'Rank': 198,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/smartsuite'},
#  {'Plugin Name': 'Eventbrite',
#   'Rank': 199,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/eventbrite'},
#  {'Plugin Name': 'lemlist',
#   'Rank': 200,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/lemlist'},
#  {'Plugin Name': 'Zoho Forms',
#   'Rank': 201,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/zoho-forms'},
#  {'Plugin Name': 'Wild Apricot',
#   'Rank': 202,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/wild-apricot'},
#  {'Plugin Name': 'Mautic',
#   'Rank': 203,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mautic'},
#  {'Plugin Name': 'Google Ads Lead Forms',
#   'Rank': 204,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/google-ads-lead-forms'},
#  {'Plugin Name': 'Facebook Messenger',
#   'Rank': 205,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/facebook-messenger'},
#  {'Plugin Name': 'Thinkific',
#   'Rank': 206,
#   'Category': 'Education',
#   'url': 'https://www.make.com/en/integrations/thinkific'},
#  {'Plugin Name': 'Odoo',
#   'Rank': 207,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/odoo'},
#  {'Plugin Name': 'Medium',
#   'Rank': 208,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/medium'},
#  {'Plugin Name': 'Chargebee',
#   'Rank': 209,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/chargebee'},
#  {'Plugin Name': 'WebinarJam',
#   'Rank': 210,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/webinarjam'},
#  {'Plugin Name': 'GitLab',
#   'Rank': 211,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/gitlab'},
#  {'Plugin Name': 'Vtiger CRM',
#   'Rank': 212,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/vtiger'},
#  {'Plugin Name': 'Morning',
#   'Rank': 213,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/morning'},
#  {'Plugin Name': 'Customer.io',
#   'Rank': 214,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/customer-io'},
#  {'Plugin Name': 'Fillout Forms',
#   'Rank': 215,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/fillout'},
#  {'Plugin Name': 'Wave',
#   'Rank': 216,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/wave'},
#  {'Plugin Name': 'RingCentral',
#   'Rank': 217,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/ringcentral'},
#  {'Plugin Name': 'ThriveCart',
#   'Rank': 218,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/thrivecart'},
#  {'Plugin Name': 'ScrapeNinja',
#   'Rank': 219,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/scrapeninja'},
#  {'Plugin Name': 'Basecamp 3',
#   'Rank': 220,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/basecamp3'},
#  {'Plugin Name': 'ChatGuru',
#   'Rank': 221,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/chatguru'},
#  {'Plugin Name': 'Zoho Invoice',
#   'Rank': 222,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/zoho-invoice'},
#  {'Plugin Name': 'beehiiv',
#   'Rank': 223,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/beehiiv'},
#  {'Plugin Name': 'Chatwork',
#   'Rank': 224,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chatwork'},
#  {'Plugin Name': 'Rebrandly',
#   'Rank': 225,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/rebrandly'},
#  {'Plugin Name': 'AWeber',
#   'Rank': 226,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/aweber'},
#  {'Plugin Name': 'Mixpanel',
#   'Rank': 227,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/mixpanel'},
#  {'Plugin Name': 'Google Chrome',
#   'Rank': 228,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chrome'},
#  {'Plugin Name': 'Nextcloud',
#   'Rank': 229,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/nextcloud'},
#  {'Plugin Name': 'Moneybird',
#   'Rank': 230,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/moneybird'},
#  {'Plugin Name': 'ArcGIS Field Maps',
#   'Rank': 231,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/arcgis-field-maps'},
#  {'Plugin Name': 'Responder.live',
#   'Rank': 232,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/responder-live'},
#  {'Plugin Name': 'Foursquare',
#   'Rank': 233,
#   'Category': 'Travel',
#   'url': 'https://www.make.com/en/integrations/foursquare'},
#  {'Plugin Name': 'tawk.to',
#   'Rank': 234,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/tawkto'},
#  {'Plugin Name': 'Bigin by Zoho CRM',
#   'Rank': 235,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/bigin-by-zoho'},
#  {'Plugin Name': 'Sellsy',
#   'Rank': 236,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/sellsy'},
#  {'Plugin Name': 'Custom JS',
#   'Rank': 237,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/custom-js'},
#  {'Plugin Name': 'ActiveTrail',
#   'Rank': 238,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/activetrail'},
#  {'Plugin Name': 'Zoho Creator',
#   'Rank': 239,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/zoho-creator'},
#  {'Plugin Name': 'Tripetto',
#   'Rank': 240,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/tripetto'},
#  {'Plugin Name': 'Microsoft 365 People',
#   'Rank': 241,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/microsoft-people'},
#  {'Plugin Name': 'ZeroBounce',
#   'Rank': 242,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/zerobounce'},
#  {'Plugin Name': 'WPForms',
#   'Rank': 243,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/wpforms'},
#  {'Plugin Name': 'Adobe Commerce',
#   'Rank': 244,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/magento2'},
#  {'Plugin Name': 'Help Scout',
#   'Rank': 245,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/helpscout'},
#  {'Plugin Name': 'Unbounce',
#   'Rank': 246,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/unbounce'},
#  {'Plugin Name': 'Fio banka',
#   'Rank': 247,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/fio'},
#  {'Plugin Name': 'Amazon SES',
#   'Rank': 248,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/amazon-ses'},
#  {'Plugin Name': 'Amazon Seller Central',
#   'Rank': 249,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/amazon-seller-central'},
#  {'Plugin Name': 'Asaas',
#   'Rank': 250,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/asaas'},
#  {'Plugin Name': 'Placid',
#   'Rank': 251,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/placid-app'},
#  {'Plugin Name': 'Ghost',
#   'Rank': 252,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/ghost'},
#  {'Plugin Name': 'Raindrop.io',
#   'Rank': 253,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/raindrop-io'},
#  {'Plugin Name': 'Shortcuts',
#   'Rank': 254,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/shortcuts'},
#  {'Plugin Name': 'Inoreader',
#   'Rank': 255,
#   'Category': 'Lifestyle',
#   'url': 'https://www.make.com/en/integrations/inoreader'},
#  {'Plugin Name': 'Front',
#   'Rank': 256,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/front'},
#  {'Plugin Name': 'Constant Contact',
#   'Rank': 257,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/constant-contact'},
#  {'Plugin Name': 'Drip',
#   'Rank': 258,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/drip'},
#  {'Plugin Name': 'Follow Up Boss',
#   'Rank': 259,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/follow-up-boss'},
#  {'Plugin Name': 'bexio',
#   'Rank': 260,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/bexio'},
#  {'Plugin Name': 'Bannerbear',
#   'Rank': 261,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/bannerbear'},
#  {'Plugin Name': 'Ecomail.cz',
#   'Rank': 262,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/ecomail-cz'},
#  {'Plugin Name': 'WP Webhooks',
#   'Rank': 263,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/wp-webhooks'},
#  {'Plugin Name': 'Unsplash',
#   'Rank': 264,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/unsplash'},
#  {'Plugin Name': 'Teamwork',
#   'Rank': 265,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/teamwork'},
#  {'Plugin Name': 'Microsoft Power BI',
#   'Rank': 266,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/microsoft-power-bi'},
#  {'Plugin Name': 'Zoho Desk',
#   'Rank': 267,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/zoho-desk'},
#  {'Plugin Name': 'Google Cloud Text-to-Speech',
#   'Rank': 268,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/google-cloud-tts'},
#  {'Plugin Name': 'sevDesk',
#   'Rank': 269,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/sevdesk'},
#  {'Plugin Name': 'VideoAsk',
#   'Rank': 270,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/videoask'},
#  {'Plugin Name': 'Kintone',
#   'Rank': 271,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/kintone'},
#  {'Plugin Name': 'Docparser',
#   'Rank': 272,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/docparser'},
#  {'Plugin Name': 'GIPHY',
#   'Rank': 273,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/giphy'},
#  {'Plugin Name': 'BambooHR',
#   'Rank': 274,
#   'Category': 'Hr-Management',
#   'url': 'https://www.make.com/en/integrations/bamboohr'},
#  {'Plugin Name': 'Moskit CRM',
#   'Rank': 275,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/moskitcrm'},
#  {'Plugin Name': 'Mailchimp Transactional Email',
#   'Rank': 276,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/mailchimp-transactional-email'},
#  {'Plugin Name': 'ImgBB',
#   'Rank': 277,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/imgbb'},
#  {'Plugin Name': 'Snowflake',
#   'Rank': 278,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/snowflake'},
#  {'Plugin Name': 'Mastodon',
#   'Rank': 279,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mastodon'},
#  {'Plugin Name': 'Frame.io',
#   'Rank': 280,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/frame-io'},
#  {'Plugin Name': 'ConvertAPI',
#   'Rank': 281,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/convertapi'},
#  {'Plugin Name': 'Beds24',
#   'Rank': 282,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/beds24'},
#  {'Plugin Name': 'Zoho Campaigns',
#   'Rank': 283,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/zoho-campaigns'},
#  {'Plugin Name': 'Teachable',
#   'Rank': 284,
#   'Category': 'Education',
#   'url': 'https://www.make.com/en/integrations/teachable'},
#  {'Plugin Name': 'Invoice Ninja',
#   'Rank': 285,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/invoiceninja'},
#  {'Plugin Name': 'Docupilot',
#   'Rank': 286,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/docupilot'},
#  {'Plugin Name': 'Documint',
#   'Rank': 287,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/documint'},
#  {'Plugin Name': 'AppSheet',
#   'Rank': 288,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/appsheet'},
#  {'Plugin Name': 'Linear',
#   'Rank': 289,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/linear'},
#  {'Plugin Name': 'EverWebinar',
#   'Rank': 290,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/everwebinar'},
#  {'Plugin Name': 'Typebot',
#   'Rank': 291,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/typebot'},
#  {'Plugin Name': 'Survey Monkey',
#   'Rank': 292,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/survey-monkey'},
#  {'Plugin Name': 'Sendcloud',
#   'Rank': 293,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/sendcloud'},
#  {'Plugin Name': 'Vimeo',
#   'Rank': 294,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/vimeo'},
#  {'Plugin Name': 'Pushbullet',
#   'Rank': 295,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/pushbullet'},
#  {'Plugin Name': 'PDF4me',
#   'Rank': 296,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdf4me'},
#  {'Plugin Name': 'Google Meet',
#   'Rank': 297,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/google-meet'},
#  {'Plugin Name': 'ABRA FlexiBee',
#   'Rank': 298,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/flexibee'},
#  {'Plugin Name': 'Tny',
#   'Rank': 299,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/tny'},
#  {'Plugin Name': 'SmartEmailing',
#   'Rank': 300,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/smart-emailing'},
#  {'Plugin Name': 'SendFox',
#   'Rank': 301,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendfox'},
#  {'Plugin Name': 'InforUMobile',
#   'Rank': 302,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/inforumobile'},
#  {'Plugin Name': 'Sendy',
#   'Rank': 303,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/sendy'},
#  {'Plugin Name': 'Missive',
#   'Rank': 304,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/missive'},
#  {'Plugin Name': 'EmailOctopus',
#   'Rank': 305,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/email-octopus'},
#  {'Plugin Name': 'Zoho Inventory',
#   'Rank': 306,
#   'Category': 'App-Families',
#   'url': 'https://www.make.com/en/integrations/zoho-inventory'},
#  {'Plugin Name': 'Miro',
#   'Rank': 307,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/miro'},
#  {'Plugin Name': 'NinjaForms',
#   'Rank': 308,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/ninja-forms'},
#  {'Plugin Name': 'GatewayAPI SMS',
#   'Rank': 309,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/gatewayapi'},
#  {'Plugin Name': 'CoinMarketCap',
#   'Rank': 310,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/coinmarketcap'},
#  {'Plugin Name': 'YouTube',
#   'Rank': 311,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/youtube'},
#  {'Plugin Name': 'YNAB',
#   'Rank': 312,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/ynab'},
#  {'Plugin Name': 'PDF Generator API',
#   'Rank': 313,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdf-generator-api'},
#  {'Plugin Name': 'OpenWeatherMap',
#   'Rank': 314,
#   'Category': 'Travel',
#   'url': 'https://www.make.com/en/integrations/openweathermap'},
#  {'Plugin Name': 'Tabidoo',
#   'Rank': 315,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/tabidoo'},
#  {'Plugin Name': 'MOCO',
#   'Rank': 316,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/moco'},
#  {'Plugin Name': 'SignRequest',
#   'Rank': 317,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/signrequest'},
#  {'Plugin Name': 'Segment',
#   'Rank': 318,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/segment'},
#  {'Plugin Name': 'pdfFiller',
#   'Rank': 319,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pdffiller'},
#  {'Plugin Name': 'Mattermost',
#   'Rank': 320,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/mattermost'},
#  {'Plugin Name': 'Habitica',
#   'Rank': 321,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/habitica'},
#  {'Plugin Name': 'Gumroad',
#   'Rank': 322,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/gumroad'},
#  {'Plugin Name': 'FluentCRM',
#   'Rank': 323,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/fluentcrm'},
#  {'Plugin Name': 'SMSAPI',
#   'Rank': 324,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/smsapi'},
#  {'Plugin Name': 'Livestorm',
#   'Rank': 325,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/livestorm'},
#  {'Plugin Name': 'easybill',
#   'Rank': 326,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/easybill'},
#  {'Plugin Name': 'Respond.io',
#   'Rank': 327,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/respond-io'},
#  {'Plugin Name': 'OneSignal',
#   'Rank': 328,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/onesignal'},
#  {'Plugin Name': 'OneNote',
#   'Rank': 329,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/onenote'},
#  {'Plugin Name': 'Axonaut',
#   'Rank': 330,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/axonaut'},
#  {'Plugin Name': 'Wrike',
#   'Rank': 331,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/wrike'},
#  {'Plugin Name': 'OnceHub',
#   'Rank': 332,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/scheduleonce'},
#  {'Plugin Name': 'Katana Cloud Inventory',
#   'Rank': 333,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/katana-mrp'},
#  {'Plugin Name': 'Snov.io',
#   'Rank': 334,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/snovio'},
#  {'Plugin Name': 'SeaTable',
#   'Rank': 335,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/seatable'},
#  {'Plugin Name': 'JustCall',
#   'Rank': 336,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/justcall'},
#  {'Plugin Name': 'Cloudflare',
#   'Rank': 337,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/cloudflare'},
#  {'Plugin Name': 'Chatbase',
#   'Rank': 338,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chatbase'},
#  {'Plugin Name': 'Streak',
#   'Rank': 339,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/streak'},
#  {'Plugin Name': 'BaseLinker',
#   'Rank': 340,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/baselinker'},
#  {'Plugin Name': 'Skloňování Jmen',
#   'Rank': 341,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/sklonovani-jmen'},
#  {'Plugin Name': 'Kartra',
#   'Rank': 342,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/kartra'},
#  {'Plugin Name': 'CleverReach',
#   'Rank': 343,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/cleverreach'},
#  {'Plugin Name': 'ZapSign',
#   'Rank': 344,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/zapsign'},
#  {'Plugin Name': 'SuperSaaS',
#   'Rank': 345,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/supersaas'},
#  {'Plugin Name': 'Salla',
#   'Rank': 346,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/salla'},
#  {'Plugin Name': 'apaleo',
#   'Rank': 347,
#   'Category': 'Travel',
#   'url': 'https://www.make.com/en/integrations/apaleo'},
#  {'Plugin Name': 'TextMagic',
#   'Rank': 348,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/textmagic'},
#  {'Plugin Name': 'Convertio',
#   'Rank': 349,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/convertio'},
# ...
#   'Rank': 884,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/prefinery'},
#  {'Plugin Name': 'Plumsail Documents',
#   'Rank': 885,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/plumsail-documents'},
#  {'Plugin Name': 'Pinboard',
#   'Rank': 886,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/pinboard'},
#  {'Plugin Name': 'Pastebin',
#   'Rank': 887,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/pastebin'},
#  {'Plugin Name': 'Onoff Business',
#   'Rank': 888,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/onoff-business'},
#  {'Plugin Name': 'Nusii',
#   'Rank': 889,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/nusii'},
#  {'Plugin Name': 'Nozbe Teams',
#   'Rank': 890,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/nozbe-teams'},
#  {'Plugin Name': 'Moxie',
#   'Rank': 891,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/moxie'},
#  {'Plugin Name': 'Mitto SMS',
#   'Rank': 892,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/mitto-sms'},
#  {'Plugin Name': 'Metabase',
#   'Rank': 893,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/metabase'},
#  {'Plugin Name': 'LinkedIn Offline Conversions',
#   'Rank': 894,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/linkedin-offline-conversions'},
#  {'Plugin Name': 'LearningSuite',
#   'Rank': 895,
#   'Category': 'Education',
#   'url': 'https://www.make.com/en/integrations/learningsuite'},
#  {'Plugin Name': 'Leady',
#   'Rank': 896,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/leady'},
#  {'Plugin Name': 'LeadSquared',
#   'Rank': 897,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/leadsquared'},
#  {'Plugin Name': 'KissFlow',
#   'Rank': 898,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/kissflow'},
#  {'Plugin Name': 'JW Player',
#   'Rank': 899,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/jw-player'},
#  {'Plugin Name': 'Jenkins',
#   'Rank': 900,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/jenkins'},
#  {'Plugin Name': 'involve.me',
#   'Rank': 901,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/involve-me'},
#  {'Plugin Name': 'Invoiced',
#   'Rank': 902,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/invoiced'},
#  {'Plugin Name': 'Infinity',
#   'Rank': 903,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/infinity'},
#  {'Plugin Name': 'Hive',
#   'Rank': 904,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/hive'},
#  {'Plugin Name': 'Hireflix',
#   'Rank': 905,
#   'Category': 'Hr-Management',
#   'url': 'https://www.make.com/en/integrations/hireflix'},
#  {'Plugin Name': 'HERO Software für Handwerker',
#   'Rank': 906,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/hero-software'},
#  {'Plugin Name': 'HappyFox Help Desk',
#   'Rank': 907,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/happyfox-help-desk'},
#  {'Plugin Name': 'Groove',
#   'Rank': 908,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/groove'},
#  {'Plugin Name': 'Grist',
#   'Rank': 909,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/grist'},
#  {'Plugin Name': 'Greenhouse Recruiting',
#   'Rank': 910,
#   'Category': 'Hr-Management',
#   'url': 'https://www.make.com/en/integrations/greenhouse'},
#  {'Plugin Name': 'GoodBarber eCommerce',
#   'Rank': 911,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/goodbarber-ecommerce'},
#  {'Plugin Name': 'Freshmail',
#   'Rank': 912,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/freshmail'},
#  {'Plugin Name': 'Formspree',
#   'Rank': 913,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/formspree'},
#  {'Plugin Name': 'Endorsal',
#   'Rank': 914,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/endorsal'},
#  {'Plugin Name': 'Emma',
#   'Rank': 915,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/emma'},
#  {'Plugin Name': 'Drift',
#   'Rank': 916,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/drift'},
#  {'Plugin Name': 'Customerly',
#   'Rank': 917,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/customerly'},
#  {'Plugin Name': 'Clust',
#   'Rank': 918,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/clust'},
#  {'Plugin Name': 'Chatra',
#   'Rank': 919,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chatra'},
#  {'Plugin Name': 'ChatBot',
#   'Rank': 920,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/chatbot'},
#  {'Plugin Name': 'BlockSurvey',
#   'Rank': 921,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/blocksurvey'},
#  {'Plugin Name': 'BigMailer',
#   'Rank': 922,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/bigmailer'},
#  {'Plugin Name': 'Bannerbite',
#   'Rank': 923,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/bannerbite'},
#  {'Plugin Name': 'Avochato',
#   'Rank': 924,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/avochato'},
#  {'Plugin Name': 'ArtiBot.ai',
#   'Rank': 925,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/artibot-ai'},
#  {'Plugin Name': 'FastBill',
#   'Rank': 926,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/fastbill'},
#  {'Plugin Name': 'Bullhorn API',
#   'Rank': 927,
#   'Category': 'Hr-Management',
#   'url': 'https://www.make.com/en/integrations/bullhorn-api'},
#  {'Plugin Name': 'Oblio.eu Facturare',
#   'Rank': 928,
#   'Category': 'Other',
#   'url': 'https://www.make.com/en/integrations/oblio.eu-facturare'},
#  {'Plugin Name': 'Relevance AI',
#   'Rank': 929,
#   'Category': 'Ai',
#   'url': 'https://www.make.com/en/integrations/relevance-ai'},
#  {'Plugin Name': 'Exact Online',
#   'Rank': 930,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/exact-online'},
#  {'Plugin Name': 'Zulip',
#   'Rank': 931,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/zulip'},
#  {'Plugin Name': 'Yandex.Translate',
#   'Rank': 932,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/yandex-translate'},
#  {'Plugin Name': 'WP All Import',
#   'Rank': 933,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/wp-all-import'},
#  {'Plugin Name': 'WiziShop',
#   'Rank': 934,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/wizishop'},
#  {'Plugin Name': 'WaiverFile',
#   'Rank': 935,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/waiverfile'},
#  {'Plugin Name': 'Visma eAccounting',
#   'Rank': 936,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/visma-eaccounting'},
#  {'Plugin Name': 'Vend',
#   'Rank': 937,
#   'Category': 'Business-Operations-Erp',
#   'url': 'https://www.make.com/en/integrations/vend'},
#  {'Plugin Name': 'Trustpilot',
#   'Rank': 938,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/trustpilot'},
#  {'Plugin Name': 'Toodledo',
#   'Rank': 939,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/toodledo'},
#  {'Plugin Name': 'Toggl Plan',
#   'Rank': 940,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/toggl-plan'},
#  {'Plugin Name': 'Timing',
#   'Rank': 941,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/timing'},
#  {'Plugin Name': 'The Keys',
#   'Rank': 942,
#   'Category': 'Internet-Of-Things',
#   'url': 'https://www.make.com/en/integrations/the-keys'},
#  {'Plugin Name': 'Temi',
#   'Rank': 943,
#   'Category': 'Language-Tools',
#   'url': 'https://www.make.com/en/integrations/temi'},
#  {'Plugin Name': 'TeamViewer',
#   'Rank': 944,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/teamviewer'},
#  {'Plugin Name': 'Survicate',
#   'Rank': 945,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/survicate'},
#  {'Plugin Name': 'SugarCRM 7/8',
#   'Rank': 946,
#   'Category': 'Crm-Sales',
#   'url': 'https://www.make.com/en/integrations/sugarcrm7'},
#  {'Plugin Name': 'Stencil',
#   'Rank': 947,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/stencil'},
#  {'Plugin Name': 'Stamped.io',
#   'Rank': 948,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/stamped'},
#  {'Plugin Name': 'SocialBee',
#   'Rank': 949,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/socialbee'},
#  {'Plugin Name': 'Snipcart',
#   'Rank': 950,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/snipcart'},
#  {'Plugin Name': 'SMSC',
#   'Rank': 951,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/smsc'},
#  {'Plugin Name': 'Smith.ai',
#   'Rank': 952,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/smith-ai'},
#  {'Plugin Name': 'SlickText',
#   'Rank': 953,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/slicktext'},
#  {'Plugin Name': 'Site Search 360',
#   'Rank': 954,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/site-search-360'},
#  {'Plugin Name': 'SigParser',
#   'Rank': 955,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/sigparser'},
#  {'Plugin Name': 'Shift4Shop',
#   'Rank': 956,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/a3dcart'},
#  {'Plugin Name': 'Scrive eSign',
#   'Rank': 957,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/scrive'},
#  {'Plugin Name': 'ScanOrders',
#   'Rank': 958,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/scanorders'},
#  {'Plugin Name': 'Retable',
#   'Rank': 959,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/retable'},
#  {'Plugin Name': 'Relatel',
#   'Rank': 960,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/relatel'},
#  {'Plugin Name': 'Quable PIM',
#   'Rank': 961,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/quable-pim'},
#  {'Plugin Name': 'Product Hunt',
#   'Rank': 962,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/product-hunt'},
#  {'Plugin Name': 'PracticePanther',
#   'Rank': 963,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/practicepanther'},
#  {'Plugin Name': 'Planyo',
#   'Rank': 964,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/planyo'},
#  {'Plugin Name': 'Paperless.io',
#   'Rank': 965,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/paperless-io'},
#  {'Plugin Name': 'Outreach',
#   'Rank': 966,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/outreach'},
#  {'Plugin Name': 'Nuelink',
#   'Rank': 967,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/nuelink'},
#  {'Plugin Name': 'MoreApp Forms',
#   'Rank': 968,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/moreapp-forms'},
#  {'Plugin Name': 'Mallabe Websites',
#   'Rank': 969,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/mallabe-websites'},
#  {'Plugin Name': 'MakeForms',
#   'Rank': 970,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/make-forms'},
#  {'Plugin Name': 'Mailshake',
#   'Rank': 971,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/mailshake'},
#  {'Plugin Name': 'Luxafor',
#   'Rank': 972,
#   'Category': 'Internet-Of-Things',
#   'url': 'https://www.make.com/en/integrations/luxafor'},
#  {'Plugin Name': 'LiveChat',
#   'Rank': 973,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/livechat'},
#  {'Plugin Name': 'Komerční banka',
#   'Rank': 974,
#   'Category': 'Commerce',
#   'url': 'https://www.make.com/en/integrations/komercni-banka'},
#  {'Plugin Name': 'Jitbit',
#   'Rank': 975,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/jitbit'},
#  {'Plugin Name': 'Iteration X',
#   'Rank': 976,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/iteration-x'},
#  {'Plugin Name': 'Invision Community',
#   'Rank': 977,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/invision-community'},
#  {'Plugin Name': 'Humanitix',
#   'Rank': 978,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/humanitix'},
#  {'Plugin Name': 'Gong',
#   'Rank': 979,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/gong'},
#  {'Plugin Name': 'GoCanvas',
#   'Rank': 980,
#   'Category': 'Surveys-Forms',
#   'url': 'https://www.make.com/en/integrations/gocanvas'},
#  {'Plugin Name': 'Go4Clients',
#   'Rank': 981,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/go4clients'},
#  {'Plugin Name': 'GetProspect',
#   'Rank': 982,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/getprospect'},
#  {'Plugin Name': 'FileCloud',
#   'Rank': 983,
#   'Category': 'File-Document-Management',
#   'url': 'https://www.make.com/en/integrations/filecloud'},
#  {'Plugin Name': 'Disqus',
#   'Rank': 984,
#   'Category': 'Customer-Support',
#   'url': 'https://www.make.com/en/integrations/disqus'},
#  {'Plugin Name': 'Demodesk',
#   'Rank': 985,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/demodesk'},
#  {'Plugin Name': 'Custify',
#   'Rank': 986,
#   'Category': 'Business-Intelligence',
#   'url': 'https://www.make.com/en/integrations/custify'},
#  {'Plugin Name': 'Clickatell',
#   'Rank': 987,
#   'Category': 'Communication',
#   'url': 'https://www.make.com/en/integrations/clickatell'},
#  {'Plugin Name': 'cituro',
#   'Rank': 988,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/cituro'},
#  {'Plugin Name': 'Captivate',
#   'Rank': 989,
#   'Category': 'Other',
#   'url': 'https://www.make.com/en/integrations/captivate'},
#  {'Plugin Name': 'Brave',
#   'Rank': 990,
#   'Category': 'Website-Building',
#   'url': 'https://www.make.com/en/integrations/getbrave-io'},
#  {'Plugin Name': 'Basecamp 2',
#   'Rank': 991,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/basecamp'},
#  {'Plugin Name': 'Axiom',
#   'Rank': 992,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/axiom'},
#  {'Plugin Name': 'Avaza',
#   'Rank': 993,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/avaza'},
#  {'Plugin Name': 'Aurora Solar',
#   'Rank': 994,
#   'Category': 'Other',
#   'url': 'https://www.make.com/en/integrations/aurora-solar'},
#  {'Plugin Name': 'ApuTime',
#   'Rank': 995,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/aputime'},
#  {'Plugin Name': 'AgilePlace',
#   'Rank': 996,
#   'Category': 'Productivity',
#   'url': 'https://www.make.com/en/integrations/agileplace'},
#  {'Plugin Name': 'AdRoll',
#   'Rank': 997,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/adroll'},
#  {'Plugin Name': '4leads',
#   'Rank': 998,
#   'Category': 'Marketing',
#   'url': 'https://www.make.com/en/integrations/four-leads'},
#  {'Plugin Name': 'Copy.AI',
#   'Rank': 999,
#   'Category': 'Ai',
#   'url': 'https://www.make.com/en/integrations/copy.ai'},
#  {'Plugin Name': 'ZenRows',
#   'Rank': 1000,
#   'Category': 'It-Development',
#   'url': 'https://www.make.com/en/integrations/zenrows'},
#  ...]

# %%
import jmespath

# %%
actions = []
triggers = []
searches = []
jsons = ['actionsJson', 'triggersJson', 'searchesJson']

# %%
for key in jsons:
    data_dict = json_data['props']['pageProps']['app'][key]
    
data_dict
# Out:
# [{'acid': False,
#   'name': 'Get Range Values',
#   'slug': 'getSheetContent',
#   'listener': False,
#   'description': 'Gets a range content.'},
#  {'acid': False,
#   'name': 'List Sheets',
#   'slug': 'listSheets',
#   'listener': False,
#   'description': 'Gets a list of all sheets in a spreadsheet.'},
#  {'acid': False,
#   'name': 'Search Rows',
#   'slug': 'filterRows',
#   'listener': False,
#   'description': 'Returns results matching the given criteria.'},
#  {'acid': False,
#   'name': 'Search Rows (Advanced)',
#   'slug': 'filterRowsAdvanced',
#   'listener': False,
#   'description': "Returns results matching the given criteria. This module doesn't return a row number."}]
