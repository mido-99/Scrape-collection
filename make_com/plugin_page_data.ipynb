# %%
import json
import pandas as pd
import json
from bs4 import BeautifulSoup
import httpx
from time import sleep

# %%
import requests

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
    'content-type': 'application/json',
    # 'cookie': 'last_touch_gclid=undefined; first_touch_gclid=undefined; first_touch_landing_page=https%3A//www.make.com/en; last_touch_referral_url=; first_touch_referral_url=; referral_url=; gb_anonymous_id=4d967744-c4b8-41b6-9f90-d802fdb6bd2e; rl_page_init_referrer=RudderEncrypt%3AU2FsdGVkX1%2FCz9PRIUWfpw55RZZzB90hnV2RmGpzB%2Bc%3D; rl_page_init_referring_domain=RudderEncrypt%3AU2FsdGVkX18Buyn6d3%2B%2FZ%2BdkINFvxspfeXihCa3tEmk%3D; _ga=GA1.1.1543941994.1716808364; make_session_id=1716808364; poptin_old_user=true; poptin_user_id=0.83emxpg2gfb; _hjSession_2919042=eyJpZCI6IjcyMTJlZjZmLWNmYzItNGI2NC04ZjY2LTlmMDQzMWQ3ZTI2ZSIsImMiOjE3MTY4MDgzNjQ4NDksInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MX0=; poptin_user_ip=156.207.60.19; poptin_user_country_code=false; poptin_session_account_b242bb2954926=true; poptin_c_visitor=true; _gcl_au=1.1.13046725.1716808366; _fbp=fb.1.1716808367190.548965802; first_touch_landing_page_query=%3Fcommunity%3D1%26verified%3D1; OptanonAlertBoxClosed=2024-05-27T11:12:55.793Z; _hjSessionUser_2919042=eyJpZCI6IjgwNmJiZjg5LTY1OTMtNWY5MS1iYjNjLTUwZDQ1ZmU4ZGNlYiIsImNyZWF0ZWQiOjE3MTY4MDgzNjQ4NDcsImV4aXN0aW5nIjp0cnVlfQ==; poptin_referrer=; __cf_bm=ZhmiI_fJ7q50hTmpJ8Egh_mJwmFZAPaR1NP6m8QnpOs-1716809499-1.0.1.1-Fx0gbBEha8nuZx4K5CVf8xKq.oSYj7Se4ArRV028nsrkWJsyYoshTns8C9RRDjC4LhN8Kkxm5HJQUDrUjMaTzQ; poptin_previous_url=; _uetsid=0c5498001c1a11efbdf0954c2b28279f; _uetvid=0c54bd001c1a11ef99362fa261b0d15d; _rdt_uuid=1716808366676.355e1e32-bf41-4c7d-87c5-36507b532296; _ga_MY0CJTCDSF=GS1.1.1716808364.1.1.1716810255.60.0.0; last_touch_landing_page=https%3A//www.make.com/en/integrations; last_touch_landing_page_query=%3Fcommunity%3D1%26verified%3D1; rl_user_id=RudderEncrypt%3AU2FsdGVkX18MS4afj%2B433q2BT8LEHvjcSWTlJng7IYo%3D; rl_trait=RudderEncrypt%3AU2FsdGVkX1955aLSSg6p81sFHh2P%2BUEBgEZDMO7egxI%3D; rl_group_id=RudderEncrypt%3AU2FsdGVkX1%2BzXHnwwFhr2zrLRrE%2BcHBuZXt9hTV%2BOUE%3D; rl_group_trait=RudderEncrypt%3AU2FsdGVkX184R3Cbr2HEJkQaynq%2BjkYGsPNcDOSMdOA%3D; rl_anonymous_id=RudderEncrypt%3AU2FsdGVkX1%2BCtbAFSuSmQiO4RFaiKGp2%2FjamFPyGhCQBQA4m4mfSFnrAMGu0FtzsjPeiD%2BPvpNhcVpIWpLX38w%3D%3D; rl_session=RudderEncrypt%3AU2FsdGVkX195z1rZFRgVdnOj8PSlOdOciXFgY9GVVw31gzR0I301uLS3vEfo%2BsVCefg1HfcaXH73CEzlcTcp3iX%2FGyEdvXawYhtNxAYDwYpUGVpbaOCq1FudLdVBeFyDFseIEfl5NmNp9z0uiEgHvQ%3D%3D; OptanonConsent=isGpcEnabled=0&datestamp=Mon+May+27+2024+14%3A44%3A16+GMT%2B0300+(Eastern+European+Summer+Time)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=758c16f0-df45-4741-813f-b146c2926d1d&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1%2CC0002%3A1&AwaitingReconsent=false&geolocation=EG%3BKN',
    'referer': 'https://www.make.com/en/integrations?community=1&verified=1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
}

params = {
    'name': '',
    'limit': '3000', # high limit to get all plugins
    'offset': '0',   # starting point
    'sort': 'Most Popular',
    'category': '',
    'addOnApps': 'true',
    'nativeApps': 'true',
    'isCategory': 'false',
    'isSubCategory': 'false',
}

response = requests.get('https://www.make.com/pw-api/integrations/search-apps', params=params, headers=headers)

# %%
entities = response.json()['entities']
len(entities)
# Out:
# 1833

# %%
df = pd.DataFrame(entities)
df.head()
# Out:
#                            sys           slug  \
# 0  {'id': 'app-google-sheets'}  google-sheets
# 1   {'id': 'app-google-email'}   google-email
# 2       {'id': 'app-airtable'}       airtable
# 3   {'id': 'app-openai-gpt-3'}   openai-gpt-3
# 4   {'id': 'app-google-drive'}   google-drive
#
#                                 name  priority    theme featured  \
# 0                      Google Sheets     44103  #0fa763     None
# 1                              Gmail     16079  #dd4b39     None
# 2                           Airtable     13093  #18bfff     True
# 3  OpenAI (ChatGPT, Whisper, DALL-E)     11970  #10a37f     True
# 4                       Google Drive     10897  #fccd48     None
#
#                                                 icon  \
# 0  {'title': 'Google Sheets', 'url': 'https://ima...
# 1  {'title': 'Gmail', 'url': 'https://images.ctfa...
# 2  {'title': 'Airtable', 'url': 'https://images.c...
# 3  {'title': 'OpenAI (DALL-E & ChatGPT)', 'url': ...
# 4  {'title': 'Google Drive', 'url': 'https://imag...
#
#                                 categoriesCollection  \
# 0  {'items': [{'slug': 'productivity'}, {'slug': ...
# 1  {'items': [{'slug': 'communication'}, {'slug':...
# 2  {'items': [{'slug': 'it-development'}, {'slug'...
# 3  {'items': [{'slug': 'it-development'}, {'slug'...
# 4  {'items': [{'slug': 'file-document-management'...
#
#                              subcategoriesCollection  supportedApp  addOnApp  \
# 0  {'items': [{'slug': 'spreadsheets'}, {'slug': ...          True     False
# 1  {'items': [{'slug': 'email'}, {'slug': 'google...          True     False
# 2  {'items': [{'slug': 'databases'}, {'slug': 'sp...          True     False
# 3  {'items': [{'slug': 'ml'}, {'slug': 'developme...          True     False
# 4  {'items': [{'slug': 'documents'}, {'slug': 'go...          True     False
#
#   description landingUrl thirdPartyAppType thirdPartyPartner
# 0         NaN        NaN               NaN               NaN
# 1         NaN        NaN               NaN               NaN
# 2         NaN        NaN               NaN               NaN
# 3         NaN        NaN               NaN               NaN
# 4         NaN        NaN               NaN               NaN

# %%
df['url'] = "https://www.make.com/en/integrations/" + df['slug']
df.url
# Out:
# 0       https://www.make.com/en/integrations/google-sh...
# 1       https://www.make.com/en/integrations/google-email
# 2           https://www.make.com/en/integrations/airtable
# 3       https://www.make.com/en/integrations/openai-gpt-3
# 4       https://www.make.com/en/integrations/google-drive
#                               ...
# 1828        https://www.make.com/en/integrations/two-chat
# 1829    https://www.make.com/en/integrations/ten-to-eight
# 1830         https://www.make.com/en/integrations/builtin
# 1831         https://www.make.com/en/integrations/gateway
# 1832             https://www.make.com/en/integrations/xml
# Name: url, Length: 1833, dtype: object

# %%
class self:
    pass
self.df = df.iloc[:3, :]
self.df
# Out:
#                            sys           slug           name  priority  \
# 0  {'id': 'app-google-sheets'}  google-sheets  Google Sheets     44103
# 1   {'id': 'app-google-email'}   google-email          Gmail     16079
# 2       {'id': 'app-airtable'}       airtable       Airtable     13093
#
#      theme featured                                               icon  \
# 0  #0fa763     None  {'title': 'Google Sheets', 'url': 'https://ima...
# 1  #dd4b39     None  {'title': 'Gmail', 'url': 'https://images.ctfa...
# 2  #18bfff     True  {'title': 'Airtable', 'url': 'https://images.c...
#
#                                 categoriesCollection  \
# 0  {'items': [{'slug': 'productivity'}, {'slug': ...
# 1  {'items': [{'slug': 'communication'}, {'slug':...
# 2  {'items': [{'slug': 'it-development'}, {'slug'...
#
#                              subcategoriesCollection  supportedApp  addOnApp  \
# 0  {'items': [{'slug': 'spreadsheets'}, {'slug': ...          True     False
# 1  {'items': [{'slug': 'email'}, {'slug': 'google...          True     False
# 2  {'items': [{'slug': 'databases'}, {'slug': 'sp...          True     False
#
#   description landingUrl thirdPartyAppType thirdPartyPartner  \
# 0         NaN        NaN               NaN               NaN
# 1         NaN        NaN               NaN               NaN
# 2         NaN        NaN               NaN               NaN
#
#                                                  url
# 0  https://www.make.com/en/integrations/google-sh...
# 1  https://www.make.com/en/integrations/google-email
# 2      https://www.make.com/en/integrations/airtable

# %%
def plugin_page_data(self):

    cookies = {
        'last_touch_gclid': 'undefined',
        'first_touch_gclid': 'undefined',
        'first_touch_landing_page': 'https%3A//www.make.com/en',
        'gb_anonymous_id': '4d967744-c4b8-41b6-9f90-d802fdb6bd2e',
        'rl_page_init_referrer': 'RudderEncrypt%3AU2FsdGVkX1%2FCz9PRIUWfpw55RZZzB90hnV2RmGpzB%2Bc%3D',
        'rl_page_init_referring_domain': 'RudderEncrypt%3AU2FsdGVkX18Buyn6d3%2B%2FZ%2BdkINFvxspfeXihCa3tEmk%3D',
        '_ga': 'GA1.1.1543941994.1716808364',
        'poptin_old_user': 'true',
        'poptin_user_id': '0.83emxpg2gfb',
        'poptin_user_ip': '156.207.60.19',
        'poptin_user_country_code': 'false',
        'poptin_session_account_b242bb2954926': 'true',
        'poptin_c_visitor': 'true',
        '_gcl_au': '1.1.13046725.1716808366',
        '_fbp': 'fb.1.1716808367190.548965802',
        'first_touch_landing_page_query': '%3Fcommunity%3D1%26verified%3D1',
        'OptanonAlertBoxClosed': '2024-05-27T11:12:55.793Z',
        '_hjSessionUser_2919042': 'eyJpZCI6IjgwNmJiZjg5LTY1OTMtNWY5MS1iYjNjLTUwZDQ1ZmU4ZGNlYiIsImNyZWF0ZWQiOjE3MTY4MDgzNjQ4NDcsImV4aXN0aW5nIjp0cnVlfQ==',
        'last_touch_landing_page_query': '',
        'first_touch_referral_url': 'http%3A//localhost%3A8888/',
        'poptin_referrer': '',
        'last_touch_landing_page': 'https%3A//www.make.com/en/integrations/google-sheets',
        'last_touch_referral_url': '',
        'referral_url': '',
        'visitor_id1009662': '179264686',
        'visitor_id1009662-hash': '1519c6c73d563505d3864a715df232c09d12f131ebe0cd353812b4f58d2c6c0d06c659c3e81d67c117cb2ec8215ee459825eaa67',
        '__cf_bm': '1kTgSA4sIMaW0D3T75liMBg5ZxRIxmWW7b_0DF0LTXQ-1716836483-1.0.1.1-uWF4cAaHH6BQEgatTwbESQ__oIBXbWuCkay8YUiPfiswxwA9loQjfPXvLPeWGK76UHod9WxnaSwmJJViQmUFMA',
        'rl_user_id': 'RudderEncrypt%3AU2FsdGVkX1%2BCCgdB42kQJtAjWsRJozHOuk0iMPy5wjQ%3D',
        'rl_trait': 'RudderEncrypt%3AU2FsdGVkX1%2Bg6ToT1Ywws2w%2BLullpd8BXty5QNALWUo%3D',
        'rl_group_id': 'RudderEncrypt%3AU2FsdGVkX1%2BL2H9TPM%2Be8Vf0OFQYEAJWhLtI%2B5n4Yck%3D',
        'rl_group_trait': 'RudderEncrypt%3AU2FsdGVkX18SuOz9gHkxMUdJTn7tGaf%2BVJ1xwJfJTe0%3D',
        'rl_anonymous_id': 'RudderEncrypt%3AU2FsdGVkX1913wNUN4YLhOjZxyk4j%2FhDA0lqzJLqGyi4MbY0tjnvpaBsv0gKI1T1OtVEbO3Ki%2FCwbyF9ifk89Q%3D%3D',
        'OptanonConsent': 'isGpcEnabled=0&datestamp=Mon+May+27+2024+22%3A06%3A41+GMT%2B0300+(Eastern+European+Summer+Time)&version=202306.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=758c16f0-df45-4741-813f-b146c2926d1d&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CC0004%3A1%2CC0002%3A1&AwaitingReconsent=false&geolocation=EG%3BKN',
        'rl_session': 'RudderEncrypt%3AU2FsdGVkX1%2BehoyhNrQ8XjNmBJS4C20m8ZbMk7WpBM5Z70ZInV8TRDUWJzRewaOErFW5ukLAdpdO%2Fk0HXvujRL6zjo6JnO4HdmCeaS7AIhFY3anWcoWEXDe68pDhruhDa%2BGOA3R8uXmi7rCt4Y4MEw%3D%3D',
        '_ga_MY0CJTCDSF': 'GS1.1.1716836799.6.1.1716836809.50.0.0',
        'make_session_id': '1716836799',
        '_uetsid': '0c5498001c1a11efbdf0954c2b28279f',
        '_uetvid': '0c54bd001c1a11ef99362fa261b0d15d',
        '_hjSession_2919042': 'eyJpZCI6IjY0ZWFhN2JkLTVjYTctNDQ1YS05NTQ0LTQzMmZjMTE1ZGZhOCIsImMiOjE3MTY4MzY4MTYzMDYsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=',
        '_rdt_uuid': '1716808366676.355e1e32-bf41-4c7d-87c5-36507b532296',
        'poptin_session': 'true',
    }

    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
        'priority': 'u=0, i',
        'sec-ch-ua': '"Google Chrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
    }
    with requests.Session() as session:
        session.headers.update(headers)
        session.cookies.update(cookies)

        self.df.loc[:, 'json_data'] = self.df['url'].apply(
            lambda url: request_plugin_page(session, url))
    self.df.loc[:, 'Description'] = self.df.loc[:, 'json_data'].apply(extract_description)

# %%
def request_plugin_page(session, plugin_url):

    attemps = 3
    for attempt in range(attemps):
        response = session.get(plugin_url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            json_str = soup.find('script', id="__NEXT_DATA__").text
            json_data = json.loads(json_str)
            return json_data
        else:
            time.sleep(5)
            if attempt == attemps -1:
                print(response.status_code, response.text)
                print(f"Error in plugin page: {plugin_url}")
                return None

# %%
def extract_description(json_data):

    if not json_data:
        return "No data available"
    try:
        plugin_name = json_data['props']['pageProps']['app']['name']
        description = json_data['props']['pageProps']['appDetails']['description'].replace(r"{name}", plugin_name)
        return description
    except Exception as e:
        print(f"Error: {e}")
        return ""

# %%
plugin_page_data(self)
# Out:
# C:\Users\Mido Hany\AppData\Local\Temp\ipykernel_12072\2519719679.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df.loc[:, 'json_data'] = self.df['url'].apply(
# C:\Users\Mido Hany\AppData\Local\Temp\ipykernel_12072\2519719679.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df.loc[:, 'Description'] = self.df.loc[:, 'json_data'].apply(extract_description)

# %%
self.df.loc[:, 'url':]
# Out:
#                                                  url  \
# 0  https://www.make.com/en/integrations/google-sh...
# 1  https://www.make.com/en/integrations/google-email
# 2      https://www.make.com/en/integrations/airtable
#
#                                            json_data  \
# 0  {'props': {'pageProps': {'app': {'sys': {'id':...
# 1  {'props': {'pageProps': {'app': {'sys': {'id':...
# 2  {'props': {'pageProps': {'app': {'sys': {'id':...
#
#                                          Description
# 0  Connect Google Sheets with any of your favorit...
# 1  Connect Gmail with any of your favorite apps i...
# 2  Connect Airtable with any of your favorite app...

# %%
def extract_actions(json_data):
    
#     json_data = df['json_data']
    result = {}
    for key, value in json_data['props']['pageProps']['app'].items():
        if 'Json' in key and value != []:
            final_key = key.rsplit('Json', 1)[0].title()
            formatted = '\n'.join([f"{i['name']}: {i['description']}" for i in value])
            result[final_key] = formatted
            
    return result

# %%
json_series = self.df['json_data']
json_series
# Out:
# 0    {'props': {'pageProps': {'app': {'sys': {'id':...
# 1    {'props': {'pageProps': {'app': {'sys': {'id':...
# 2    {'props': {'pageProps': {'app': {'sys': {'id':...
# Name: json_data, dtype: object

# %%
extracted_data = json_series.apply(extract_actions)
extracted_data[0]
# Out:
# {'Actions': "Add a Conditional Format Rule: Creates a new conditional format rule at the given index. All subsequent rules' indexes are incremented.\nAdd a Row: Appends a new row to the bottom of the table.\nAdd a Sheet: Adds a new sheet.\nClear a Cell: Cleares a specific cell.\nClear a Row: Clears values from a specific row.\nClear Values from a Range: Clears a specified range of values from a spreadsheet.\nCopy a Sheet: Copies a sheet to another spreadsheet.\nCreate a Spreadsheet: Creates a new spreadsheet.\nCreate a Spreadsheet from a Template: Creates a new spreadsheet from a template sheet.\nDelete a Conditional Format Rule: Deletes a conditional format rule at the given index. All subsequent rules' indexes are decremented.\nDelete a Row: Deletes a specific row.\nDelete a Sheet: Deletes a specific sheet.\nGet a Cell: Gets a specific cell.\nMake an API Call: Performs an arbitrary authorized API call.\nPerform a Function - Responder: Returns processed data as a result of the MAKE_FUNCTION or INTEGROMAT function. Sheets Add-On required.\nRename a Sheet: Renames a specific sheet.\nUpdate a Cell: Updates a specific cell.\nUpdate a Row: Updates a row.",
#  'Searches': "Get Range Values: Gets a range content.\nList Sheets: Gets a list of all sheets in a spreadsheet.\nSearch Rows: Returns results matching the given criteria.\nSearch Rows (Advanced): Returns results matching the given criteria. This module doesn't return a row number.",
#  'Triggers': 'Perform a Function: Receives data passed to the function MAKE_FUNCTION or INTEGROMAT used in a sheet. Sheets Add-On required.\nWatch Changes: Triggers when a cell is updated. Watches only changes made in Google Sheet app. Sheets Add-On required.\nWatch New Rows: Triggers when a new row is added.'}

# %%
extracted_data.tolist()
# Out:
# [{'Actions': "Add a Conditional Format Rule: Creates a new conditional format rule at the given index. All subsequent rules' indexes are incremented.\nAdd a Row: Appends a new row to the bottom of the table.\nAdd a Sheet: Adds a new sheet.\nClear a Cell: Cleares a specific cell.\nClear a Row: Clears values from a specific row.\nClear Values from a Range: Clears a specified range of values from a spreadsheet.\nCopy a Sheet: Copies a sheet to another spreadsheet.\nCreate a Spreadsheet: Creates a new spreadsheet.\nCreate a Spreadsheet from a Template: Creates a new spreadsheet from a template sheet.\nDelete a Conditional Format Rule: Deletes a conditional format rule at the given index. All subsequent rules' indexes are decremented.\nDelete a Row: Deletes a specific row.\nDelete a Sheet: Deletes a specific sheet.\nGet a Cell: Gets a specific cell.\nMake an API Call: Performs an arbitrary authorized API call.\nPerform a Function - Responder: Returns processed data as a result of the MAKE_FUNCTION or INTEGROMAT function. Sheets Add-On required.\nRename a Sheet: Renames a specific sheet.\nUpdate a Cell: Updates a specific cell.\nUpdate a Row: Updates a row.",
#   'Searches': "Get Range Values: Gets a range content.\nList Sheets: Gets a list of all sheets in a spreadsheet.\nSearch Rows: Returns results matching the given criteria.\nSearch Rows (Advanced): Returns results matching the given criteria. This module doesn't return a row number.",
#   'Triggers': 'Perform a Function: Receives data passed to the function MAKE_FUNCTION or INTEGROMAT used in a sheet. Sheets Add-On required.\nWatch Changes: Triggers when a cell is updated. Watches only changes made in Google Sheet app. Sheets Add-On required.\nWatch New Rows: Triggers when a new row is added.'},
#  {'Actions': 'Copy an Email: Copies an email or a draft into a selected folder.\nCreate a Draft: Creates a new draft and adds it to a selected folder.\nDelete an Email: Removes an email or a draft from a selected folder.\nMark an Email as Read: Marks an email or a draft in a selected directory as read by setting the "Read" flag.\nMark an Email as Unread: Marks an email or draft in a selected directory as unread by setting the "Unread" flag.\nModify Email Labels: Modifies labels on the specified email message.\nMove an Email: Moves a chosen email or a draft to a selected folder.\nSend an Email: Sends a new email.',
#   'Feeders': 'Iterate Attachments: Iterates through received attachments.',
#   'Triggers': 'Watch Emails: Triggers when a new email is received to be processed according to specified criteria.'},
#  {'Actions': 'Create a Record: Creates a new record in Airtable.\nDelete a Record: Deletes a record by its ID.\nGet a Record: Retrieves a single record by its ID.\nMake an API Call: Performs an arbitrary authorized API call.\nUpdate a Record: Updates a record by its ID.\nUpsert a Record: Creates new or updates an existing record.',
#   'Searches': 'Search Records: Searches for specific records or returns all records.',
#   'Triggers': 'Watch Records: Returns all newly created or updated records in a view (requires "Created Time" or "Last Modified Time" fields).\nWatch Responses: Triggers when a new response is submitted.'}]

# %%
extracted_df = pd.DataFrame(extracted_data.tolist())
extracted_df
# Out:
#                                              Actions  \
# 0  Add a Conditional Format Rule: Creates a new c...
# 1  Copy an Email: Copies an email or a draft into...
# 2  Create a Record: Creates a new record in Airta...
#
#                                             Searches  \
# 0  Get Range Values: Gets a range content.\nList ...
# 1                                                NaN
# 2  Search Records: Searches for specific records ...
#
#                                             Triggers  \
# 0  Perform a Function: Receives data passed to th...
# 1  Watch Emails: Triggers when a new email is rec...
# 2  Watch Records: Returns all newly created or up...
#
#                                              Feeders
# 0                                                NaN
# 1  Iterate Attachments: Iterates through received...
# 2                                                NaN

# %%
final_df = pd.concat([df2, extracted_df], axis=1)
final_df
# Out:
#                                            json_data  \
# 0  {'props': {'pageProps': {'app': {'sys': {'id':...
# 1  {'props': {'pageProps': {'app': {'sys': {'id':...
# 2  {'props': {'pageProps': {'app': {'sys': {'id':...
#
#                                              Actions  \
# 0  Add a Conditional Format Rule: Creates a new c...
# 1  Copy an Email: Copies an email or a draft into...
# 2  Create a Record: Creates a new record in Airta...
#
#                                             Searches  \
# 0  Get Range Values: Gets a range content.\nList ...
# 1                                                NaN
# 2  Search Records: Searches for specific records ...
#
#                                             Triggers  \
# 0  Perform a Function: Receives data passed to th...
# 1  Watch Emails: Triggers when a new email is rec...
# 2  Watch Records: Returns all newly created or up...
#
#                                              Feeders
# 0                                                NaN
# 1  Iterate Attachments: Iterates through received...
# 2                                                NaN

# %%
df3 = self.df.copy()

# %%
json_data_series = self.df['json_data']
extracted_data = json_data_series.apply(extract_actions)
extracted_df = pd.DataFrame(extracted_data.tolist())
self.df = pd.concat([self.df, extracted_df], axis=1)
self.df
# Out:
#                            sys           slug           name  priority  \
# 0  {'id': 'app-google-sheets'}  google-sheets  Google Sheets     44103
# 1   {'id': 'app-google-email'}   google-email          Gmail     16079
# 2       {'id': 'app-airtable'}       airtable       Airtable     13093
#
#      theme featured                                               icon  \
# 0  #0fa763     None  {'title': 'Google Sheets', 'url': 'https://ima...
# 1  #dd4b39     None  {'title': 'Gmail', 'url': 'https://images.ctfa...
# 2  #18bfff     True  {'title': 'Airtable', 'url': 'https://images.c...
#
#                                 categoriesCollection  \
# 0  {'items': [{'slug': 'productivity'}, {'slug': ...
# 1  {'items': [{'slug': 'communication'}, {'slug':...
# 2  {'items': [{'slug': 'it-development'}, {'slug'...
#
#                              subcategoriesCollection  supportedApp  ...  \
# 0  {'items': [{'slug': 'spreadsheets'}, {'slug': ...          True  ...
# 1  {'items': [{'slug': 'email'}, {'slug': 'google...          True  ...
# 2  {'items': [{'slug': 'databases'}, {'slug': 'sp...          True  ...
#
#    thirdPartyAppType thirdPartyPartner  \
# 0                NaN               NaN
# 1                NaN               NaN
# 2                NaN               NaN
#
#                                                  url  \
# 0  https://www.make.com/en/integrations/google-sh...
# 1  https://www.make.com/en/integrations/google-email
# 2      https://www.make.com/en/integrations/airtable
#
#                                            json_data  \
# 0  {'props': {'pageProps': {'app': {'sys': {'id':...
# 1  {'props': {'pageProps': {'app': {'sys': {'id':...
# 2  {'props': {'pageProps': {'app': {'sys': {'id':...
#
#                                          Description  \
# 0  Connect Google Sheets with any of your favorit...
# 1  Connect Gmail with any of your favorite apps i...
# 2  Connect Airtable with any of your favorite app...
#
#                                           doc_url  \
# 0  https://www.make.com/en/help/app/google-sheets
# 1   https://www.make.com/en/help/app/google-email
# 2       https://www.make.com/en/help/app/airtable
#
#                                              Actions  \
# 0  Add a Conditional Format Rule: Creates a new c...
# 1  Copy an Email: Copies an email or a draft into...
# 2  Create a Record: Creates a new record in Airta...
#
#                                             Searches  \
# 0  Get Range Values: Gets a range content.\nList ...
# 1                                                NaN
# 2  Search Records: Searches for specific records ...
#
#                                             Triggers  \
# 0  Perform a Function: Receives data passed to th...
# 1  Watch Emails: Triggers when a new email is rec...
# 2  Watch Records: Returns all newly created or up...
#
#                                              Feeders
# 0                                                NaN
# 1  Iterate Attachments: Iterates through received...
# 2                                                NaN
#
# [3 rows x 23 columns]

# %%
self.df['doc_url'] = "https://www.make.com/en/help/app/" + self.df['slug']
self.df
# Out:
# C:\Users\Mido Hany\AppData\Local\Temp\ipykernel_12072\7018127.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['doc_url'] = "https://www.make.com/en/help/app/" + self.df['slug']
#                            sys           slug           name  priority  \
# 0  {'id': 'app-google-sheets'}  google-sheets  Google Sheets     44103
# 1   {'id': 'app-google-email'}   google-email          Gmail     16079
# 2       {'id': 'app-airtable'}       airtable       Airtable     13093
#
#      theme featured                                               icon  \
# 0  #0fa763     None  {'title': 'Google Sheets', 'url': 'https://ima...
# 1  #dd4b39     None  {'title': 'Gmail', 'url': 'https://images.ctfa...
# 2  #18bfff     True  {'title': 'Airtable', 'url': 'https://images.c...
#
#                                 categoriesCollection  \
# 0  {'items': [{'slug': 'productivity'}, {'slug': ...
# 1  {'items': [{'slug': 'communication'}, {'slug':...
# 2  {'items': [{'slug': 'it-development'}, {'slug'...
#
#                              subcategoriesCollection  supportedApp  addOnApp  \
# 0  {'items': [{'slug': 'spreadsheets'}, {'slug': ...          True     False
# 1  {'items': [{'slug': 'email'}, {'slug': 'google...          True     False
# 2  {'items': [{'slug': 'databases'}, {'slug': 'sp...          True     False
#
#   description landingUrl thirdPartyAppType thirdPartyPartner  \
# 0         NaN        NaN               NaN               NaN
# 1         NaN        NaN               NaN               NaN
# 2         NaN        NaN               NaN               NaN
#
#                                                  url  \
# 0  https://www.make.com/en/integrations/google-sh...
# 1  https://www.make.com/en/integrations/google-email
# 2      https://www.make.com/en/integrations/airtable
#
#                                            json_data  \
# 0  {'props': {'pageProps': {'app': {'sys': {'id':...
# 1  {'props': {'pageProps': {'app': {'sys': {'id':...
# 2  {'props': {'pageProps': {'app': {'sys': {'id':...
#
#                                          Description  \
# 0  Connect Google Sheets with any of your favorit...
# 1  Connect Gmail with any of your favorite apps i...
# 2  Connect Airtable with any of your favorite app...
#
#                                           doc_url
# 0  https://www.make.com/en/help/app/google-sheets
# 1   https://www.make.com/en/help/app/google-email
# 2       https://www.make.com/en/help/app/airtable

# %%
self.df.doc_url[0]
# Out:
# 'https://www.make.com/en/help/app/google-sheets'

# %%
self.df.loc[0, 'Actions']
# Out:
# "Add a Conditional Format Rule: Creates a new conditional format rule at the given index. All subsequent rules' indexes are incremented.\nAdd a Row: Appends a new row to the bottom of the table.\nAdd a Sheet: Adds a new sheet.\nClear a Cell: Cleares a specific cell.\nClear a Row: Clears values from a specific row.\nClear Values from a Range: Clears a specified range of values from a spreadsheet.\nCopy a Sheet: Copies a sheet to another spreadsheet.\nCreate a Spreadsheet: Creates a new spreadsheet.\nCreate a Spreadsheet from a Template: Creates a new spreadsheet from a template sheet.\nDelete a Conditional Format Rule: Deletes a conditional format rule at the given index. All subsequent rules' indexes are decremented.\nDelete a Row: Deletes a specific row.\nDelete a Sheet: Deletes a specific sheet.\nGet a Cell: Gets a specific cell.\nMake an API Call: Performs an arbitrary authorized API call.\nPerform a Function - Responder: Returns processed data as a result of the MAKE_FUNCTION or INTEGROMAT function. Sheets Add-On required.\nRename a Sheet: Renames a specific sheet.\nUpdate a Cell: Updates a specific cell.\nUpdate a Row: Updates a row."
