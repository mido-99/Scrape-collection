# %%
# Tweets loading api
import requests
import json
import jmespath

# %%
cookies = {
    'des_opt_in': 'Y',
    'dnt': '1',
    'guest_id': 'v1%3A172130542309363976',
    'night_mode': '2',
    'guest_id_marketing': 'v1%3A172130542309363976',
    'guest_id_ads': 'v1%3A172130542309363976',
    'g_state': '{"i_l":0}',
    'kdt': 'hBXbJG7ZcXtmGD9UPoULxuaOfCDp1EINzrfQxzkQ',
    'auth_token': '1a057101daf2960459a8ef655d813f5b11f27ff2',
    'twid': 'u%3D900594828018409472',
    'ct0': '7eb78511619661d262e738930f15c27c414c618d9ab183f0cc4d26f11bffae0d929b7ab0253af92aa8e71ab6f4d4ec4a5e19c9ee4c447808477d2ef1e9a781b4e2e703270cb4c72acace3064740c8e05',
    'external_referer': 'padhuUp37zjgzgv1mFWxJ12Ozwit7owX|0|8e8t2xd8A2w%3D',
    'lang': 'en',
    'personalization_id': '"v1_HuU2ijKrtvCe2nIvWDD+Nw=="',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9,ar;q=0.8',
    'authorization': 'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA',
    'cache-control': 'no-cache',
    'content-type': 'application/json',
    # 'cookie': 'des_opt_in=Y; dnt=1; guest_id=v1%3A172130542309363976; night_mode=2; guest_id_marketing=v1%3A172130542309363976; guest_id_ads=v1%3A172130542309363976; g_state={"i_l":0}; kdt=hBXbJG7ZcXtmGD9UPoULxuaOfCDp1EINzrfQxzkQ; auth_token=1a057101daf2960459a8ef655d813f5b11f27ff2; twid=u%3D900594828018409472; ct0=7eb78511619661d262e738930f15c27c414c618d9ab183f0cc4d26f11bffae0d929b7ab0253af92aa8e71ab6f4d4ec4a5e19c9ee4c447808477d2ef1e9a781b4e2e703270cb4c72acace3064740c8e05; external_referer=padhuUp37zjgzgv1mFWxJ12Ozwit7owX|0|8e8t2xd8A2w%3D; lang=en; personalization_id="v1_HuU2ijKrtvCe2nIvWDD+Nw=="',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://x.com/Scrapfly_dev',
    'sec-ch-ua': '"Not)A;Brand";v="99", "Google Chrome";v="127", "Chromium";v="127"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
    'x-client-transaction-id': 'XUs1QEC9/2nEVkKxJY1aSTwd9/gBNphdOfkkOTrWS3Jt5w6NgYpLAD8wZvAnk8q4vlOoAl/mdOJKyFNy8UtSbJQLkFQkXg',
    'x-csrf-token': '7eb78511619661d262e738930f15c27c414c618d9ab183f0cc4d26f11bffae0d929b7ab0253af92aa8e71ab6f4d4ec4a5e19c9ee4c447808477d2ef1e9a781b4e2e703270cb4c72acace3064740c8e05',
    'x-twitter-active-user': 'yes',
    'x-twitter-auth-type': 'OAuth2Session',
    'x-twitter-client-language': 'en',
}

params = {
    'variables': '{"userId":"1310623081300402178","count":20,"cursor":"DAABCgABGUIXla___-wKAAIXu_LN5xrQRggAAwAAAAIAAA","includePromotedContent":true,"withQuickPromoteEligibilityTweetFields":true,"withVoice":true,"withV2Timeline":true}',
    'features': '{"rweb_tipjar_consumption_enabled":true,"responsive_web_graphql_exclude_directive_enabled":true,"verified_phone_label_enabled":false,"creator_subscriptions_tweet_preview_api_enabled":true,"responsive_web_graphql_timeline_navigation_enabled":true,"responsive_web_graphql_skip_user_profile_image_extensions_enabled":false,"communities_web_enable_tweet_community_results_fetch":true,"c9s_tweet_anatomy_moderator_badge_enabled":true,"articles_preview_enabled":true,"responsive_web_edit_tweet_api_enabled":true,"graphql_is_translatable_rweb_tweet_is_translatable_enabled":true,"view_counts_everywhere_api_enabled":true,"longform_notetweets_consumption_enabled":true,"responsive_web_twitter_article_tweet_consumption_enabled":true,"tweet_awards_web_tipping_enabled":false,"creator_subscriptions_quote_tweet_preview_enabled":false,"freedom_of_speech_not_reach_fetch_enabled":true,"standardized_nudges_misinfo":true,"tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled":true,"rweb_video_timestamps_enabled":true,"longform_notetweets_rich_text_read_enabled":true,"longform_notetweets_inline_media_enabled":true,"responsive_web_enhance_cards_enabled":false}',
    'fieldToggles': '{"withArticlePlainText":false}',
}

response = requests.get(
    'https://x.com/i/api/graphql/E3opETHurmVJflFsUBVuUQ/UserTweets',
    params=params,
    cookies=cookies,
    headers=headers,
)
response.status_code
# Out:
# 200

# %%
data = response.json()['data']['user']['result']['timeline_v2']['timeline']['instructions'][0]['entries']

# %%
jmespath.search('''
    [].entryId
''', data)
# Out:
# ['tweet-1709924524895133961',
#  'tweet-1700165182817792263',
#  'tweet-1699064129884172642',
#  'tweet-1698697721064886589',
#  'tweet-1697237947639058495',
#  'tweet-1696915594195423525',
#  'tweet-1695721614179279330',
#  'tweet-1691835433083085117',
#  'tweet-1689606378208256002',
#  'tweet-1687459308600958978',
#  'tweet-1685865219585703936',
#  'tweet-1680441195854708737',
#  'tweet-1678765768228638726',
#  'tweet-1677012783777583105',
#  'tweet-1676895848654069760',
#  'tweet-1667013143904567296',
#  'tweet-1664267318053179398',
#  'tweet-1658170586508546048',
#  'tweet-1653035176631447552',
#  'cursor-top-1820043131081457645',
#  'cursor-bottom-1820043131081457625']

# %%
[cursor for cursor in data[-2:]]
# Out:
# [{'entryId': 'cursor-top-1820043131081457645',
#   'sortIndex': '1820043131081457645',
#   'content': {'entryType': 'TimelineTimelineCursor',
#    '__typename': 'TimelineTimelineCursor',
#    'value': 'DAABCgABGUIXlbAAJv0KAAIXut9LuxphCQgAAwAAAAEAAA',
#    'cursorType': 'Top'}},
#  {'entryId': 'cursor-bottom-1820043131081457625',
#   'sortIndex': '1820043131081457625',
#   'content': {'entryType': 'TimelineTimelineCursor',
#    '__typename': 'TimelineTimelineCursor',
#    'value': 'DAABCgABGUIXla___9cKAAIW8MK8KFewAAgAAwAAAAIAAA',
#    'cursorType': 'Bottom'}}]

# %%
jmespath.search('''
    [].content.itemContent.tweet_results.result.legacy.full_text
''', data)
# Out:
# ["Here's a quick tutorial on how to scrape Google Trends through it's hidden secret API #webScraping 🤖🥷\n\nhttps://t.co/k3BJjte76T https://t.co/PNZCmOpuzn",
#  'A new blog post has been published! \n\nHow to Scrape Google SEO Keyword Data and Rankings 🤖\n\nCheckout it out 👇\nhttps://t.co/uHSFwtDCM1 https://t.co/999OO23GZ0',
#  'A new blog post has been published! \n\nUltimate XPath Cheatsheet for HTML Parsing in Web Scraping 🤖\n\nCheckout it out 👇\nhttps://t.co/BXhUHln3gT https://t.co/3cdAlCMW4l',
#  'A new blog post has been published! \n\nHow to Effectively Use User Agents for Web Scraping 🤖\n\nCheckout it out 👇\nhttps://t.co/gNOlZadNUo https://t.co/LWZJoCU1vY',
#  'A new blog post has been published! \n\nHow to Observe E-Commerce Trends using Web Scraping 🤖\n\nCheckout it out 👇\nhttps://t.co/DnlqSIEY6H https://t.co/rdVCI3RALA',
# ...

# %%
# Try without hypen: DAABCgABGUIXla___9cKAAIW8MK8KFewAAgAAwAAAAIAAA

# %%
params4 = {
    'variables': '{"userId":"1310623081300402178","count":20,"cursor":"DAABCgABGUIXla___9cKAAIW8MK8KFewAAgAAwAAAAIAAA","includePromotedContent":true,"withQuickPromoteEligibilityTweetFields":true,"withVoice":true,"withV2Timeline":true}',
    'features': '{"rweb_tipjar_consumption_enabled":true,"responsive_web_graphql_exclude_directive_enabled":true,"verified_phone_label_enabled":false,"creator_subscriptions_tweet_preview_api_enabled":true,"responsive_web_graphql_timeline_navigation_enabled":true,"responsive_web_graphql_skip_user_profile_image_extensions_enabled":false,"communities_web_enable_tweet_community_results_fetch":true,"c9s_tweet_anatomy_moderator_badge_enabled":true,"articles_preview_enabled":true,"responsive_web_edit_tweet_api_enabled":true,"graphql_is_translatable_rweb_tweet_is_translatable_enabled":true,"view_counts_everywhere_api_enabled":true,"longform_notetweets_consumption_enabled":true,"responsive_web_twitter_article_tweet_consumption_enabled":true,"tweet_awards_web_tipping_enabled":false,"creator_subscriptions_quote_tweet_preview_enabled":false,"freedom_of_speech_not_reach_fetch_enabled":true,"standardized_nudges_misinfo":true,"tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled":true,"rweb_video_timestamps_enabled":true,"longform_notetweets_rich_text_read_enabled":true,"longform_notetweets_inline_media_enabled":true,"responsive_web_enhance_cards_enabled":false}',
    'fieldToggles': '{"withArticlePlainText":false}',
}

response4 = requests.get(
    'https://x.com/i/api/graphql/E3opETHurmVJflFsUBVuUQ/UserTweets',
    params=params4,
    headers=headers,
    cookies=cookies
)
response4.status_code
# Out:
# 200

# %%
data = response4.json()['data']['user']['result']['timeline_v2']['timeline']['instructions'][0]['entries']

# %%
data
# Out:
# [{'entryId': 'tweet-1651042163885473794',
#   'sortIndex': '1820043131081457623',
#   'content': {'entryType': 'TimelineTimelineItem',
#    '__typename': 'TimelineTimelineItem',
#    'itemContent': {'itemType': 'TimelineTweet',
#     '__typename': 'TimelineTweet',
#     'tweet_results': {'result': {'__typename': 'Tweet',
#       'rest_id': '1651042163885473794',
#       'core': {'user_results': {'result': {'__typename': 'User',
#          'id': 'VXNlcjoxMzEwNjIzMDgxMzAwNDAyMTc4',
#          'rest_id': '1310623081300402178',
#          'affiliates_highlighted_label': {},
#          'has_graduated_access': True,
#          'is_blue_verified': True,
#          'profile_image_shape': 'Circle',
#          'legacy': {'following': False,
#           'can_dm': False,
#           'can_media_tag': True,
#           'created_at': 'Mon Sep 28 16:51:22 +0000 2020',
#           'default_profile': True,
#           'default_profile_image': False,
# ...

# %%
jmespath.search('''
    [].content.itemContent.tweet_results.result.legacy.full_text
''', data)
# Out:
# ['A new blog post has been published! \n\nHow to Scrape Without Getting Blocked? In-Depth Tutorial 🤖\n\nCheckout it out 👇\nhttps://t.co/tPqNzOy92c https://t.co/lrWLxz3R4C',
#  'A new blog post has been published! \n\nStepping into Footwear Market with Web Scraping 🤖\n\nCheckout it out 👇 https://t.co/kCohTttrmM',
#  'A new blog post has been published! \n\nHow to Scrape https://t.co/PRRUEhuYJp for Fashion Apparel Data in Python 🤖\n\nCheckout it out 👇 https://t.co/9WaCUH38NA',
#  'A new blog post has been published! \n\nHow to Scrape Sitemaps to Discover Scraping Targets 🤖\n\nCheckout it out 👇 https://t.co/7jm5EkjzGx',
#  'A new blog post has been published! \n\nHow to Scrape Fashionphile for Second Hand Fashion Data 🤖\n\nCheckout it out 👇 https://t.co/8KqHNTH8Ar',
# ...

# %%
jmespath.search('''
    [].content.itemContent.tweet_results.result.legacy.full_text
''', data2)
# Out:
# ['🤖Learn #webscraping with #Go through native HTTP requests, HTML parsing to a step-by-step guide to using #Colly👇\nhttps://t.co/w1u22r0ewM',
#  "🤖 Here's how to use #LLM and #webscraping for #RAG applications using  #LlamaIndex and #LangChain 👇\nhttps://t.co/XxzhwALlCh",
#  '🤖 Introduction to cloud browsers in #webscraping and their benefits, as well as a step-by-step setup with self-hosted Selenium-grid cloud browsers 👇\nhttps://t.co/dA7g4laX7c',
#  '🤖 Learn how to #scrape forms through a step-by-step guide using HTTP clients and headless browsers. 👇\n\nhttps://t.co/P4ZGv40sWN',
#  "🔍Here's how to create a minimum advertised price (MAP) monitoring tool using #webscraping 👇\nhttps://t.co/Oa1Ct6Y9n7",
#  "🍯Here's how honeypot traps are used to lure and blacklist web scrapers. Be cautious when #webScraping 👇\nhttps://t.co/UfZsUVGXeb",
#  "🤖 Here's how to scrape https://t.co/XpjedjMUA9 - the biggest real estate platform in Germany - with  #python 🐍\nhttps://t.co/0bu2FBePrM",
# ...

# %%
# Apply obtained cursor for navigation

params2 = {
    'variables': '{"userId":"1310623081300402178","count":20,"cursor":"DAABCgABGUIeO6K__-9cKAAIW8MK8KFewAAgAAwAAAAIAAA","includePromotedContent":true,"withQuickPromoteEligibilityTweetFields":true,"withVoice":true,"withV2Timeline":true}',
    'features': '{"rweb_tipjar_consumption_enabled":true,"responsive_web_graphql_exclude_directive_enabled":true,"verified_phone_label_enabled":false,"creator_subscriptions_tweet_preview_api_enabled":true,"responsive_web_graphql_timeline_navigation_enabled":true,"responsive_web_graphql_skip_user_profile_image_extensions_enabled":false,"communities_web_enable_tweet_community_results_fetch":true,"c9s_tweet_anatomy_moderator_badge_enabled":true,"articles_preview_enabled":true,"responsive_web_edit_tweet_api_enabled":true,"graphql_is_translatable_rweb_tweet_is_translatable_enabled":true,"view_counts_everywhere_api_enabled":true,"longform_notetweets_consumption_enabled":true,"responsive_web_twitter_article_tweet_consumption_enabled":true,"tweet_awards_web_tipping_enabled":false,"creator_subscriptions_quote_tweet_preview_enabled":false,"freedom_of_speech_not_reach_fetch_enabled":true,"standardized_nudges_misinfo":true,"tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled":true,"rweb_video_timestamps_enabled":true,"longform_notetweets_rich_text_read_enabled":true,"longform_notetweets_inline_media_enabled":true,"responsive_web_enhance_cards_enabled":false}',
    'fieldToggles': '{"withArticlePlainText":false}',
}

response2 = requests.get(
    'https://x.com/i/api/graphql/E3opETHurmVJflFsUBVuUQ/UserTweets',
    params=params2,
    headers=headers,
    cookies=cookies
)
response2.status_code

# %%
response2.json()
# Out:
# {'data': {'user': {'result': {'__typename': 'User',
#     'timeline_v2': {'timeline': {'instructions': [{'type': 'TimelineClearCache'},
#        {'type': 'TimelineAddEntries',
#         'entries': [{'entryId': 'tweet-1816390770561077499',
#           'sortIndex': '1820052146146508800',
#           'content': {'entryType': 'TimelineTimelineItem',
#            '__typename': 'TimelineTimelineItem',
#            'itemContent': {'itemType': 'TimelineTweet',
#             '__typename': 'TimelineTweet',
#             'tweet_results': {'result': {'__typename': 'Tweet',
#               'rest_id': '1816390770561077499',
#               'core': {'user_results': {'result': {'__typename': 'User',
#                  'id': 'VXNlcjoxMzEwNjIzMDgxMzAwNDAyMTc4',
#                  'rest_id': '1310623081300402178',
#                  'affiliates_highlighted_label': {},
#                  'has_graduated_access': True,
#                  'is_blue_verified': True,
# ...

# %%
data2 = response2.json()['data']['user']['result']['timeline_v2']['timeline']['instructions'][1]['entries']
# Note on loading more Tweets, They become index 1 in "instructions" unlike first api call

# %%
data2
# Out:
# [{'entryId': 'tweet-1816390770561077499',
#   'sortIndex': '1820052146146508800',
#   'content': {'entryType': 'TimelineTimelineItem',
#    '__typename': 'TimelineTimelineItem',
#    'itemContent': {'itemType': 'TimelineTweet',
#     '__typename': 'TimelineTweet',
#     'tweet_results': {'result': {'__typename': 'Tweet',
#       'rest_id': '1816390770561077499',
#       'core': {'user_results': {'result': {'__typename': 'User',
#          'id': 'VXNlcjoxMzEwNjIzMDgxMzAwNDAyMTc4',
#          'rest_id': '1310623081300402178',
#          'affiliates_highlighted_label': {},
#          'has_graduated_access': True,
#          'is_blue_verified': True,
#          'profile_image_shape': 'Circle',
#          'legacy': {'following': False,
#           'can_dm': False,
#           'can_media_tag': True,
#           'created_at': 'Mon Sep 28 16:51:22 +0000 2020',
#           'default_profile': True,
#           'default_profile_image': False,
# ...

# %%
len(data2)
# Out:
# 20

# %%
jmespath.search('''
    [].entryId
''', data2)
# Out:
# ['tweet-1816390770561077499',
#  'tweet-1801028043693019440',
#  'tweet-1792408667058495651',
#  'tweet-1788949979429490958',
#  'tweet-1787674119737168225',
#  'who-to-follow-1820052146146508805',
#  'tweet-1756939351110599161',
#  'tweet-1730075764106956956',
#  'tweet-1729039540063764753',
#  'tweet-1724299685031014447',
#  'tweet-1723658307531931834',
#  'tweet-1723304616396505275',
#  'tweet-1719259455915970760',
#  'tweet-1718162930632659167',
#  'tweet-1717834976962453701',
#  'tweet-1714209891135668315',
#  'tweet-1711991838159286776',
#  'tweet-1710227449676746822',
#  'cursor-top-1820052146146508801',
#  'cursor-bottom-1820052146146508782']

# %%
[cursor for cursor in data2[-2:]]
# Out:
# [{'entryId': 'cursor-top-1820052146146508801',
#   'sortIndex': '1820052146146508801',
#   'content': {'entryType': 'TimelineTimelineCursor',
#    '__typename': 'TimelineTimelineCursor',
#    'value': 'DAABCgABGUIfyKvAJxEKAAIZNR3IPJdQ-wgAAwAAAAEAAA',
#    'cursorType': 'Top'}},
#  {'entryId': 'cursor-bottom-1820052146146508782',
#   'sortIndex': '1820052146146508782',
#   'content': {'entryType': 'TimelineTimelineCursor',
#    '__typename': 'TimelineTimelineCursor',
#    'value': 'DAABCgABGUIfyKu__-wKAAIXu_LN5xrQRggAAwAAAAIAAA',
#    'cursorType': 'Bottom'}}]

# %%
# Another test DAABCgABGUIfyKu__-wKAAIXu_LN5xrQRggAAwAAAAIAAA

# %%
params3 = {
    'variables': '{"userId":"1310623081300402178","count":20,"cursor":"DAABCgABGUIfyKu__-wKAAIXu_LN5xrQRggAAwAAAAIAAA","includePromotedContent":true,"withQuickPromoteEligibilityTweetFields":true,"withVoice":true,"withV2Timeline":true}',
    'features': '{"rweb_tipjar_consumption_enabled":true,"responsive_web_graphql_exclude_directive_enabled":true,"verified_phone_label_enabled":false,"creator_subscriptions_tweet_preview_api_enabled":true,"responsive_web_graphql_timeline_navigation_enabled":true,"responsive_web_graphql_skip_user_profile_image_extensions_enabled":false,"communities_web_enable_tweet_community_results_fetch":true,"c9s_tweet_anatomy_moderator_badge_enabled":true,"articles_preview_enabled":true,"responsive_web_edit_tweet_api_enabled":true,"graphql_is_translatable_rweb_tweet_is_translatable_enabled":true,"view_counts_everywhere_api_enabled":true,"longform_notetweets_consumption_enabled":true,"responsive_web_twitter_article_tweet_consumption_enabled":true,"tweet_awards_web_tipping_enabled":false,"creator_subscriptions_quote_tweet_preview_enabled":false,"freedom_of_speech_not_reach_fetch_enabled":true,"standardized_nudges_misinfo":true,"tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled":true,"rweb_video_timestamps_enabled":true,"longform_notetweets_rich_text_read_enabled":true,"longform_notetweets_inline_media_enabled":true,"responsive_web_enhance_cards_enabled":false}',
    'fieldToggles': '{"withArticlePlainText":false}',
}

response3 = requests.get(
    'https://x.com/i/api/graphql/E3opETHurmVJflFsUBVuUQ/UserTweets',
    params=params3,
    headers=headers,
    cookies=cookies
)
response3.status_code
# Out:
# 200

# %%
len(response3.json()['data']['user']['result']['timeline_v2']['timeline']['instructions'][0]['entries'])
# Out:
# 21
