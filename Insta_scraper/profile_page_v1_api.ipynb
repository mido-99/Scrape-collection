# %%
import requests
import jmespath
from pprint import pprint
import json

# %%
url = "https://www.instagram.com/api/v1/users/web_profile_info/?username=leomessi&hl=en"
headers={
        # this is internal ID of an instegram backend app. It doesn't change often.
        "x-ig-app-id": "936619743392459",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9,ru;q=0.8",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept": "*/*",
    }

resp = requests.get(url, headers=headers)
resp.status_code
# Out:
# 200

# %%
resp.json()
# Out:
# {'data': {'user': {'ai_agent_type': None,
#    'biography': 'Bienvenidos a la cuenta oficial de Instagram de Leo Messi / Welcome to the official Leo Messi Instagram account',
#    'bio_links': [{'title': 'The Messi Experience 🔥⚽️🔟',
#      'lynx_url': 'https://l.instagram.com/?u=http%3A%2F%2Fthemessiexperience.com%2F&e=AT1E28ZTe5F4YGJrG3gfoyhF-eVPAMbdrtYyuxC5Dy0n1Y1Jh7eiBstwT9OYbceyQt3Jh32jEQPG6XU1G0KtT9X1c9tAjgTS',
#      'url': 'http://themessiexperience.com',
#      'link_type': 'external'},
#     {'title': 'MÁS+ by Messi',
#      'lynx_url': 'https://l.instagram.com/?u=http%3A%2F%2Fwww.masbymessi.com%2F&e=AT03NR0gNL76cgFUVCiP8P5PJQ9DmmhaN_7dgptnYscP789GnOfYvRKEkph9FwsUBCxbnH9SbliUNV_gBMV9-LHhq33LiGh-',
#      'url': 'http://www.masbymessi.com',
#      'link_type': 'external'},
#     {'title': '📺 Watch MLS Season Pass',
# ...

# %%
resp.json().keys()
# Out:
# dict_keys(['data', 'status'])

# %%
keys = resp.json()['data']['user'].keys()
for i in data:
    print(i)
# Out:
# ai_agent_type
# biography
# bio_links
# fb_profile_biolink
# biography_with_entities
# blocked_by_viewer
# restricted_by_viewer
# country_block
# eimu_id
# external_url
# external_url_linkshimmed
# edge_followed_by
# fbid
# followed_by_viewer
# edge_follow
# follows_viewer
# full_name
# group_metadata
# has_ar_effects
# has_clips
# has_guides
# has_channel
# has_blocked_viewer
# highlight_reel_count
# has_onboarded_to_text_post_app
# has_requested_viewer
# hide_like_and_view_counts
# id
# is_business_account
# is_professional_account
# is_supervision_enabled
# is_guardian_of_viewer
# is_supervised_by_viewer
# is_supervised_user
# is_embeds_disabled
# is_joined_recently
# guardian_id
# business_address_json
# business_contact_method
# business_email
# business_phone_number
# business_category_name
# overall_category_name
# category_enum
# category_name
# is_private
# is_verified
# is_verified_by_mv4b
# is_regulated_c18
# edge_mutual_followed_by
# pinned_channels_list_count
# ...

# %%
print(json.dumps(data['edge_felix_video_timeline']))
# Out:
# {"count": 23, "page_info": {"has_next_page": true, "end_cursor": "QVFES19MeV80VkRlMXRLd0p5Q0ZiRFZaa1Vnd2Q5NzlxY2F0ODFFbkVaOGJKZ1U2NzBDMHl0QWxBX1E2enp2U3lyOE9QU1ZCclpqazdTd2p6LXhyN2Y3Zg=="}, "edges": [{"node": {"__typename": "GraphVideo", "id": "2901804208007939757", "shortcode": "ChFR42CDAat", "dimensions": {"height": 608, "width": 1080}, "display_url": "https://instagram.fcai20-6.fna.fbcdn.net/v/t51.2885-15/298829157_143969708316579_4182084686304569330_n.jpg?stp=dst-jpg_e15_fr_s1080x1080&_nc_ht=instagram.fcai20-6.fna.fbcdn.net&_nc_cat=103&_nc_ohc=v4r95Y3N804Q7kNvgHVBxiO&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AYBEGT90vx9LNK1SmlJDtg5B38nJI-BE1Fim8L0ISaNzSw&oe=6688C296&_nc_sid=8b3546", "edge_media_to_tagged_user": {"edges": [{"node": {"user": {"full_name": "Dezer Development", "followed_by_viewer": false, "id": "1521840888", "is_verified": false, "profile_pic_url": "https://instagram.fcai20-2.fna.fbcdn.net/v/t51.2885-19/12748322_1016056875152909_191918168_a.jpg?stp=dst-jpg_s150x150&_nc_ht=inst
# ...

# %%
data = resp.json()['data']['user']
result = jmespath.search(
    '''{
    name: full_name,
    username: username,
    bio: biography,
    bio_links: bio_links[].url,
    category: category_name,
    followers: edge_followed_by.count,
    follows: edge_follow.count,
    posts: edge_owner_to_timeline_media.count,
    profile_pic_url: profile_pic_url_hd,
    private: is_private,
    verified: is_verified,
    business_account: is_business_account,
    joined_recently: is_joined_recently
    }''', data)

result
# Out:
# {'name': 'Leo Messi',
#  'username': 'leomessi',
#  'bio': 'Bienvenidos a la cuenta oficial de Instagram de Leo Messi / Welcome to the official Leo Messi Instagram account',
#  'bio_links': ['http://themessiexperience.com',
#   'http://www.masbymessi.com',
#   'https://apple.co/Messigift'],
#  'category': 'Athlete',
#  'followers': 503887571,
#  'follows': 321,
#  'posts': 1230,
#  'profile_pic_url': 'https://instagram.fcai20-2.fna.fbcdn.net/v/t51.2885-19/424905549_7243065989106669_45026390061580919_n.jpg?stp=dst-jpg_s320x320&_nc_ht=instagram.fcai20-2.fna.fbcdn.net&_nc_cat=1&_nc_ohc=6fDSR0iMKWEQ7kNvgFHUMM0&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AYAogY3cr9PeM07YKy0kAoVwN8jF0QGF9a1otSzZ5WdWqg&oe=6688EC71&_nc_sid=8b3546',
#  'private': False,
#  'verified': True,
#  'business_account': True,
#  'joined_recently': False}
