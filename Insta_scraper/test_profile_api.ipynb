# %%
import requests

import jmespath

# %%
url = "https://www.instagram.com/api/v1/users/web_profile_info/?username=leomessi&hl=en"
headers={
        # this is internal ID of an instegram backend app. It doesn't change often.
        "x-ig-app-id": "936619743392459",
        # use browser-like features
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9,ru;q=0.8",
        "Accept-Encoding": "gzip, deflate, br",
        "Accept": "*/*",
    }

resp = requests.get(url, headers=headers)
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# '{"data":{"user":{"ai_agent_type":null,"biography":"Bienvenidos a la cuenta oficial de Instagram de Leo Messi / Welcome to the official Leo Messi Instagram account","bio_links":[{"title":"📺 WATCH FREE","lynx_url":"https://l.instagram.com/?u=http%3A%2F%2Fapple.co%2Fmlsmessi\\u0026e=AT2Fvyntf19kgODslCsnhjfQdRM8HhaY50Ojwcgvd_Vw_G2K-PbW903gJErJyEzm5MU0urDImWnjY-UYjARAy_wLiCoTw6ge","url":"http://apple.co/mlsmessi","link_type":"external"},{"title":"The Messi Experience 🔥⚽️🔟","lynx_url":"https://l.instagram.com/?u=http%3A%2F%2Fthemessiexperience.com%2F\\u0026e=AT2Gd6vjPLBuseFMjUctifgHfV7H1duYxYOC5WeCmo2rPfi4BwcP3NJNrnoqd7V5fKr3qXaE7ckTM-5fyjIPyYjH5X0-8BJB","url":"http://themessiexperience.com","link_type":"external"}],"fb_profile_biolink":null,"biography_with_entities":{"raw_text":"Bienvenidos a la cuenta oficial de Instagram de Leo Messi / Welcome to the official Leo Messi Instagram account","entities":[]},"blocked_by_viewer":false,"restricted_by_viewer":null,"country_block":false,"eimu_id":"112779213447425","external_url":"http://apple.co/mlsmessi","external_url_linkshimmed":"https://l.instagram.com/?u=http%3A%2F%2Fapple.co%2Fmlsmessi\\u0026e=AT316dWPIndTQLm7r7FIr5Jic8xka1x2D4uQVIwdvx7mAKSt8XBi5moQhQmAv1nE4ww5tF7p2YVXG-DFu8kbqe3uFnspvkHp","edge_followed_by":{"count":502951371},"fbid":"17841401016706680","followed_by_viewer":false,"edge_follow":{"count":312},"follows_viewer":false,"full_name":"Leo Messi","group_metadata":null,"has_ar_effects":false,"has_clips":true,"has_guides":false,"has_channel":false,"has_blocked_viewer":false,"highlight_reel_count":3,"has_onboarded_to_text_post_app":false,"has_requested_viewer":false,"hide_like_and_view_counts":false,"id":"427553890","is_business_account":true,"is_professional_account":true,"is_supervision_enabled":false,"is_guardian_of_viewer":false,"is_supervised_by_viewer":false,"is_supervised_user":false,"is_embeds_disabled":false,"is_joined_recently":false,"guardian_id":null,"business_address_json":"{\\"city_name\\": \\"Miami, Florida\\", \\"city_id\\": 110148382341970, \\"latitude\\": 25.77481, \\"longitude\\": -80.19773, \\"street_address\\": null, \\"zip_code\\": null}","business_contact_method":"UNKNOWN","business_email":null,"business_phone_number":null,"business_category_name":"None","overall_category_name":null,"category_enum":"ATHLETE","category_name":"Athlete","is_private":false,"is_verified":true,"is_verified_by_mv4b":false,"is_regulated_c18":false,"edge_mutual_followed_by":{"count":0,"edges":[]},"pinned_channels_list_count":0,"profile_pic_url":"https://instagram.fcai20-4.fna.fbcdn.net/v/t51.2885-19/424905549_7243065989106669_45026390061580919_n.jpg?stp=dst-jpg_s150x150\\u0026_nc_ht=instagram.fcai20-4.fna.fbcdn.net\\u0026_nc_cat=1\\u0026_nc_ohc=dx5aTS42lO8Q7kNvgG4GYBh\\u0026edm=AOQ1c0wBAAAA\\u0026ccb=7-5\\u0026oh=00_AYAi4fJQ2bidN34hZbPqohpBQDyEfG818t_lqlsxo-OuEw\\u0026oe=6643EDF1\\u0026_nc_sid=8b3546","profile_pic_url_hd":"https://instagram.fcai20-4.fna.fbcdn.net/v/t51.2885-19/424905549_7243065989106669_45026390061580919_n.jpg?stp=dst-jpg_s320x320\\u0026_nc_ht=instagram.fcai20-4.fna.fbcdn.net\\u0026_nc_cat=1\\u0026_nc_ohc=dx5aTS42lO8Q7kNvgG4GYBh\\u0026edm=AOQ1c0wBAAAA\\u0026ccb=7-5\\u0026oh=00_AYBLP-Bv7nP2ehusW9Ypg3kPLjIf0mvhI-ZRUo4woJfnBw\\u0026oe=6643EDF1\\u0026_nc_sid=8b3546","requested_by_viewer":false,"should_show_category":true,"should_show_public_contacts":true,"show_account_transparency_details":true,"remove_message_entrypoint":false,"transparency_label":null,"transparency_product":null,"username":"leomessi","connected_fb_page":null,"pronouns":[],"edge_felix_video_timeline":{"count":23,"page_info":{"has_next_page":true,"end_cursor":"QVFEUFE3TjFFOUU5QmRaNVRuMTZuQmlXb1h5NGVJUlVIVkJQQ2Z0azhMTkpZLTlFZzZDcFZlLVdMbXlkT0J3UHhSVnBnOEQyV3RBS0R2dGxybENaM1hiYg=="},"edges":[{"node":{"__typename":"GraphVideo","id":"2901804208007939757","shortcode":"ChFR42CDAat","dimensions":{"height":608,"width":1080},"display_url":"https://instagram.fcai20-6.fna.fbcdn.net/v/t51.2885-15/298829157_14396 ...

# %%
resp.json().keys()
# Out:
# dict_keys(['data', 'status'])

# %%
from pprint import pprint
#pprint(resp.json()['data']['user'].keys())
for i in data:
    print(i)
# Out:
# ai_agent_type
# biography
# bio_links
# fb_profile_biolink
# biography_with_entities
# blocked_by_viewer
# restricted_by_viewer
# country_block
# eimu_id
# external_url
# external_url_linkshimmed
# edge_followed_by
# fbid
# followed_by_viewer
# edge_follow
# follows_viewer
# full_name
# group_metadata
# has_ar_effects
# has_clips
# has_guides
# has_channel
# has_blocked_viewer
# highlight_reel_count
# has_onboarded_to_text_post_app
# has_requested_viewer
# hide_like_and_view_counts
# id
# is_business_account
# is_professional_account
# is_supervision_enabled
# is_guardian_of_viewer
# is_supervised_by_viewer
# is_supervised_user
# is_embeds_disabled
# is_joined_recently
# guardian_id
# business_address_json
# business_contact_method
# business_email
# business_phone_number
# business_category_name
# overall_category_name
# category_enum
# category_name
# is_private
# is_verified
# is_verified_by_mv4b
# is_regulated_c18
# edge_mutual_followed_by
# pinned_channels_list_count
# profile_pic_url
# profile_pic_url_hd
# requested_by_viewer
# should_show_category
# should_show_public_contacts
# show_account_transparency_details
# remove_message_entrypoint
# transparency_label
# transparency_product
# username
# connected_fb_page
# pronouns
# edge_felix_video_timeline
# edge_owner_to_timeline_media
# edge_saved_media
# edge_media_collections
# edge_related_profiles

# %%
data = resp.json()['data']['user']

# %%
result = jmespath.search(
    '''{
    name: full_name,
    username: username,
    bio: biography,
    bio_links: bio_links[].url,
    category: category_name,
    followers: edge_followed_by.count,
    follows: edge_follow.count,
    posts: edge_owner_to_timeline_media.count,
    profile_pic_url: profile_pic_url_hd,
    private: is_private,
    verified: is_verified,
    business_account: is_business_account,
    joined_recently: is_joined_recently
    }''', data)

result
